# %% [markdown]
# ![](https://i.ytimg.com/vi/tyyA0VtQXjQ/maxresdefault.jpg)

# %% [markdown]
#  # Projet web Mining :
#  # FEUDJIO NGOUANET VALDES VOTEL   &   SOBJIO LUDANE LAGNOL

# %% [markdown]
# ### Introduction au projet
#
# Dans le cadre des travaux pratiques du cours de Traitement Automatique des Langues (TAL), nous avons pour objectif de concevoir une application dédiée à l'extraction d'informations à partir de données issues de flux RSS. Ce projet vise à mettre en œuvre des techniques fondamentales du TAL pour collecter, analyser et extraire des connaissances pertinentes à partir d'un corpus de textes en français.
#
# L'application s'articule en deux grandes étapes :
# 1. **Scrapping et collecte de données** : Cette phase consiste à capturer des articles via des flux RSS, en les intégrant dans une base de données structurée. Elle repose sur des outils tels que `feedparser` et `newspaper` pour récupérer les métadonnées et le contenu textuel des articles.
# 2. **Extraction et analyse d'informations** : À partir du corpus collecté, nous explorons des techniques de reconnaissance des entités nommées (Personnes, Organisations, Lieux, etc.) et d'identification des relations entre ces entités. Cette tâche, connue sous le nom d'extraction d'information, permet de révéler les interactions pertinentes au sein du corpus.
#
# Les enjeux de ce projet sont multiples :
# - Automatiser la collecte de données textuelles à partir de flux en ligne.
# - Appliquer des modèles linguistiques pour identifier des informations structurées dans des textes non structurés.
# - Comprendre les relations sémantiques au sein des données pour dégager des connaissances exploitables.
#
# Les résultats attendus incluent :
# - Une base de données enrichie par des articles analysés et leurs métadonnées.
# - Une analyse qualitative des entités nommées et des relations détectées.
# - Une réflexion critique sur les méthodes utilisées, leurs limites et des pistes d’amélioration.
#
# Ce projet illustre des applications concrètes du TAL, notamment dans les domaines de la veille géopolitique, économique ou encore du fact-checking journalistique. À travers cette démarche, nous développons une expertise technique et conceptuelle sur des outils et méthodes clés dans l'extraction et l'analyse de l'information.

# %% [markdown]
# ### PARTIE 1 : WEB SCRAPING DE LA BASE DE DONNEES

# %% [markdown]
# #### installation des packages de base

# %%
#!wget https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json
#!wget https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/tvinfo-sources.json
#!pip install feedparser
#!pip install newspaper3k
#!python -m spacy download fr_core_news_md

# %% [markdown]
# #### Chargement des données deja existantes et des données sur les flus RSS

# %%
import json
import ssl
import feedparser as fp

# (a) Se prémunir contre le blocage de commande
ssl._create_default_https_context = ssl._create_unverified_context

# (b) Lire la base de données existante (francetvinfo.json)
with open("francetvinfo.json", "r", encoding="utf-8") as f:
    existing_data = json.load(f)


# (c) Lire les flux RSS listés dans tvinfo-sources.json
with open("tvinfo-sources.json", "r", encoding="utf-8") as f:
    rss_sources = json.load(f)

# %% [markdown]
# #### Selection des données qui ne sont pas encore dans la base de données existante

# %% [markdown]
# # QUESTION 2
#
# Pour identifier les zones contenant le titre et le texte d'un article dans le code HTML d'une page web, il faut d'abord inspecter la structure de la page.
#
# 1. **Le titre de l'article** : Le titre se trouve souvent dans un élément `<h1>`, `<h2>`, ou un autre type de balise avec une classe spécifique (par exemple, `<h1 class="article-title">`). En inspectant le code HTML, on peut repérer cette balise pour obtenir le titre de l'article.
#
# 2. **Le texte de l'article** : Le texte principal de l'article est généralement contenu dans un bloc `<div>`, `<article>`, ou parfois dans des balises `<p>` à l'intérieur d'une section avec une classe désignant le corps de l'article, comme `<div class="content">` ou `<div class="article-body">`. Vous devez repérer ces éléments pour récupérer le contenu principal.
#
# ### Que faut-il faire pour récupérer le texte de l'article ?
# Pour récupérer le texte de l'article, vous devrez analyser le code HTML et localiser les éléments correspondants (généralement des balises `<div>`, `<article>`, `<section>`, ou des balises spécifiques contenant des classes comme "content" ou "body"). Ensuite, vous pouvez extraire le texte de ces éléments en utilisant des outils comme BeautifulSoup en Python ou d'autres méthodes de parsing HTML.
#
# ### L'utilité de la bibliothèque Newspaper
# La bibliothèque *newspaper3k* est utile car elle automatise cette tâche de récupération du texte de l'article en analysant et extrayant directement le contenu principal de la page HTML. Elle est particulièrement efficace pour contourner les variations dans la structure HTML d'une page et permet de récupérer rapidement le titre, l'auteur, la date de publication et le texte sans avoir à inspecter manuellement chaque balise HTML.
#
# *Newspaper3k* fournit également des fonctionnalités supplémentaires comme la gestion des images, le nettoyage du contenu (en retirant les publicités ou les éléments non pertinents), et l'analyse sémantique du texte. Cela facilite grandement l'extraction d'informations de manière fiable et automatisée, même pour des pages au design complexe ou changeant.

# %% [markdown]
# # QUESTION 3

# %%
import feedparser as fp
from newspaper import Article
import requests
from urllib.parse import urlparse

# Extraire les liens existants pour éviter les doublons
existing_links = existing_data.keys()

# Scanner les flux RSS et repérer les nouveaux articles
new_articles = {}
invalid_urls_count = 0  # Compteur pour les URLs invalides

# Fonction pour vérifier si l'URL du flux RSS est valide

"""
Ce bloc de code parcourt les articles d'un flux RSS et vérifie si chaque article est nouveau en comparant son lien avec une liste de liens existants.
Pour chaque nouvel article, il utilise la bibliothèque `newspaper` pour télécharger et analyser les informations détaillées de l'article.
Les détails extraits, tels que le titre, la date de publication, l'auteur, la catégorie, le contenu et le lien de l'image, sont ensuite ajoutés à un dictionnaire `new_articles`.
En cas d'erreur de connexion ou d'autre exception lors du traitement de l'article, un message d'erreur est affiché.
"""


def check_url_validity(url):
    try:
        if not isinstance(url, str):  # Vérifier que l'URL est bien une chaîne de caractères
            print(f"URL invalide (pas une chaîne de caractères) : {url}")
            return False

        # Vérifier que l'URL ne contient pas de fragments ou autres éléments invalides
        parsed_url = urlparse(url)
        if parsed_url.fragment:
            print(f"URL invalide (contenant un fragment) : {url}")
            return False  # Si l'URL contient un fragment, on la considère invalide

        response = requests.get(url, timeout=5)
        if response.status_code != 200:
            print(f"Erreur de connexion pour l'URL {url} : Code de statut {response.status_code}")
            return False
        
        return True
    except requests.exceptions.RequestException as e:
        print(f"Erreur de connexion pour l'URL {url}: {e}")
        return False

for category, url in rss_sources.items():
    print(f"Lecture du flux RSS '{category}': {url}")
    
    # Vérification de la validité de l'URL
    if not check_url_validity(url):
        invalid_urls_count += 1  # Incrémenter le compteur pour les URLs invalides
        continue  # Passer au flux suivant

    # Analyser le flux RSS
    data = fp.parse(url)

    # Parcourir les articles du flux RSS
    for item in data.entries:
        if item.link not in existing_links:  # Vérifier si l'article est nouveau
            try:
                # Utiliser newspaper pour extraire les informations détaillées
                article = Article(item.link)
                article.download()
                article.parse()

                # Ajouter les détails de l'article dans new_articles
                new_articles[item.link] = {
                    "title": article.title or item.title,
                    "date": article.publish_date if article.publish_date else (item.published if hasattr(item, "published") else "N/A"),
                    "author": article.authors or item.get("author", "Inconnu"),
                    "category": category,
                    "content": article.text or item.get("description", "Pas de contenu"),
                    "image_link": article.top_image or "Pas d'image"
                }

            except requests.exceptions.RequestException as e:
                print(f"Erreur de connexion pour l'article {item.link}: {e}")
            except Exception as e:
                print(f"Erreur lors du traitement de l'article {item.link} : {e}")

# Afficher les résultats
print(f"{len(new_articles)} nouveaux articles")
print(f"{invalid_urls_count} flux RSS invalides ou inaccessibles.")
# Out:
# Lecture du flux RSS 'france': https://www.francetvinfo.fr/france.rss
# Lecture du flux RSS 'europe': https://www.francetvinfo.fr/monde/europe.rss
# Lecture du flux RSS 'economie': https://www.francetvinfo.fr/economie/entreprises.rss
# 59 nouveaux articles
# 0 flux RSS invalides ou inaccessibles.

# %% [markdown]
# ### Résumé du comportement
#
# - Les flux RSS sont parcourus et les articles sont récupérés.
# - Les doublons sont évités en vérifiant si le lien de l'article existe déjà dans `existing_links`.
# - Les informations détaillées de chaque article sont extraites via la bibliothèque `newspaper3k`, et elles sont ajoutées à `new_articles`.
# - Les erreurs sont gérées avec un bloc `try-except`, ce qui permet de continuer l'exécution même en cas de problème avec un article spécifique.

# %%
# Afficher les 10 premiers liens des nouveaux articles
print("Nombres d'articles",len(new_articles))
for key in list(new_articles.keys())[:10]:
    print(key)
# Out:
# Nombres d'articles 59
# https://www.francetvinfo.fr/france/hauts-de-france/pas-de-calais/pas-de-calais-au-moins-trois-migrants-morts-dans-une-tentative-de-traversee-de-la-manche_6983336.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/faits-divers/police/marseille-des-policiers-vises-par-des-tirs-cette-nuit-lors-d-une-course-poursuite_6983255.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/france/hauts-de-france/pas-de-calais-au-moins-deux-morts-dans-une-tentative-de-traversee-de-la-manche_6983165.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/monde/environnement/video-trier-ses-dechets-est-il-vraiment-utile_6979421.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/monde/europe/migrants/au-moins-trois-migrants-sont-morts-dans-le-pas-de-calais-lors-d-une-tentative-de-traversee-de-la-manche_6983171.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/replay-radio/le-journal-des-outre-mers/mayotte-toujours-dans-la-detresse-15-jours-apres-le-passage-du-cyclone-chido_6960071.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/replay-radio/8h30-fauvelle-dely/francois-bayrou-a-mayotte-mieux-vaut-tard-que-jamais-estime-laurent-jacobelli-porte-parole-du-rn-qui-reclame-des-mesures-de-fond_6960050.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/politique/francois-bayrou/francois-bayrou-attendu-lundi-a-mayotte_6983180.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/societe/drogue/tahiti-une-demi-tonne-de-cocaine-saisie-sur-un-navire-espagnol_6983177.html#xtor=RSS-3-[general]
# https://www.francetvinfo.fr/meteo/neige/avalanches/savoie-une-skieuse-de-44-ans-meurt-emportee-par-une-avalanche_6982058.html#xtor=RSS-3-[general]

# %%
import json
from datetime import datetime

# Fonction pour convertir les objets datetime en chaîne de caractères
def convert_datetime(obj):
    if isinstance(obj, datetime):
        return obj.strftime('%Y-%m-%d %H:%M:%S')  # Vous pouvez adapter le format à vos besoins
    raise TypeError("Type non sérialisable")

# Charger les données existantes dans tvinfo-sources.json
try:
    with open("francetvinfo.json", "r", encoding="utf-8") as file:
        existing_data = json.load(file)
except FileNotFoundError:
    print("Le fichier francetvinfo.json n'existe pas encore, il sera créé.")
    existing_data = {}  # Initialiser un dictionnaire vide si le fichier n'existe pas

# Mettre à jour les données existantes avec les nouveaux articles
existing_data.update(new_articles)

# Sauvegarder les données mises à jour dans tvinfo-sources.json
with open("francetvinfo.json", "w", encoding="utf-8") as file:
    # Utiliser `default` pour convertir les objets `datetime`
    json.dump(existing_data, file, indent=4, ensure_ascii=False, default=convert_datetime)

# Afficher le nombre d'articles ajoutés
added_articles_count = len(new_articles)
print(f"{added_articles_count} nouveaux articles ont été ajoutés au fichier francetvinfo.json.")
print("Le fichier francetvinfo.json a été mis à jour.")
# Out:
# 59 nouveaux articles ont été ajoutés au fichier francetvinfo.json.
# Le fichier francetvinfo.json a été mis à jour.

# %% [markdown]
# Le code ci-dessus a pour objectif de mettre à jour une base de données d'articles en y ajoutant de nouveaux articles récupérés depuis plusieurs flux RSS. Il commence par réinitialiser la base de données existante, puis il ajoute les nouveaux articles détectés, en évitant les doublons grâce à une vérification des liens. Chaque article est analysé pour extraire ses détails (titre, date, auteur, contenu, image, etc.) à l'aide de la bibliothèque *newspaper3k*. Enfin, la base de données mise à jour contient l'ensemble des articles existants et les nouveaux, et la taille totale de la base peut être affichée.

# %% [markdown]
# # QUESTION 4
# Pour gérer les images et garantir qu'elles restent accessibles même si elles sont supprimées du site web, voici comment nous pourrions procéder :
#
# 1. **Téléchargement de l'image** :
#    - Lors de l'extraction des articles via la bibliothèque *newspaper3k*, nous récupérons souvent l'URL de l'image principale avec l'attribut `article.top_image`. Nous pouvons utiliser cette URL pour télécharger l'image.
#    - Nous utiliserons une bibliothèque telle que `requests` pour télécharger l'image depuis l'URL fournie.
#
# 2. **Stockage local des images** :
#    - Une fois l'image téléchargée, nous la sauvegardons dans un répertoire spécifique de notre système de fichiers, par exemple dans un dossier appelé `images` ou `media`.
#    - Le nom du fichier peut être dérivé du titre de l'article ou d'un identifiant unique (comme un hash de l'URL de l'image) pour éviter les conflits de noms de fichiers.
#
# 3. **Référence dans la base de données** :
#    - Plutôt que de conserver uniquement l'URL de l'image dans la base de données, nous enregistrons le chemin local du fichier sur le disque (par exemple, `./images/article123.jpg`).
#    - Cela nous permettra de nous y référer ultérieurement, même si l'image originale a été supprimée du site.
#
# 4. **Vérification régulière** :
#    - Pour gérer l'espace disque et s'assurer que les images locales sont toujours pertinentes, nous pourrions mettre en place une tâche planifiée pour vérifier périodiquement si les articles sont toujours valides et si les images sont toujours présentes sur le site. Si elles sont manquantes, nous pourrions décider de supprimer l'image locale ou de la mettre à jour.
#
# 5. **Sécurisation et gestion des tailles** :
#    - Pour éviter de stocker des images trop volumineuses, nous pourrions éventuellement compresser les images avant de les stocker.
#    - Il pourrait également être utile de renommer les fichiers avec un format standard et de les convertir en un format d'image plus léger, comme le format `.webp`, si nécessaire.
#
# En suivant cette approche, nous garantirions que les images restent accessibles localement, même si elles sont supprimées ou déplacées sur le site web d'origine.
# # QUESTION 5
#
# Pour collecter des informations complémentaires sur les articles que nous avons extraits des flux RSS, nous pourrions explorer d'autres sources d'information en ligne telles que :
#
# ### 1. **Twitter (ou autres réseaux sociaux)**
#    - **Ce que nous pourrions collecter** :
#      - **Réactions et discussions** autour de l'article, incluant des commentaires et des retweets, qui peuvent fournir un aperçu de la réception publique de l'article ou de l'événement couvert.
#      - **Hashtags et mentions** associés à l'article ou au sujet, afin de suivre l'actualité et voir comment elle évolue sur les réseaux sociaux.
#      - **Auteur de tweets** ou **influenceurs** qui partagent ou commentent l'article, permettant d'étendre la recherche à des points de vue ou des perspectives différentes.
#
#    - **Librairies utiles** :
#      - `Tweepy` ou `TwitterAPI` : Ces bibliothèques Python nous permettent de collecter des tweets en temps réel ou via l'API de recherche, en ciblant des mots-clés, des hashtags, ou des mentions liées à l'article.
#
# ### 2. **Google News API**
#    - **Ce que nous pourrions collecter** :
#      - **Articles similaires** à celui que nous avons récupéré, en utilisant des mots-clés pour rechercher des sources complémentaires et élargir notre compréhension du sujet.
#      - **Tendances d'actualité** sur des sujets liés à l'article pour suivre l'évolution des discussions sur ces thèmes.
#
#    - **Librairies utiles** :
#      - `google-news-python` : Une bibliothèque qui permet de récupérer les dernières nouvelles en temps réel à partir de Google News en fonction des mots-clés ou des catégories d'articles. Cela peut compléter les informations et fournir des perspectives supplémentaires.
#
# ### 3. **YouTube**
#    - **Ce que nous pourrions collecter** :
#      - **Vidéos d'actualité** et analyses liées à l'article, souvent publiées par des journalistes, des blogueurs ou des experts sur des sujets spécifiques.
#      - **Commentaires** des spectateurs qui peuvent offrir des perspectives ou des informations supplémentaires sur le sujet traité dans l'article.
#
#    - **Librairies utiles** :
#      - `google-api-python-client` : Cette bibliothèque permet d’interagir avec l'API YouTube, ce qui permet de récupérer des vidéos, titres, descriptions et commentaires associés à un sujet particulier.
#
# Ces sources et outils nous permettraient d'enrichir les informations collectées à partir des flux RSS en explorant différents types de contenu en ligne, d'avis d'experts, et d'interactions sociales, pour une compréhension plus complète des sujets abordés dans les articles.

# %% [markdown]
# ### Extraction d'informations

# %% [markdown]
# # Question 7
#
# **Étiquettes IOB (Inside, Outside, Beginning) :**
#
# Les étiquettes **IOB** sont un format standard utilisé dans la reconnaissance d'entités nommées (NER, Named Entity Recognition). Ce système permet de structurer les entités en fonction de leur position dans la phrase.
#
# - **I** : **Inside** (à l’intérieur) – Indique qu’un mot fait partie d’une entité nommée, mais qu’il n’est pas au début.
# - **O** : **Outside** (à l’extérieur) – Indique qu’un mot ne fait pas partie d’une entité nommée.
# - **B** : **Beginning** (début) – Indique qu’un mot est le premier de l’entité nommée.
#
# Par exemple, pour une phrase comme « Jean Dupont est maire de Plouguemeur », l'annotation IOB pourrait être :
#
# - Jean (B-PERSON)
# - Dupont (I-PERSON)
# - est (O)
# - maire (O)
# - de (O)
# - Plouguemeur (B-LOC)
#
# Ici, **Jean Dupont** est une entité de type **PERSON**, et **Plouguemeur** est une entité de type **LOC** (lieu).
#
# **Technique de détection des entités nommées :**
#
# La détection des entités nommées (NER) est une tâche de traitement du langage naturel (NLP) qui vise à identifier les entités spécifiques (personnes, lieux, organisations, etc.) dans un texte. Cette tâche est souvent réalisée à l’aide de modèles d'apprentissage automatique ou de réseaux neuronaux, comme ceux utilisés par des bibliothèques populaires telles que **spaCy**.
#
# Voici une explication simplifiée de la technique de détection des entités nommées avec spaCy :
#
# 1. **Entraînement du modèle NER** :
#    - Le modèle est d'abord formé sur un large corpus de textes annotés, où les entités nommées sont identifiées manuellement. Ces annotations incluent les types d'entités (par exemple, **PERSON**, **LOC**, **ORG**) et leur position dans la phrase.
#    - Le modèle apprend à reconnaître des motifs linguistiques et des contextes spécifiques qui indiquent la présence de ces entités dans de nouveaux textes.
#
# 2. **Traitement du texte avec spaCy** :
#    - Une fois le modèle entraîné, on peut l'appliquer à de nouveaux textes. Le modèle scanne le texte et applique des techniques de traitement du langage telles que la **tokenisation** (diviser le texte en mots), l’**étiquetage des parties du discours** (identification de catégories grammaticales) et la **reconnaissance des entités nommées**.
#    - Le modèle analyse le contexte des mots dans le texte et détermine s'ils forment une entité nommée (personne, organisation, lieu, etc.). Si tel est le cas, il les étiquette avec la catégorie appropriée (comme **PERSON**, **LOC**, ou **ORG**).
#
# 3. **Exemple d’application avec spaCy** :
#    - Après avoir chargé le modèle `fr_core_news_md` (un modèle pour le français), nous pouvons l'utiliser pour analyser une phrase.
#    - spaCy attribue des étiquettes IOB aux entités détectées et fournit des informations telles que la position des entités dans le texte (indices de début et de fin).
#
# Cela permet de structurer l’information et de rendre l'extraction d'entités plus précise et plus systématique pour des applications telles que la veille économique, la création de bases de connaissances ou encore le fact-checking.

# %%
new_articles
# Out:
# {'https://www.francetvinfo.fr/france/hauts-de-france/pas-de-calais/pas-de-calais-au-moins-trois-migrants-morts-dans-une-tentative-de-traversee-de-la-manche_6983336.html#xtor=RSS-3-[general]': {'title': 'Pas-de-Calais : au moins trois migrants morts dans une tentative de traversée de la Manche',
#   'date': datetime.datetime(2024, 12, 29, 14, 5, 24, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'Au moins trois migrants sont décédés lors d’une tentative de traversée de la Manche, dimanche 29 décembre au matin, dans le Pas-de-Calais. Ce drame porte à au moins 76 le nombre de migrants décédés cette année dans de telles tentatives.\n\nL’hélicoptère de la marine nationale a repéré une victime : un homme mort noyé en tentant de rejoindre la plage. Vers 6h15 du matin, dimanche 29 décembre, l’alerte a été donnée : une embarcation pneumatique avec une soixantaine de personnes à bord venait de chavirer. Malgré le dispositif de secours, trois personnes sont mortes noyées, 45 ont pu être secourues et mises à l’abri dans un centre nautique, la plupart en état d’hypothermie. Quatre migrants ont été hospitalisés en urgence relative.\n\nUne surcharge du bateau\n\n"C’est un groupe de 50 à 60 personnes qui devaient prendre le bateau et il y a eu un autre groupe qui est venu sur le bateau. Ça a créé une surcharge sur le bateau", raconte une bénévole qui a assisté au naufrage. Une cellule médicale a été mise en place. Les associations aident au transfert des migrants vers des lieux d’accueil. Des hommes et des femmes syriens et soudanais pour la plupart, candidats à la traversée vers l’Angleterre.\n\nRegardez l\'intégralité du reportage dans la vidéo ci-dessus.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/LeTG2-I7UOKl-VG1L1EDpCr_u_I/0x0:1611x906/1500x843/2024/12/29/pas-de-calais-au-moins-trois-migrants-morts-dans-une-tentative-de-traversee-de-la-manche-6771480693283008371031.jpg'},
#  'https://www.francetvinfo.fr/faits-divers/police/marseille-des-policiers-vises-par-des-tirs-cette-nuit-lors-d-une-course-poursuite_6983255.html#xtor=RSS-3-[general]': {'title': "Marseille : des policiers visés par des tirs lors d'une course-poursuite",
#   'date': datetime.datetime(2024, 12, 29, 11, 54, 12, tzinfo=tzoffset(None, 3600)),
#   'author': ['Avec France Bleu Provence'],
#   'category': 'france',
#   'content': 'Aucun des policiers n\'a été blessé et trois personnes ont été interpellées, selon la préfecture de police des Bouches-du-Rhône.\n\nDes policiers de la brigade anti-criminalité (BAC) de Marseille ont essuyé des tirs dans la nuit de samedi 28 à dimanche 29 décembre, lors d\'une course-poursuite, a appris France Bleu Provence de source policière, confirmant une information d\'Actu 17.\n\nAucun d\'entre eux n\'est blessé et trois personnes ont été interpellées, indique une source policière à France Bleu Provence. "Bravo à eux. Leur courage a permis de placer en garde à vue ces criminels armés", écrit la préfecture de police des Bouches-du-Rhône sur le réseau social X.\n\n❌ Cette nuit, les policiers de la BAC de #Marseille repéraient une voiture volée. Dans le véhicule, trois individus prenaient la fuite et tiraient sur les policiers avec une arme longue. Épaulés par des renforts, ils parvenaient à interpeller les auteurs .\n\n\n\nBravo à eux. Leur… — Préfet de police des Bouches-du-Rhône (@prefpolice13) December 29, 2024\n\n"Les policiers de la BAC repéraient une voiture isolée" aux Pennes-Mirabeau, dans la banlieue nord de Marseille, relate la préfecture de police toujours sur X. "Dans le véhicule, trois individus prenaient la fuite" en direction des quartiers nord de Marseille "et tiraient sur les policiers avec une arme longue", poursuit-elle.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/S_LFaatextnd5RiT2oiNAm3r2H8/9x0:1014x565/1500x843/2024/12/29/000-9zn2ug-67712979b46de476871454.jpg'},
#  'https://www.francetvinfo.fr/france/hauts-de-france/pas-de-calais-au-moins-deux-morts-dans-une-tentative-de-traversee-de-la-manche_6983165.html#xtor=RSS-3-[general]': {'title': 'Pas-de-Calais : au moins trois migrants sont morts dans une tentative de traversée de la Manche',
#   'date': datetime.datetime(2024, 12, 29, 9, 55, 33, tzinfo=tzoffset(None, 3600)),
#   'author': ['Avec France Bleu Nord'],
#   'category': 'france',
#   'content': 'Trois personnes sont mortes à Sangatte, dans le Pas-de-Calais, dimanche matin, en tentant la traversée de la Manche.\n\nAu moins trois migrants sont morts, dimanche 29 décembre, vers 6h du matin, en tentant de traverser la Manche, à Sangatte, dans le Pas-de-Calais, selon un bilan encore "provisoire" de la préfecture maritime de la Manche et la mer du Nord et la préfecture du Pas-de-Calais. En parallèle, des opérations de recherche de potentiels naufragés se pousuivent dimanche matin. Une enquête est ouverte par le parquet de Boulogne-sur-Mer.\n\n: à lire aussi Naufrages dans la Manche : comment expliquer le nombre record de migrants morts en 2024 ?\n\nDe nombreuses personnes ont tenté de monter dans une embarcation, vers 6h du matin, à proximité de la plage de Sangatte, relate France Bleu Nord. La préfecture maritime parle "d\'un embarquement chaotique", "avec une cinquantaine de personnes restées dans l\'eau et sur la plage".\n\nAu cours de l\'opération, "45 personnes sont assistées par les secours à terre", selon la préfecture du Pas-de-Calais, dont "quatre personnes en urgence relative" qui ont été transportées dans les centres hospitaliers de Calais et de Boulogne-sur-Mer.\n\nL\'hélicoptère "Dauphin" de la Marine nationale a récupéré "trois personnes inanimées", selon le communiqué. \'\'Les gestes de premiers secours leurs sont immédiatement prodigués" mais "leur décès est constaté par les équipes du Smur". Le maire de Sangatte Guy Allemand s\'est rendu sur place.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/bOvDeqyhkZ52GxKATyncPCEmkno/0x18:1024x594/1500x843/2024/12/29/000-36pe8vh-67710df672305354647749.jpg'},
#  'https://www.francetvinfo.fr/monde/environnement/video-trier-ses-dechets-est-il-vraiment-utile_6979421.html#xtor=RSS-3-[general]': {'title': 'VIDÉO. Trier ses déchets est-il vraiment utile\xa0?',
#   'date': datetime.datetime(2024, 12, 27, 15, 2, 16, tzinfo=tzoffset(None, 3600)),
#   'author': ['Thomas Destelle'],
#   'category': 'france',
#   'content': 'Visite d\'un centre de tri parisien qui réceptionne le contenu des poubelles jaunes. Après avoir été jetés, ces emballages notamment en acier, plastique ou carton, vont être séparés par types de matériaux, et rejoignons par la suite les filières de recyclage.\n\nVisite d\'un centre de tri parisien qui réceptionne le contenu des poubelles jaunes. Après avoir été jetés, ces emballages notamment en acier, plastique ou carton, vont être séparés par type de matériaux, et rejoindront par la suite les filières de recyclage.\n\n"Tout part à l\'incinérateur !" Pour certains, faire l\'effort de trier ne sert à rien car la destination finale de tous les déchets serait identique. Qu\'en est-il vraiment ? Que deviennent nos déchets mis dans la poubelle jaune ?\n\nDans la capitale, c\'est le Syctom qui s\'occupe de traiter les ordures ménagères pour six millions d\'habitants et 82 communes. Ce service public a en charge le traitement des ordures ménagères. L\'agence métropolitaine traite chaque année deux millions de tonnes d\'ordures ménagère par an.\n\nUne partie des déchets récupérés par les poubelles jaunes parisiennes se retrouve dans le 15e arrondissement, en bordure du périphérique, au centre de tri de Paris XV. C\'est le premier centre de tri intramuros du Syctom, qui traite chaque année 35 000 tonnes d\'ordures : cela représente une cinquantaine de camions par jour, chargés d\'emballages, de papier, de carton et de plastique.\n\nUn tri selon la composition\n\nDès le déchargement, on constate les premières erreurs de tri : notamment des sacs-poubelle noirs fermés, qui n\'ont rien à faire dans la poubelle jaune. "On ne sait pas ce qu\'il y a dedans et s\'il est fermé les opérateurs ne vont pas s\'amuser à déchirer chacun des sacs pour trier et surtrier le contenu", explique Sofien Elandaloussi, directeur partenariat et mobilisation des publics au Syctom.\n\n: à lire aussi Recyclage : des amendes pour les déchets mal triés ?\n\nLes déchets vont ensuite dans un trommel, un grand tambour incliné, qui sépare les déchets selon leur taille. Les déchets se retrouvent sur des tapis roulants et vont être triés selon leur composition. Les emballages en acier sont récupérés grâce à des aimants. Pour le plastique, des trieurs optiques interviennent et séparent par exemple selon la couleur. En fin de circuit, des agents font une dernière sélection pour éviter les erreurs de tri. "Les opérateurs affinent le tri qui a été fait par les machines et les éléments techniques en amont. On ne peut pas faire sans ce dernier regard", indique Sofien Elandaloussi. Pour la dernière étape, les déchets sont mis en balles, c\'est-à-dire qu\'ils sont compactés en carrés d\'un mètre sur un mètre, pour être vendus.\n\nSelon l\'Ademe, notre poubelle d\'ordures ménagères contient encore 35% de déchets recyclables, dont une grande part d\'emballages plastiques. Pour encourager le tri, les consignes de tri ont donc été simplifiées : tous les emballages sans exception iront dans le bac de tri. "On ne cherche pas à savoir de quelle matière c\'est fait, quand on a un emballage on le trie", rappelle Sofien Elandaloussi.\n\nUne nécessité pour simplifier et augmenter le tri des déchets car seulement 29% des 1,1 million de tonnes d\'emballages en plastique mises sur le marché chaque année en France sont recyclés, selon Citeo.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/Lw8uszQGJqWUFLP9zeDCukXha6w/0x312:3000x1999/1500x843/2024/12/27/poubelles-thomas-d-676e884b4c5e7582582817.jpg'},
#  'https://www.francetvinfo.fr/monde/europe/migrants/au-moins-trois-migrants-sont-morts-dans-le-pas-de-calais-lors-d-une-tentative-de-traversee-de-la-manche_6983171.html#xtor=RSS-3-[general]': {'title': 'Pas-de-Calais : au moins trois migrants sont morts dans une tentative de traversée de la Manche',
#   'date': datetime.datetime(2024, 12, 29, 9, 55, 33, tzinfo=tzoffset(None, 3600)),
#   'author': ['Avec France Bleu Nord'],
#   'category': 'europe',
#   'content': 'Trois personnes sont mortes à Sangatte, dans le Pas-de-Calais, dimanche matin, en tentant la traversée de la Manche.\n\nAu moins trois migrants sont morts, dimanche 29 décembre, vers 6h du matin, en tentant de traverser la Manche, à Sangatte, dans le Pas-de-Calais, selon un bilan encore "provisoire" de la préfecture maritime de la Manche et la mer du Nord et la préfecture du Pas-de-Calais. En parallèle, des opérations de recherche de potentiels naufragés se pousuivent dimanche matin. Une enquête est ouverte par le parquet de Boulogne-sur-Mer.\n\n: à lire aussi Naufrages dans la Manche : comment expliquer le nombre record de migrants morts en 2024 ?\n\nDe nombreuses personnes ont tenté de monter dans une embarcation, vers 6h du matin, à proximité de la plage de Sangatte, relate France Bleu Nord. La préfecture maritime parle "d\'un embarquement chaotique", "avec une cinquantaine de personnes restées dans l\'eau et sur la plage".\n\nAu cours de l\'opération, "45 personnes sont assistées par les secours à terre", selon la préfecture du Pas-de-Calais, dont "quatre personnes en urgence relative" qui ont été transportées dans les centres hospitaliers de Calais et de Boulogne-sur-Mer.\n\nL\'hélicoptère "Dauphin" de la Marine nationale a récupéré "trois personnes inanimées", selon le communiqué. \'\'Les gestes de premiers secours leurs sont immédiatement prodigués" mais "leur décès est constaté par les équipes du Smur". Le maire de Sangatte Guy Allemand s\'est rendu sur place.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/bOvDeqyhkZ52GxKATyncPCEmkno/0x18:1024x594/1500x843/2024/12/29/000-36pe8vh-67710df672305354647749.jpg'},
#  'https://www.francetvinfo.fr/replay-radio/le-journal-des-outre-mers/mayotte-toujours-dans-la-detresse-15-jours-apres-le-passage-du-cyclone-chido_6960071.html#xtor=RSS-3-[general]': {'title': 'Mayotte toujours dans la détresse, 15 jours après le passage du cyclone Chido',
#   'date': datetime.datetime(2024, 12, 29, 10, 55, 27, tzinfo=tzoffset(None, 3600)),
#   'author': ['Outre-Mer La'],
#   'category': 'france',
#   'content': 'Le journal des outremers Le dimanche à 11h25, 16h25 et 21h55.\n\nLe Premier ministre François Bayrou se rend à Mayotte avec cinq ministres de son gouvernement, dont Manuel Valls, le ministre des Outre-mer, demain lundi 30 décembre. Le défi est colossal pour les Mahorais privés encore de tout pour certains, et également pour les entreprises locales, notamment les PME.\n\nLe Premier ministre François Bayrou sera à Mayotte demain lundi 30 décembre. Il vient accompagné de cinq ministres de son gouvernement. Mayotte, dévastée par le cyclone Chido, il y a tout juste 15 jours. Le bilan reste encore incertain. Il fait état de plusieurs dizaines de morts et 4000 blessés.\n\nUn hôpital de campagne accueille désormais une centaine de patients par jour. Mayotte où se multiplient aussi les initiatives personnelles. En Petite-Terre, un restaurant solidaire prépare des repas qu’il distribue aux sinistrés. Reportage dans le quartier de la Vigie, ou se trouvait un bidonville avant le passage du cyclone. Yvana Navion de Mayotte la 1ere.\n\nUn homme retrouvé mort en Martinique, il était séquestré depuis 32 ans\n\nEn Martinique, un homme d’une quarantaine d’années qui souffrait de graves troubles neurologiques, a été retrouvé mort au domicile de sa mère. Il y vivait séquestré dans une chambre depuis 32 ans, la plupart du temps attaché. Les voisins étaient au courant, mais personne n’avait alerté les services sociaux. La réaction de Patricia Telle, la maire de Trinité, où le drame s’est déroulé. Propos recueillis par Mike Irasque de Martinique la 1ere.\n\nUne enquête a été ouverte pour "séquestration ayant entraîné la mort". La mère de la victime, âgée de 80 ans a été mise en examen et placée sous contrôle judiciaire\n\nLe congrès de Nouvelle-Calédonie doit élire un nouveau gouvernement le 7 janvier prochain\n\nLe précédent a été renversé mardi dernier, par le groupe "Calédonie ensemble". C’était le premier gouvernement dirigé par un élu indépendantiste, Louis Mapou. Un nouvel épisode institutionnel dans un territoire secoué par une grave crise sociale et économique depuis six mois.\n\nA Tahiti, une histoire qui booste un commerce de yaourt, grâce aux réseaux sociaux\n\nA Tahiti, pour booster ses ventes de yaourt, la propriétaire d’une laiterie a créé un personnage fictif, Tehau, joué par elle-même et qu’elle fait vivre sur les réseaux sociaux. Résultat, ses vidéos cartonnent et son commerce est florissant. Un reportage de Raihei Nadjarian, Polynésie la 1ere.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/F2N6vnfPbEqb1Weyzx96-ZSagXs/0x22:930x547/1500x843/2024/12/28/capture-d-ecran-2024-12-27-a-19-44-02-676eccf58c181026089231-67701d6040d1c791668245.jpg'},
#  'https://www.francetvinfo.fr/replay-radio/8h30-fauvelle-dely/francois-bayrou-a-mayotte-mieux-vaut-tard-que-jamais-estime-laurent-jacobelli-porte-parole-du-rn-qui-reclame-des-mesures-de-fond_6960050.html#xtor=RSS-3-[general]': {'title': 'François Bayrou à Mayotte : "Mieux vaut tard que jamais", estime Laurent Jacobelli, porte-parole du RN, qui réclame des "mesures de fond"',
#   'date': datetime.datetime(2024, 12, 29, 10, 44, 27, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'Laurent Jacobelli, porte-parole du RN et député de Moselle, était l’invité du "8h30 franceinfo", dimanche 29 décembre. Il répondait aux questions de Benjamin Fontaine.\n\nFrançois Bayrou à Mayotte : "Mieux vaut tard que jamais"\n\nAprès le passage du cyclone Chido, le Premier ministre François Bayrou est attendu lundi 30 décembre à Mayotte. "Mieux vaut tard que jamais", réagit dimanche sur franceinfo Laurent Jacobelli, porte-parole du Rassemblement national. "Les premiers signaux n\'étaient pas forcément les bons de la part du Premier ministre" comme notamment "s\'occuper de la mairie de Pau", critique le député RN de Moselle. "Il faut des mesures de fond pour Mayotte", "des mesures d\'urgence pour ce petit bout de France", enchaîne Laurent Jacobelli qui souhaite "mettre tout en place pour les aider" en matière de nourriture, en matière sanitaire et en matière d\'immigration "pour l\'avenir".\n\n"50% d\'étrangers sur l\'île, c\'est plus possible", estime ainsi le porte-parole du RN qui veut supprimer le droit du sol. Le député de Moselle veut "en finir avec les bidonvilles" et "aider les constructions solides" et "mettre en place enfin des systèmes de distribution d\'eau dignes de ce nom", "même hors période de cyclone". "Mayotte mérite d\'être mieux traitée", résume Laurent Jacobelli, "à la hauteur de l\'engagement de ceux qui ont choisi d\'être Français".\n\nGérald Darmanin "annonce beaucoup de choses et ne fait rien"\n\n"C\'est la méthode Darmanin : j\'annonce beaucoup de choses et je ne fais rien", a étrillé ce dimanche sur franceinfo le député Rassemblement national Laurent Jacobelli, alors que le nouveau ministre de la Justice s\'est dit favorable à un isolement renforcé en détention "des 100 plus grands narcotrafiquants", dans un entretien publié dans Le Parisien.\n\n"Quand j\'entends le nom Darmanin, il y a un mot qui me vient à l\'esprit c\'est bonimenteur", a poursuivi le porte-parole du RN. Pour Laurent Jacobelli, "Monsieur Darmanin, c\'est l\'échec au ministère de l\'Intérieur" et "on ne voit pas bien ce qui réussirait dans un ministère alors qu\'il l\'a raté dans l\'autre". L\'élu mosellan a tiré à boulets rouges sur le bilan de l\'ex-locataire de la place Beauvau : "Darmanin, c\'est l\'échec de la sécurité, c\'est l\'échec de l\'immigration, c\'est l\'échec des OQTF". "Avec Gérald Darmanin, il y a eu 60% de narchomicides ou tentatives d\'homicides supplémentaires, avec Darmanin, c\'est 50% des indicateurs de sécurité qui se sont aggravés", a-t-il ajouté.\n\nNommé garde des Sceaux lundi soir, Gérald Darmanin a déjà dit vouloir "nettoyer les prisons" de leurs nombreuses difficultés. Il souhaite notamment la construction de nouvelles prisons pour l\'exécution des peines de "quelques mois, semaines, voire jours". Une proposition qui a le soutien du RN. "Quand un gamin de 15 ans est attrapé en train de faire un trafic de drogue, même si c\'est la première fois, il lui faut une peine courte. Et ça veut dire des centres de rétention adaptés, adaptés à la minorité et adaptés aux petits délits", a expliqué le député RN. "Monsieur Darmanin sait lire le programme du Rassemblement national", a-t-il ironisé. "J\'ai un conseil à lui donner : laissez-nous la place, nous, on fera le boulot", a ajouté Laurent Jacobelli.\n\nFiscalité : "Nous sommes un pays surendetté"\n\nConcernant la fiscalité, Laurent Jacobelli, député de Moselle, assure que "si on parle d\'impôts sur les surprofits exceptionnels, si on parle d\'impôts sur le rachat d\'actions qui sont des actions non productives et qui peuvent servir l\'économie, pourquoi pas. Mais si on parle du matraquage fiscal dans lequel on nous a habitué pendant des années, c\'est évidemment non". "Aujourd\'hui on travaille pratiquement un jour sur deux pour l\'État, nous sommes le pays le plus taxé de l\'OCDE, nous sommes un pays surendetté".',
#   'image_link': 'https://www.francetvinfo.fr/pictures/eZVlaGem_U4q1-74pLlRDH2BPdA/0x0:1024x576/1500x843/2024/12/29/untitled-10-6771026154906411118622.jpg'},
#  'https://www.francetvinfo.fr/politique/francois-bayrou/francois-bayrou-attendu-lundi-a-mayotte_6983180.html#xtor=RSS-3-[general]': {'title': 'François Bayrou attendu lundi à Mayotte',
#   'date': datetime.datetime(2024, 12, 29, 10, 10, 44, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': "Le Premier ministre se rendra dans le département ultramarin lundi 30 décembre. Un premier déplacement officiel attendu de pied ferme après la polémique sur sa participation en visioconférence à la cellule de crise consacrée à Mayotte, le 16 décembre dernier.\n\nLe Premier ministre se rendra dans le département ultramarin lundi 30 décembre. Un premier déplacement officiel attendu de pied ferme après la polémique sur sa participation en visioconférence à la cellule de crise consacrée à Mayotte, le 16 décembre dernier.\n\nAvec François Bayrou, c’est toute une délégation ministérielle qui se rendra à Mayotte. Un déplacement sous le signe de la reconstruction où Manuel Valls, ministre des Outre-Mer, Valérie Létard, ministre du Logement et de la Rénovation urbaine et Yannick Neuder, ministre de la Santé, se rendront aussi sur l’île.\n\nLa colère gronde encore chez les habitants\n\n“On est venu pour se soigner et demander de l’aide”, déclare une sinistrée. “Il faut que les gens voient, viennent pour nous aider”, ajoute-t-elle. Sur place, l’annonce de la venue de François Bayrou suscite la colère chez certains collectifs citoyens qui demandent davantage d’aides humanitaires : “les aides annoncées par rapport au secours, sont insuffisantes. On est toujours là à courir derrière une bouteille d’eau, de la nourriture”, exhorte Sylviane Amavi, porte-parole du collectif des citoyens de Mayotte. Deux semaines après le passage du cyclone Chido, plus de la moitié des foyers de l’île sont toujours privés d’électricité.\n\nRegardez l'intégralité du reportage dans la vidéo ci-dessus.",
#   'image_link': 'https://www.francetvinfo.fr/pictures/KTybXDpflOy5Vp117z-P8r0SScM/198x0:1722x857/1500x843/2024/12/29/f-bayrou-attendu-lundi-a-mayotte-67711158ea16c824073248.jpg'},
#  'https://www.francetvinfo.fr/societe/drogue/tahiti-une-demi-tonne-de-cocaine-saisie-sur-un-navire-espagnol_6983177.html#xtor=RSS-3-[general]': {'title': 'Une demi-tonne de cocaïne saisie au large de Tahiti sur un navire espagnol',
#   'date': datetime.datetime(2024, 12, 29, 10, 17, 49, tzinfo=tzoffset(None, 3600)),
#   'author': ['Franceinfo Avec Afp'],
#   'category': 'france',
#   'content': "Un peu plus de 500 kg de cocaïne ainsi que 8 000 euros en espèce ont été saisis à bord d'un navire espagnol à Tahiti lundi 23 décembre, a appris l'AFP six jours plus tard auprès de la gendarmerie nationale. Le 23 décembre, le Bougainville, bâtiment de soutien et d'assistance outre-mer (BSAOM) de la marine nationale, a arraisonné le Raymi, un navire de pêche battant pavillon espagnol, au sud de la zone économique exclusive (ZEE) de Polynésie française.\n\nSur ce bateau, la marine nationale a découvert onze ballots, contenant 524 kg de cocaïne, a détaillé la gendarmerie à l'AFP. Les 14 membres d'équipage ont été interpellés, a-t-elle ajouté. L'opération a été menée grâce à une coopération internationale, impliquant le commandement de la Gendarmerie pour la Polynésie française, notamment l'antenne de l'Office anti-stupéfiants (OFAST) à Papeete, et la police fédérale australienne. Le Raymi, escorté par le Bougainville, est arrivé à Papeete samedi en début de matinée, a précisé encore la gendarmerie. Une enquête a été ouverte sous l'autorité du parquet de Papeete.",
#   'image_link': 'https://www.francetvinfo.fr/pictures/FvOlGEL5h2HFx5U4IyP2CaN5wso/0x74:1024x649/1500x843/2024/12/29/000-364n7vj-677113443827d690293145.jpg'},
#  'https://www.francetvinfo.fr/meteo/neige/avalanches/savoie-une-skieuse-de-44-ans-meurt-emportee-par-une-avalanche_6982058.html#xtor=RSS-3-[general]': {'title': 'Savoie : une skieuse de 44 ans meurt emportée par une avalanche',
#   'date': datetime.datetime(2024, 12, 28, 23, 17, 42, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': "Samedi 28 décembre, une skieuse est décédée sur le domaine skiable de La Norma, en Savoie. La femme de 44 ans a été emportée par une coulée de neige alors qu'elle évoluait hors-piste avec deux autres personnes. Depuis mardi, le risque d'avalanche est évalué à 3 sur 5.\n\nSur des images diffusées par le PGHM de Savoie, on peut encore discerner les traces de l’avalanche à plus de 2 500 m d’altitude, qui a emporté la skieuse sur plusieurs centaines de mètres en fin de matinée, samedi 28 décembre. Un quart d’heure après le drame, les secouristes sont arrivés sur place, mais il était déjà trop tard.\n\nDeux skieurs morts en une semaine\n\nUn hélicoptère du Peloton de gendarmerie de haute montagne (PGHM) est arrivé très vite sur place, au Vallon du Ruisseau Saint-Antoine, non loin du domaine skiable de La Norma. Accompagnée de son mari et d’une troisième personne, la victime, qui habitait la région, n’était pas équipée d’un détecteur de victime d’avalanche. Le maire de la commune se dit sous le choc. Cette semaine, en Savoie, un jeune skieur de 13 ans a perdu la vie dans une avalanche.\n\nRetrouvez l'intégralité du reportage dans la vidéo ci-dessus",
#   'image_link': 'https://www.francetvinfo.fr/pictures/jptxLRuXQOZOCN9rbd8CutR2PCM/171x0:1435x711/1500x843/2024/12/28/savoie-une-skieuse-de-44-ans-meurt-emportee-par-une-avalanche-677078d2e2367190713157.png'},
#  'https://www.francetvinfo.fr/france/mayotte/mayotte-comment-rouvrir-au-plus-tot-les-ecoles_6981980.html#xtor=RSS-3-[general]': {'title': 'Mayotte : comment rouvrir au plus tôt les écoles ?',
#   'date': datetime.datetime(2024, 12, 28, 21, 39, 31, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'Deux semaines après le passage du cyclone Chido à Mayotte, des bénévoles œuvrent à la reconstruction des écoles détruites. Malgré leurs efforts, une rentrée des classes dans un avenir proche semble impossible.\n\nCharpentiers, architectes, professionnels du bâtiment se sont donné rendez-vous tôt ce matin. La mission de ces bénévoles est simple : faire le tour des écoles afin de constater les dégâts et de commencer à reconstruire. “Les dégâts sont impressionnants et même terribles… On essaye d’aider au maximum”, déclare Stéphane Aimé, architecte bénévole. Le chantier est colossal, près de la moitié des établissements scolaires de Mayotte ont été endommagés par le cyclone tandis que d’autres servent de refuges aux sinistrés.\n\nUn risque de décrochage scolaire\n\nAprès avoir perdu son toit lors du cyclone, une institutrice n’y croit pas et n’a plus la force de rester. Elle est sous le choc, son logement est complètement détruit. Comme des centaines d’autres professeurs, elle a demandé à être évacuée. "On a cru qu’on allait mourir, on a envie de rentrer en métropole pour se ressourcer un peu auprès de nos familles", confie-t-elle. Sur place, on ne sait toujours pas quand les cours pourront reprendre. Camille Mercier a décidé d’anticiper et de reprendre le travail à sa façon. L’enseignante distribue des exercices afin d’éviter le décrochage et garder un lien avec ses élèves.\n\nRegardez l\'intégralité du reportage dans la vidéo ci-dessus.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/lY82nFmq0rbdSCtkMsQOsSt6-Y4/0x0:1651x928/1500x843/2024/12/28/mayotte-comment-rouvrir-au-plus-tot-les-ecoles-67706179ce5dd636998961.png'},
#  'https://www.francetvinfo.fr/faits-divers/savoie-une-skieuse-de-44-ans-meurt-dans-une-avalanche_6981953.html#xtor=RSS-3-[general]': {'title': 'Savoie : une skieuse de 44 ans meurt dans une avalanche',
#   'date': datetime.datetime(2024, 12, 28, 20, 24, 32, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'En Savoie, une skieuse de 44 ans est décédée samedi 28 décembre, emportée par une avalanche dans la station de la Norma. Elle skiait dans un secteur hors-piste avec deux autres personnes.\n\nEn Savoie, une skieuse de 44 ans est décédée samedi 28 décembre, emportée par une avalanche dans la station de la Norma. Elle skiait dans un secteur hors-piste avec deux autres personnes.\n\nSur les images, on peut encore discerner les traces de l’avalanche à plus de 2 500 m d’altitude. Une coulée de neige a entraîné la skieuse le 28 décembre en fin de matinée. Un quart d’heure après le drame, les secouristes sont arrivés sur place, mais il était déjà trop tard. "Il a fallu 50 minutes pour découvrir la personne qui était sous la neige. Lorsqu\'elle a été découverte et sortie, malheureusement, elle a succombé à ses blessures", raconte un secouriste.\n\nLa victime habitait la région\n\nUn hélicoptère du Peloton de gendarmerie de haute montagne (PGHM) est arrivé très vite sur place, au Vallon du Ruisseau Saint-Antoine, non loin du domaine skiable de la Norma. Accompagnée de son mari et d’une troisième personne, la victime, qui habitait la région, n’était pas équipée d’un détecteur de victime d’avalanche.\n\nRegardez l\'intégralité du reportage dans la vidéo ci-dessus.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/serWIA0ezg6oq021uA_py0nuZGQ/0x0:1920x1080/1500x843/2024/12/28/savoie-une-skieuse-de-44-ans-meurt-dans-une-avalanche-67704fb02be72978739243.jpg'},
#  'https://www.francetvinfo.fr/monde/nouvel-an-2025/sciences-sport-animaux-culture-espace-on-a-trouve-24-bonnes-nouvelles-que-nous-laisse-l-annee-2024_6952952.html#xtor=RSS-3-[general]': {'title': "Sciences, sport, animaux, culture, espace... On a trouvé 24 bonnes nouvelles que nous laisse l'année 2024",
#   'date': datetime.datetime(2024, 12, 28, 7, 13, 30, tzinfo=tzoffset(None, 3600)),
#   'author': ['Pierre Godon'],
#   'category': 'france',
#   'content': 'Champions du monde du pessimisme, les Européens ? C\'était la thèse de l\'ancien président de la Commission européenne José Manuel Barroso, pointant le ratio très élevé de Français, Belges ou Italiens qui voient l\'avenir uniquement en teintes grises. Et pourtant, franceinfo vous a déniché 24 bonnes nouvelles à retenir de l\'année qui se termine, dans des domaines aussi variés que les sciences, l\'environnement, la société, l\'actualité internationale, le sport ou la culture.\n\n1 Les Jeux olympiques à Paris, LA bonne nouvelle qui a marqué l\'année\n\nUne mascotte Phryge des Jeux de Paris 2024 salue un jeune spectateur du match de handball Croatie-Japon, à l\'Arena Paris Sud de la porte de Versailles, le 27 juillet 2024. (CHRISTIAN PETERSEN / GETTY IMAGES EUROPE)\n\nOn craignait le pire, tout s\'est bien passé (à part la météo détestable pour plusieurs des cérémonies). Les athlètes français ont glané des dizaines de médailles, les supporters français ont eu la banane pendant six semaines, les Phryges sont devenues des icônes nationales (y compris le modèle paralympique, ce qui traduit une nette évolution par rapport aux Jeux précédents), les transports ont fonctionné sans accrocs et les oiseaux de mauvais augure ont eu tout faux. On aurait pu consacrer 12 paragraphes au succès des Jeux (qui ont même fini avec un excédent budgétaire pour la partie organisationnelle) mais on va se limiter à un.\n\n2 Il est (re)venu le temps des cathédrales\n\nLa façade illuminée de Notre-Dame de Paris remercie les pompiers et artisans qui ont sauvé la cathédrale, le 7 décembre 2024. (FRANCE TELEVISIONS)\n\nCinq ans (et quelques mois) après l\'incendie qui a ravagé Notre-Dame de Paris, la cathédrale a rouvert ses portes en mondovision et en grande pompe, début décembre. Et le résultat architectural est bluffant (à une polémique sur les vitraux près), au point que le diocèse de Paris anticipe une hausse des visites de 30% pour atteindre 15 millions de visiteurs en 2025. Pour réserver votre place, c\'est par là.\n\n3 La "comète du siècle" a illuminé nos soirées\n\nMême si le soleil s\'est fait assez discret en fin d\'année, il a su revenir à temps pour dévoiler la comète C/2023 A3 Tsuchinshan-Atlas, surnommée la "comète du siècle" en octobre. Un formidable phénomène observable pendant une dizaine de jours, même pour ceux qui n\'étaient pas équipés d\'un téléscope dernier cri. Et pour ceux coincés sous la grisaille, le spectacle était aussi sur les réseaux sociaux.\n\nVoir cette publication sur Instagram Une publication partagée par Nicolas Escurat (@nicolas_escurat)\n\n4 Miss France 2025 a été sacrée à 34 ans, un nouveau record\n\nEn France, on n\'est pas allé jusqu\'à imiter les Pays-Bas, qui ont arrêté leur concours de beauté national, jugé "d\'un autre temps", mais les organisateurs ont fait de gros efforts pour le remettre au goût du jour. La fameuse limite d\'âge a ainsi volé en éclats et c\'est Angélique Angarni-Filopon, Miss Martinique et âgée de 34 ans, qui a été sacrée le 14 décembre, pulvérisant le record de la lauréate la plus âgée. Elle a célébré sa victoire avec cette phrase forte : "Au nom de toutes les femmes à qui on a dit \'c\'est trop tard\'."\n\nLa gagnante du concours Miss France 2025, la Martiniquaise Angélique Angarni-Filopon, au Futuroscope de Poitiers, à Chasseneuil-du-Poitou (Vienne), le 15 décembre 2024. (ROMAIN PERROCHEAU / AFP)\n\n5 Un chargeur unique pour les téléphones est adopté en Europe\n\n"Tu n\'aurais pas un chargeur d\'iPhone ?" figure dans le top 5 des phrases régulièrement entendues à la rédaction de franceinfo.fr. Mais ce sera bientôt de l\'histoire ancienne, car le fameux chargeur universel européen devient obligatoire à partir de samedi 28 décembre. Bon, pas sûr que les étourdis qui oubliaient leur chargeur avant l\'entrée en vigueur de la mesure décidée par la Commission européenne changent radicalement, mais au moins ils trouveront plus facilement une bonne âme pour leur en prêter un.\n\n6 On ...
#   'image_link': 'https://www.francetvinfo.fr/pictures/gfSoUndt7Zm4atZhRyan7R8qOC4/0x0:1411x794/1500x843/2024/12/20/24-676544309b6aa664025717.png'},
#  'https://www.francetvinfo.fr/france/nouvelle-aquitaine/landes/landes-six-opposants-au-chantier-de-la-ligne-a-tres-haute-tension-installes-dans-des-arbres-a-capbreton-une-demande-de-moratoire-envoyee-au-premier-ministre_6981572.html#xtor=RSS-3-[general]': {'title': 'Landes : six opposants au chantier de la ligne à très haute tension installés dans des arbres à Capbreton, une demande de moratoire envoyée au Premier ministre',
#   'date': datetime.datetime(2024, 12, 28, 10, 45, 42, tzinfo=tzoffset(None, 3600)),
#   'author': ['Avec France Bleu Gascogne'],
#   'category': 'france',
#   'content': 'Les opposants à ce projet dénoncent des concéquences "désastreuses du tracé" de la ligne à très haute tension.\n\nSix militants sont installés dans des platanes, depuis jeudi 26 décembre, devant la mairie de Capbreton, selon France Bleu Gascogne, pour protester contre le chantier de la ligne à très haute tension (THT) de 400 000 volts entre la France et l\'Espagne.\n\nInspirée des actions contre le chantier de l’A69 dans le Tarn, cette mobilisation est menée par des "grimpeurs et grimpeuses aquitains", ajoute France Bleu Gascogne. L’action est coordonnée par le mouvement écologiste Extinction Rebellion.\n\nUne action d\'une "durée indéterminée"\n\nLes militants, qui se relaient, sont munis de cordes, hamacs, tentes et banderoles, et se préparent à un "campement pour une durée indéterminée", a appris l\'Agence Radio France auprès de l\'association Landes Aquitaine Environnement. "Les gendarmes sont présents épisodiquement en observateurs", ajoute sa présidente.\n\nUne quarantaine d\'organisations (Collectif de grimpeurs et grimpeuses d\'Aquitaine, Attac Aquitaine, XR Landes, Soulèvement de la Terre Aquitaine, Collectif Stop THT 40 ...) opposées au tracé actuel de la ligne THT, mais pas au projet, ont adressé, vendredi, un courrier à François Bayrou, le Premier ministre.\n\nElles demandent un "moratoire immédiat" alertant sur les conséquences "désastreuses du tracé de ce projet", "un tracé écocidaire non validé par le Conseil national de la protection de la nature, les seuls experts scientifiques et techniques intervenus dans ce dossier".',
#   'image_link': 'https://www.francetvinfo.fr/pictures/IenRzMY9cBmkG8I-HavbpYRXWno/0x45:1024x621/1500x843/2024/12/28/manifestation-du-18-novembre-capbreton-plage-des-oceanides-contre-la-ligne-tres-haute-tension-qui-doit-passer-sous-terre-entre-seignosse-et-capbreton-geant-cable-qui-le-reste-du-trace-est-sous-marin-entre-l-676fc8199554d669023838.jpg'},
#  'https://www.francetvinfo.fr/france/mayotte/mayotte-apres-le-cyclone-des-ecoles-pillees-et-vandalisees_6979952.html#xtor=RSS-3-[general]': {'title': '"Ils ont volé les tables, les chaises" : après le passage du cyclone Chido à Mayotte, des écoles pillées et vandalisées',
#   'date': datetime.datetime(2024, 12, 27, 21, 37, 31, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'Après le passage du cyclone Chido, les Mahorais font face à des actes de pillages et de vandalisme. À Mamoudzou, des écoles ayant accueilli des sinistrés ont été prises pour cibles.\n\nAprès le passage du cyclone Chido, un nouveau coup dur pour les Mahorais. Plusieurs écoles publiques ont été pillées et vandalisées. À Mamoudzou, un directeur d\'un établissement a encore du mal à réaliser. Chaque soir, des personnes viennent là-bas se servir allègrement.\n\n"Dans cette salle, ils ont volé les tables, les chaises, le matériel pédagogique des enfants", fait-il savoir. Même le bureau de son adjoint a été cambriolé. Les voleurs sont entrés par le toit qui avait été éventré. "Ils ont volé l\'écran qui était là. Il y avait un micro-ondes qui était là également", déclare-t-il.\n\nReconstruire les maisons\n\nDans la ville, 14 autres écoles ont été pillées depuis Chido. Les voleurs viennent des quartiers défavorisés. Des jeunes hommes nous ont confirmé que certains habitants venaient se servir dans les écoles pour reconstruire leurs maisons. "Ils prennent tout ce qui peut leur servir pour créer leur maison", dit-il. À Mayotte, les cambriolages datent d\'avant le cyclone, mais il les a rendus plus faciles.\n\nRegardez l\'intégralité du reportage dans la vidéo ci-dessus.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/UAy929gnqKIxU3YTla2G82nqSM4/0x35:1607x941/1500x843/2024/12/27/mayotte-des-ecoles-pillees-et-vandalisees-676f0f71f06bc223949293.jpg'},
#  'https://www.francetvinfo.fr/culture/culture-des-baisses-de-dotation-partout-en-france_6981515.html#xtor=RSS-3-[general]': {'title': 'Culture, des baisses de dotation partout en France',
#   'date': datetime.datetime(2024, 12, 28, 8, 39, 22, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'La culture est-elle en danger ? En 2025, de nombreux régions françaises ont décidé de réduire le budget alloué à la Culture. Selon les acteurs culturels, cette décision met en danger le secteur, dont la méditation culturelle qui a permis la réinsertion de nombreuses personnes.\n\nLa culture est-elle en danger ? En 2025, de nombreux régions françaises ont décidé de réduire le budget alloué à la Culture. Selon les acteurs culturels, cette décision met en danger le secteur, dont la méditation culturelle qui a permis la réinsertion de nombreuses personnes.\n\nPlus qu’une coupe, c’est une amputation sévère dans le budget de la Culture que la présidente de la région Pays de la Loire a fait voter la semaine dernière : moins 62% de dotation pour 2025. Une annonce brutale aux lourdes conséquences selon Aymeric Seassau, adjoint à la maire de Nantes et délégué à la culture : "Les impacts vont être très nombreux dans le spectacle vivant notamment. Mais je pense aussi à l’événementiel cinéma qui pourrait être très touché. On estime pour la seule ville de Nantes à plus de trois millions d’euros le manque à gagner pour les acteurs culturels nantais."\n\nLa médiation culturelle en danger\n\nEt la région Pays de la Loire n’est pas la seule à sacrifier son budget culture : moins 27% en Île-de-France et entre moins 5 à 10% en Provence-Alpes-Côte d’Azur. Des restrictions qui auront des impacts directs sur les emplois et les structures mais aussi sur une donnée moins quantifiable : la médiation culturelle.\n\nRegardez l\'intégralité du reportage dans la vidéo ci-dessus.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/VuPeMrhNelETnFVG5wWO1Tc2kp8/198x0:1722x857/1500x843/2024/12/28/culture-des-baisses-de-dotation-partout-en-france-676fa96530903846954211.jpg'},
#  'https://www.francetvinfo.fr/meteo/cyclone-ouragan/cyclone-chido-a-mayotte/mayotte-le-pillage-nouveau-defi-de-securite_6981494.html#xtor=RSS-3-[general]': {'title': 'Mayotte : le pillage, nouveau défi de sécurité',
#   'date': datetime.datetime(2024, 12, 28, 8, 3, 21, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': 'Alors que les Mahorais ont tout perdu à cause du cyclone Chido, ils sont maintenant confrontés à des actes de pillages et de vandalisme. À Mamoudzou, par exemple, des écoles ayant accueilli des sinistrés se font voler leur matériel.\n\nAlors que les Mahorais ont tout perdu à cause du cyclone Chido, ils sont maintenant confrontés à des actes de pillages et de vandalisme. À Mamoudzou, par exemple, des écoles ayant accueilli des sinistrés se font voler leur matériel.\n\nEntre le manque d\'eau, l\'absence de réseau électrique et l\'aide alimentaire non conforme, les Mahorais ne sont pas au vout de leur peine. Plusieurs écoles publiques ont été pillées et vandalisées. À Mamoudzou, un directeur d\'un établissement a encore du mal à réaliser. Chaque soir, des personnes viennent là-bas se servir allègrement.\n\n"Dans cette salle, ils ont volé les tables, les chaises, le matériel pédagogique des enfants", fait-il savoir. Même le bureau de son adjoint a été cambriolé. Les voleurs sont entrés par le toit qui avait été éventré. "Ils ont volé l\'écran qui était là. Il y avait un micro-ondes qui était là également", déclare-t-il.\n\nReconstruire les maisons\n\nDans la ville, 14 autres écoles ont été pillées depuis Chido. Les voleurs viennent des quartiers défavorisés. Des jeunes hommes nous ont confirmé que certains habitants venaient se servir dans les écoles pour reconstruire leurs maisons. "Ils prennent tout ce qui peut leur servir pour créer leur maison", dit-il. À Mayotte, les cambriolages datent d\'avant le cyclone, mais il les a rendus plus faciles.\n\nRegardez l\'intégralité du reportage dans la vidéo ci-dessus.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/iKkNYlymasoU_EoUy66lRvG_yBQ/199x0:1721x856/1500x843/2024/12/28/mayotte-le-pillage-nouveau-defi-de-securite-676fa0fb3656f080920680.jpg'},
#  'https://www.francetvinfo.fr/internet/reseaux-sociaux/reseaux-sociaux-une-star-chinoise-pour-attirer-les-touristes-dans-la-somme_6979973.html#xtor=RSS-3-[general]': {'title': 'Réseaux Sociaux : une star chinoise pour attirer les touristes dans la Somme',
#   'date': datetime.datetime(2024, 12, 27, 22, 7, 49, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': "Une influenceuse chinoise qui promeut le tourisme dans la Somme : c'est le pari du département français qui s'est offert les services de Jelly Lin, actrice et star des réseaux sociaux en Chine.\n\nUne influenceuse chinoise qui promeut le tourisme dans la Somme : c'est le pari du département français qui s'est offert les services de Jelly Lin, actrice et star des réseaux sociaux en Chine.\n\nEn moins de deux minutes, grâce à sa vidéo, l’actrice chinoise Jelly Lin a fait connaître le département de la Somme dans le monde entier. Dans sa vidéo, elle déambule dans des lieux emblématiques comme la cathédrale d’Amiens ou encore à Saint-Valery-sur-Somme. Une publicité inattendue pour les habitants de la région.\n\nL’actrice et mannequin est aussi une influenceuse très populaire en Chine. Sa vidéo a déjà fait plus de 40 millions de vues. Une aubaine pour les commerçants qui ont eu la chance de participer au clip.\n\nUne campagne de pub valant 150 000 à 200 000 euros\n\nLes professionnels du tourisme comptent sur l’actrice pour attirer les visiteurs venus de Chine, qui ont déserté la région depuis la pandémie de Covid-19.\n\nCoût de la campagne : entre 150 000 et 200 000 euros financés par la France et la Chine, avec pour objectif d’attirer un millier de visiteurs supplémentaires. Une nouvelle façon de communiquer qui a déjà fait ses preuves : l’an dernier, une téléréalité chinoise tournée en Alsace avait permis d’attirer plus de 70 % de visiteurs supplémentaires.\n\nRegardez l'intégralité du reportage dans la vidéo ci-dessus.",
#   'image_link': 'https://www.francetvinfo.fr/pictures/H1tNh5hVMTJC-aMaJ4u0cVRYKn4/0x0:1920x1080/1500x843/2024/12/27/une-star-chinoise-pour-attirer-les-touristes-dans-la-somme-676f15f7c66ba885604593.jpg'},
#  'https://www.francetvinfo.fr/societe/changement-de-vie-laurent-loingtier-ancien-soignant-devenu-restaurateur_6980015.html#xtor=RSS-3-[general]': {'title': 'Changement de vie : Laurent Loingtier ancien soignant devenu restaurateur',
#   'date': datetime.datetime(2024, 12, 27, 22, 47, 43, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
#   'content': "Pour changer de vie, il suffit parfois d'une envie et d'un peu de volonté... à l’instar de Laurent, un ancien soignant qui, à 40 ans passés, a décidé d'ouvrir un restaurant dans un petit village du Perche.\n\nPour changer de vie, il suffit parfois d'une envie et d'un peu de volonté... à l’instar de Laurent, un ancien soignant qui, à 40 ans passés, a décidé d'ouvrir un restaurant dans un petit village du Perche.\n\nOn dit que tous les chemins mènent à Rome. Mais pour cette famille, il mène dans un petit village de Normandie, c’est là qu’ils se sont tous retrouvés.\n\nLaurent n’a jamais quitté le Perche. C’est la terre qui l’a vu grandir. Il y a 23 ans, il a décidé de s’installer dans cette maison pas comme les autres, avec en tête l’idée étrange de cuisiner au milieu des antiquités. “J’étais soignant à l’hôpital pendant 20 ans et je devais y rester jusqu’à la fin de ma carrière (...) Cette opportunité de venir faire la cuisine s’est présentée et c’était juste le bon moment”, raconte-t-il.\n\nUne histoire de famille\n\nL'aventure s’est d’abord écrite à deux, avec sa mère, une ancienne commerçante à la retraite. Si elle a finalement raccroché le tablier il y a peu, Nicole n’est jamais très loin.\n\nLe jour varie mais le rituel ne change pas. Une fois par semaine, le clan se réunit.\n\nRegardez l'intégralité du reportage dans la vidéo ci-dessus.",
#   'image_link': 'https://www.francetvinfo.fr/pictures/UmRHzciJnNkIR_0epWxDW0LzVqM/0x0:1920x1080/1500x843/2024/12/27/changement-de-vie-laurent-loingtier-ancien-soignant-devenu-restaurateur-676f1fe20b352222658413.jpg'},
#  'https://www.francetvinfo.fr/faits-divers/fusillade-d-ajaccio-le-suspect-est-mis-en-examen-pour-meurtre-et-violences-volontaires-apres-avoir-reconnu-les-faits_6979946.html#xtor=RSS-3-[general]': {'title': 'Fusillade d’Ajaccio : le suspect est mis en examen pour meurtre et violences volontaires, après avoir reconnu les faits',
#   'date': datetime.datetime(2024, 12, 27, 21, 38, 9, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'france',
# ...
#   'image_link': 'https://www.francetvinfo.fr/pictures/rKac5NSPGQLLv_mk412jFZJEskc/0x180:3456x2124/1500x843/2024/12/17/grain-de-cafe-6761c7fc179c2637602921.jpg'},
#  'https://www.francetvinfo.fr/economie/energie/energies-renouvelables-il-va-falloir-simplifier-les-procedures-pour-accelerer-la-decarbonation-estime-la-directrice-france-de-totalenergies_6960404.html#xtor=RSS-3-[general]': {'title': 'Énergies renouvelables : "Il va falloir simplifier" les procédures "pour accélérer" la décarbonation, estime la directrice France de TotalEnergies',
#   'date': datetime.datetime(2024, 12, 17, 9, 55, 24, tzinfo=tzoffset(None, 3600)),
#   'author': ['Isabelle Patrier', 'Directrice France De Totalenergies'],
#   'category': 'economie',
#   'content': 'Investir en France est "un enfer" a déclaré la semaine dernière le PDG de Total Patrick Pouyanné. Des propos que reprend et explique Isabelle Patrier.\n\n"Il va falloir simplifier" le millefeuille administratif "pour accélérer" la décarbonation, estime la directrice France de TotalEnergies, Isabelle Patrier, mardi 17 décembre sur France Bleu Nord. Lors d\'un congrès mardi dernier, le PDG de Total Patrick Pouyanné a déclaré : "C\'est l\'enfer d\'investir en France".\n\n"Je reprends ces propos, assure Isabelle Patrier, la directrice générale de TotalEnergies. Aujourd\'hui vous avez une loi d\'accélération qui a été votée pour essayer justement d\'aller beaucoup plus vite et de s\'attaquer à la simplification et au millefeuille administratif français".\n\n"Force est de constater que depuis cette loi d\'accélération, globalement, on a décéléré, on a bien ralenti le rythme." Isabelle Patrier, directrice France de TotalEnergies à France Bleu Nord\n\nSelon la directrice France de TotalEnergies, "on arrivait à produire des mégawattheures en produisant et en investissant dans des fermes solaires, des fermes éoliennes ou dans l\'hydroélectricité sur le pays. On a divisé par deux depuis cette loi d\'accélération. On a tous la même impression de ralentir."\n\nUne ferme solaire en France, c\'est "14 permis"\n\nPatrick Pouyanné avait aussi estimé en résumé qu\'il valait mieux finalement investir aux États-Unis ou en Allemagne plutôt qu\'en France. "Combien de moyens vous pouvez mettre sur le pays France pour pouvoir développer cette électricité renouvelable ?, questionne à son tour Isabelle Patrier. Effectivement, quand vous vous comparez aux autres, vous vous dites que pour des moyens comparables, vous avancez trois fois, deux fois moins vite que les autres". Elle calcule, par exemple, qu\'une ferme solaire, "en France c\'est quatorze permis, forcément, ça semble contradictoire."\n\nTotalEnergies espère cependant tenir ses engagements de décarbonation. L\'an dernier, la production était répartie à 53% pour le pétrole, 42% pour le gaz naturel et 6% d\'électricité. En 2030, l\'entreprise prévoit d\'arriver à 20% d\'électricité dans sa production, et 50% en 2050. "On va y arriver, assure Isabelle Patrier, pour une raison très claire, c\'est qu\'on a des objectifs et que chaque année, on les atteint."\n\nLes niveaux d\'investissements prévus seront les mêmes en 2025 : "Un tiers de nos investissements sont dans les énergies bas carbone, quatre milliards à peu près dans l\'électricité", détaille Isabelle Patrier. Elle explique que Total Energies "a déjà l\'équivalent de la moitié du parc nucléaire français en puissance renouvelable installée, 25 gigawatts", dont "deux sur le territoire français", mais "il y a des pays dans lesquels on arrive à le faire beaucoup plus vite", conclut-elle.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/1OMg6jdoJ8tmBCH_k_NIzBEtxIY/0x432:5835x3711/1500x843/2024/12/17/maxnewsworldsix182228-67613b561d6c1761049783.jpg'},
#  'https://www.francetvinfo.fr/replay-radio/le-brief-eco/le-japonais-softbank-annonce-investir-cent-milliards-de-dollars-aux-etats-unis_6932525.html#xtor=RSS-3-[general]': {'title': 'Le japonais SoftBank annonce investir cent milliards de dollars aux États-Unis',
#   'date': datetime.datetime(2024, 12, 17, 8, 1, 6, tzinfo=tzoffset(None, 3600)),
#   'author': ['Emmanuel'],
#   'category': 'economie',
#   'content': "Le groupe technologique japonais SoftBank promet à Donald Trump d'investir cent milliards de dollars au cours des quatre prochaines années pour se développer aux États-Unis. Vu d’Europe, cela nous paraît démesuré. Comment faut-il l’interpréter ?\n\nCela montre l'attractivité grandissante des États-Unis avant même la prise de pouvoir officielle du président élu en janvier 2025 à la Maison-Blanche. Créée en 1981, la SoftBank Corporation est une société d’investissement japonaise présente aujourd’hui dans tous les grands opérateurs téléphoniques nationaux et internationaux, jusqu’au portail YahooBB, la porte d’entrée du géant américain Yahoo au Japon. Le groupe n’en est pas à son coup d’essai : lors de la première élection de Trump en 2016, SoftBank avait déjà investi 50 milliards de dollars dans des sociétés américaines. Il ne fait que poursuivre son offensive.\n\nIntérêt pour Donald Trump, intérêt pour Tokyo\n\nPour le président américain, l’intérêt est de montrer tout simplement que l’Amérique est attractive par rapport à d’autres zones dans le monde, dont la Chine et l’Europe qui, avec ses persistantes divisions internes et son manque de stratégie commune en matière industrielle, perd de son influence.\n\nSoftBank est avant tout un géant technologique à la pointe de l’Intelligence Artificielle. Le conglomérat nippon veut actuellement développer un supercalculateur utilisant des puces fabriquées par l’américain NVidia. Cet investissement de cent milliards de dollars aux États-Unis (quelque 95 milliards d'euros) doit par ailleurs permettre de créer 100 000 emplois sur le sol américain. Tout bénéfice pour la politique sociale de Trump qui, parallèlement, promet aux entreprises de gros allègements fiscaux.\n\nLe Japon aussi cherche à tirer son épingle du jeu. Tokyo entend récupérer son statut de grande puissance technologique pour trouver une alternative à l’inquiétant vieillissement de sa population. Quant aux américains Microsoft, Amazon et Google, ils promettent d’investir massivement dans l’IA au Japon. Intérêt réciproque bien senti entre Washington et Tokyo donc, au nez et à la barbe de l’Europe, confrontée à ses problèmes politiques, contrainte pendant ce temps perdu de regarder passer les trains.",
#   'image_link': 'https://www.francetvinfo.fr/pictures/OBVuKAG_utsHXhSpd2GlLxgX76Q/0x11:1024x587/1500x843/2024/12/17/053-ar-241004masayoshison05-67611f0f2dc58638973622.jpg'},
#  'https://www.francetvinfo.fr/economie/entreprises/duralex-le-succes-de-la-boutique-des-salaries-a-orleans_6958724.html#xtor=RSS-3-[general]': {'title': 'Duralex : le succès de la boutique des salariés à Orléans',
#   'date': datetime.datetime(2024, 12, 16, 15, 10, 49, tzinfo=tzoffset(None, 3600)),
#   'author': 'Inconnu',
#   'category': 'economie',
#   'content': 'La marque de verre Duralex a lancé son premier magasin éphémère à Orléans, dans le Loiret, près de l\'usine qui a été reprise par les salariés. Depuis, la boutique ne désemplit pas.\n\nLa marque de verre Duralex a lancé son premier magasin éphémère à Orléans, dans le Loiret, près de l\'usine qui a été reprise par les salariés. Depuis, la boutique ne désemplit pas.\n\nDans les halles d\'Orléans (Loiret), la boutique éphémère Duralex ne désemplit pas. Depuis l\'ouverture, jeudi 12 décembre, plus de 20 000 clients se sont déplacés. "L\'envie de venir, et puis soutenir l\'économie française", dit une Orléanaise en pleines courses de Noël. Duralex est devenue une coopérative six mois plus tôt. Pour la période de fêtes, les employés de l\'usine se transforment en vendeurs.\n\nUn succès boosté par la nostalgie\n\nAhmed Terristi est d\'habitude chef d\'équipe, en charge de la moulerie. "C\'est ma première expérience en tant que vendeur. Il y a un monde fou, c\'est impressionnant. Ça fait du baume au cœur", confie-t-il.\n\nPrès de 30 000 euros de ventes ont été enregistrés sur la seule journée de dimanche, un succès boosté par une certaine nostalgie. "C\'est notre enfance à la cantine… Avec les petits verres, on disait : t\'as quel âge?", raconte une cliente. L\'État, de son côté, s\'est engagé à verser un prêt de 750 000 euros pour soutenir les 200 salariés de la verrerie française.\n\nRetrouvez l\'intégralité du reportage dans la vidéo ci-dessus',
#   'image_link': 'https://www.francetvinfo.fr/pictures/S0YW5stjP2xDWf0NMyKsg5bfkRY/0x83:743x501/1500x843/2024/12/16/duralex-676032aeca877641115547.png'},
#  'https://www.francetvinfo.fr/replay-radio/le-decryptage-eco/la-france-creuse-son-deficit-a-6-en-2024-une-tendance-qui-pourrait-se-prolonger-en-2025_6930737.html#xtor=RSS-3-[general]': {'title': 'La France creuse son déficit à 6 % en 2024, une tendance qui pourrait se prolonger en 2025',
#   'date': datetime.datetime(2024, 12, 16, 9, 58, 54, tzinfo=tzoffset(None, 3600)),
#   'author': ['Fanny Guinochet'],
#   'category': 'economie',
#   'content': 'La loi spéciale de finances est discutée lundi à l\'Assemblée nationale, elle permettra de corriger certains dysfonctionnements posés par la reconduction du budget 2024, mais qui n\'efface pas les difficultés économiques du pays.\n\nPremier test pour François Bayrou lundi 16 décembre, alors que la loi de finances spéciale est examinée au Parlement. Une loi qui devrait être votée sans problème, car elle est indispensable pour que l’État continue de fonctionner. La teneur des débats tout à l’heure va toutefois donner quelques indications à François Bayrou avant l’élaboration d’un budget en bonne et due forme. Budget qui promet d’être complexe, tant la situation économique dont il hérite est alarmante. À la fin de l\'année 2024, le déficit de l\'État français devrait dépasser les 6% du PIB.\n\nLe gouvernement Barnier tablait pour sa part sur 6,1%, mais d\'autres, comme par exemple la banque Morgan Stanley, prévoit plutôt 6,3%. Plusieurs économistes le disent d\'ailleurs, cette fin d’année, les recettes fiscales seront sûrement moins bonnes que prévu. Un peu comme en 2023, sauf que cette année, s’est ajoutée l’instabilité politique qui pèse sur l’investissement des entreprises, mais aussi sur la consommation. Tout ça risque de se traduire par des rentrées de TVA plus faibles que prévu, alors que de l’autre côté, les dépenses, elles, continuent de déraper.\n\nDe mal en pis\n\nLogiquement, pour 2025, ce sera même pire. Michel Barnier ambitionnait de ramener le déficit à 5%, et pour y parvenir, il tablait sur 60 milliards d’euros d’effort dans le budget. Quelque 60 milliards qui ont volé en éclat avec la censure de son gouvernement. Faute de budget d’ailleurs, d\'importantes dépenses sont déjà actées pour 2025. L’indexation de toutes les pensions de retraite sur l’inflation, par exemple, coûtera 6,5 milliards d\'euros. Un montant que personne n’osera d\'ailleurs remettre en cause.\n\nPour 2025, Laurent Saint Martin, le ministre démissionnaire des comptes publics a déjà prévenu : le déficit restera autour de 6%. Un niveau inquiétant, d\'autant que la France est un des seuls pays à atteindre ces sommets en Europe, alors que la règle européenne est à 3% du PIB. Et c\'est justement cette situation que les agences de notation sanctionnent. C’est même l’avertissement envoyé par l’agence Moody\'s, qui dès la nomination de François Bayrou, vendredi 13 décembre, a dégradé la note financière française craignant, "que la fragmentation politique empêche une consolidation budgétaire significative".\n\nEn clair, Moody\'s, comme les autres agences, ne se font aucune illusion : François Bayrou va chercher une majorité pour faire passer le futur budget et pour ce faire, accepter des concessions forcément coûteuses, comme des aménagements à la réforme des retraites, des allégements de charges, ou encore des baisses d’impôts. Des finances publiques qui seront donc, une fois de plus, les grandes sacrifiées sur l’autel de la stabilité politique.',
#   'image_link': 'https://www.francetvinfo.fr/pictures/s-RN35wgbYhPsmvx3bgNVlxI03I/88x0:936x477/1500x843/2024/12/16/068-2097439-675feb1b2ed80835102804.jpg'},
#  'https://www.francetvinfo.fr/replay-radio/ca-nous-marque/bioderma-le-secteur-de-la-dermocosmetique-est-en-croissance-de-pres-de-8_6927266.html#xtor=RSS-3-[general]': {'title': 'Bioderma : "Le secteur de la dermocosmétique est en croissance de près de 8%"',
#   'date': datetime.datetime(2024, 12, 14, 12, 4, 44, tzinfo=tzoffset(None, 3600)),
#   'author': ['Victor'],
#   'category': 'economie',
#   'content': 'Créée il y a près de cinquante ans, la marque s\'est imposée dans le marché de la dermocosmétique, grâce au succès incontesté de son eau micellaire démaquillante.\n\nBioderma : la contraction de biologie et dermatologie. C\'est aussi le nom de la marque, fondée en 1977 par Jean-Noël Thorel, un pharmacien passionné de biologie. Il va révolutionner le marché de la dermocosmétique au début des années 90, en inventant l\'eau micellaire, un soin démaquillant qui prend soin de la peau.\n\nUne bouteille d\'eau micellaire vendue chaque seconde dans le monde\n\n"Il s\'en vend une par seconde dans le monde", détaille David Durand, directeur de l\'innovation chez Naos, propriétaire de Bioderma. La marque, qui a réalisé près de 800 millions d\'euros de chiffre d\'affaires cette année, est présente dans une centaine de pays. Elle compte 45 filiales et 3.300 collaborateurs.\n\nL\'enseigne continue de se développer, à l\'image du secteur de la dermocosmétique : près de 8% de croissance en 2024, et plus de deux milliards d\'euros de chiffre d\'affaires. David Durand n\'est pas surpris : "Les patients vivent de plus en plus dans des zones sujettes au stress, à la pollution. Un environnement qui est quand même compliqué, et donc ces clients se tournent vers des marques qui se basent avant tout sur la sécurité et l\'efficacité. Et quoi de plus naturel que le circuit pharmaceutique pour trouver ses marques ? Ce qui explique que les marques vendues en pharmacie sont nombreuses."\n\n150 chercheurs pour élaborer les produits\n\nLes produits sont fabriqués à Aix-en-Provence, dans le sud de la France. David Durand développe : "On a 500 collaborateurs qui travaillent chaque jour dans nos usines. On a 150 chercheurs qui travaillent dans les laboratoires de recherche, en partenariat avec des dermatologues, des pharmaciens, biologistes, et c\'est basé sur un principe de recherche fondateur, à travers de toutes nos marques. On considère la peau comme un écosystème, et donc on préserve de manière durable les ressources de la peau, et on réapprend à la peau à se redéfinir, à s\'adapter naturellement".',
#   'image_link': 'https://www.francetvinfo.fr/pictures/efvKEXn6WPPUnY1vBsT-OyLASfM/0x157:2016x1290/1500x843/2024/12/13/bioderma-675c3a754522d088529245.jpg'}}

# %%
import spacy
# Load pipeline and related models
process = spacy.load("fr_core_news_md")
# process text with pipeline

# %%
commentaires = [existing_data[key]['content'] for key in existing_data.keys()]
commentaires[0]
# Out:
# 'Beaucoup de maires et de secrétaires de mairie ont rencontré au cours de leurs mandats des problèmes de violence, essentiellement verbale. C\'est le cas de Claire. Un jour, un homme est entré dans son bureau et a frappé très fort sur son bureau pour l\'intimider. "J\'ai réagi à l\'instinct, j\'ai essayé de discuter, mais ça s\'est envenimé. Heureusement qu\'une dame est arrivée à la permanence et a menacé d\'appeler la gendarmerie", raconte Claire Carrère-Godebout, maire (SE) de Graveron-Sémerville (Eure).\n\nDes professeurs de karaté et un psychologue\n\nLa plupart de ces élus ne savent pas comment se comporter face à une situation conflictuelle. Alors, l\'Association des maires ruraux de l\'Eure les initie à l\'autodéfense, avec l\'aide de professeurs de karaté. Et un psychologue leur a expliqué comment désamorcer un différent. "C\'est nécessaire qu\'ils aient confiance en eux donc, à partir de là, je pense que cet atelier ne peut avoir que des bénéfices", explique Christophe Micaux.'

# %% [markdown]
# # QUESTION 8

# %%
import spacy
import json
from collections import defaultdict
import pandas as pd

# Charger le modèle spaCy pour le français (désactiver les parties inutiles pour gagner du temps)
nlp = spacy.load("fr_core_news_md", disable=["tagger", "parser"])

# Charger les données depuis le fichier JSON
with open("francetvinfo.json", "r", encoding="utf-8") as f:
    existing_data = json.load(f)

# Dictionnaire pour stocker les entités extraites par article
entities_by_article = defaultdict(list)

# Fonction pour extraire les entités
def extract_entities(doc):
    return [
        {
            "text": ent.text,
            "type": ent.label_,
            "start": ent.start_char,
            "end": ent.end_char
        }
        for ent in doc.ents
    ]

# Traitement des articles avec spaCy
for article_url, article_data in existing_data.items():
    # Traitement du contenu de chaque article avec pipe
    doc = nlp(article_data["content"])
    entities = extract_entities(doc)
    entities_by_article[article_url] = entities

# Afficher un échantillon des entités extraites pour vérifier
for article_url, entities in list(entities_by_article.items())[:2]:
    print(f"URL: {article_url}")
    for ent in entities:
        print(f" - {ent['text']} ({ent['type']})")
# Out:
# URL: https://www.francetvinfo.fr/sante/prevention/eure-quand-les-elus-apprennent-a-se-defendre_3791635.html#xtor=RSS-3-[france]
#  - Claire (PER)
#  - Claire Carrère-Godebout (PER)
#  - SE (LOC)
#  - Graveron-Sémerville (LOC)
#  - Eure (LOC)
#  - Association des maires ruraux de l'Eure (ORG)
#  - Christophe Micaux (PER)
# URL: https://www.francetvinfo.fr/france/video-sur-le-dos-d-un-aigle-pecheur-au-dessus-du-massif-du-mont-blanc-dont-les-glaciers-fondent-aujourd-hui-a-vue-d-oeil_3791583.html#xtor=RSS-3-[france]
#  - AlertePollution Rivières (LOC)
#  - Cliquez (LOC)
#  - !
#
# Embarquement (MISC)
#  - Victor (MISC)
#  - Pygargue (LOC)
#  - Haliaeetus (LOC)
#  - massif du Mont-Blanc (LOC)
#  - Europe (LOC)
#  - Alpes (LOC)
#  - Victor (PER)
#  - Jacques-Olivier Travers (PER)
#  - Antarctique (LOC)
#  - Amazonie (LOC)
#  - Alpes (LOC)
#  - glacier des Bossons (LOC)
#  - Alpes (LOC)

# %% [markdown]
# # QUESTION 9

# %%
import spacy
from collections import Counter
import pandas as pd

# Chargement du modèle spaCy pour le français
process = spacy.load("fr_core_news_md", disable=["tagger"])

# Liste des commentaires à analyser
commentaires = {
    key: existing_data[key]['content']
    for key in existing_data.keys()
}

# Dictionnaire pour stocker les entités extraites par lien
resultats = {}

# Compteur global pour stocker les fréquences des entités
entite_counter = Counter()

# Compteurs distincts pour chaque type d'entité
personne_counter = Counter()
lieu_counter = Counter()
organisation_counter = Counter()

# Extraction des entités nommées
def extract_entities(doc):
    entities = []
    for ent in doc.ents:
        entities.append({
            "text": ent.text,
            "type": ent.label_,
            "start": ent.start_char,
            "end": ent.end_char
        })
        # Compter les entités par type
        if ent.label_ == "PER":  # Personnes
            personne_counter[ent.text] += 1
        elif ent.label_ == "LOC":  # Lieux
            lieu_counter[ent.text] += 1
        elif ent.label_ == "ORG":  # Organisations
            organisation_counter[ent.text] += 1
        # Compter globalement toutes les entités
        entite_counter[ent.text] += 1
    return entities

# Traitement des articles
for key, doc in zip(commentaires.keys(), process.pipe(commentaires.values(), batch_size=20, n_process=2)):
    try:
        entities = extract_entities(doc)
        resultats[key] = entities
    except Exception as e:
        print(f"Erreur lors du traitement du document {key}: {e}")

# Obtenir les 20 entités les plus fréquentes globalement
top_20_entites = entite_counter.most_common(20)

# Obtenir les 20 entités les plus fréquentes par type
top_20_personnes = personne_counter.most_common(20)
top_20_lieux = lieu_counter.most_common(20)
top_20_organisations = organisation_counter.most_common(20)

# %%
entities = extract_entities(doc)
resultats[key] = entities

# Exemple avec votre structure de données `resultats`
for link, entities in resultats.items():
    print(f"Article : {link}")
    
    # Itérer sur les entités extraites de l'article
    for ent in entities:
        # Affichage de l'entité et de son type
        print(f" - Texte: {ent['text']}, Type: {ent['type']}, Span: ({ent['start']}, {ent['end']})")
# Out:
# Article : https://www.francetvinfo.fr/sante/prevention/eure-quand-les-elus-apprennent-a-se-defendre_3791635.html#xtor=RSS-3-[france]
#  - Texte: Claire, Type: PER, Span: (155, 161)
#  - Texte: Claire Carrère-Godebout, Type: PER, Span: (437, 460)
#  - Texte: SE, Type: LOC, Span: (469, 471)
#  - Texte: Graveron-Sémerville, Type: LOC, Span: (476, 495)
#  - Texte: Eure, Type: LOC, Span: (497, 501)
#  - Texte: Association des maires ruraux de l'Eure, Type: ORG, Span: (653, 692)
#  - Texte: Christophe Micaux, Type: PER, Span: (964, 981)
# Article : https://www.francetvinfo.fr/france/video-sur-le-dos-d-un-aigle-pecheur-au-dessus-du-massif-du-mont-blanc-dont-les-glaciers-fondent-aujourd-hui-a-vue-d-oeil_3791583.html#xtor=RSS-3-[france]
#  - Texte: AlertePollution Rivières, Type: LOC, Span: (1, 25)
#  - Texte: Cliquez, Type: LOC, Span: (121, 128)
#  - Texte: !
#
# , Type: MISC, Span: (151, 154)
#  - Texte: Victor, Type: MISC, Span: (204, 210)
#  - Texte: Pygargue, Type: LOC, Span: (215, 223)
#  - Texte: Haliaeetus, Type: LOC, Span: (241, 251)
#  - Texte: massif du Mont-Blanc, Type: LOC, Span: (277, 297)
#  - Texte: Europe, Type: LOC, Span: (321, 327)
#  - Texte: Alpes, Type: LOC, Span: (841, 846)
#  - Texte: Victor, Type: PER, Span: (910, 916)
#  - Texte: Jacques-Olivier Travers, Type: PER, Span: (982, 1005)
#  - Texte: Antarctique, Type: LOC, Span: (1392, 1403)
#  - Texte: Amazonie, Type: LOC, Span: (1410, 1418)
#  - Texte: Alpes, Type: LOC, Span: (1477, 1482)
#  - Texte: glacier des Bossons, Type: LOC, Span: (1614, 1633)
#  - Texte: Alpes, Type: LOC, Span: (1816, 1821)
# Article : https://www.francetvinfo.fr/societe/video-massif-du-mont-blanc-la-hausse-des-temperatures-fait-s-ecrouler-la-montagne-par-pans-entier-a-haute-altitude_3791537.html#xtor=RSS-3-[france]
#  - Texte: AlertePollution Rivières, Type: LOC, Span: (1, 25)
#  - Texte: Cliquez, Type: LOC, Span: (121, 128)
#  - Texte: massif du Mont-Blanc, Type: LOC, Span: (421, 441)
#  - Texte: Chamonix, Type: LOC, Span: (601, 609)
#  - Texte: Philippe Batoux, Type: PER, Span: (611, 626)
#  - Texte: Ludovic Ravanel, Type: PER, Span: (630, 645)
#  - Texte: CNRS, Type: ORG, Span: (686, 690)
#  - Texte: Philippe Batoux, Type: PER, Span: (992, 1007)
#  - Texte: massif du Mont-Blanc, Type: LOC, Span: (1332, 1352)
#  - Texte: Ça, Type: MISC, Span: (1354, 1356)
#  - Texte: Chez les alpinistes, Type: MISC, Span: (1424, 1443)
# Article : https://www.francetvinfo.fr/replay-magazine/france-2/13h15/13h15-du-dimanche-19-janvier-2020_3766797.html#xtor=RSS-3-[france]
#  - Texte: chaîne des Alpes, Type: LOC, Span: (22, 38)
#  - Texte: Europe, Type: LOC, Span: (93, 99)
#  - Texte: le Mont-Blanc, Type: LOC, Span: (113, 126)
#  - Texte: département de la Haute-Savoie, Type: LOC, Span: (307, 337)
#  - Texte: France, Type: LOC, Span: (342, 348)
#  - Texte: vallée d'Aoste, Type: LOC, Span: (356, 370)
#  - Texte: Italie, Type: LOC, Span: (375, 381)
#  - Texte: Témoin, Type: ORG, Span: (462, 468)
#  - Texte: Jean-Sébastien Desbordes, Type: PER, Span: (521, 545)
#  - Texte: Matthieu Martin, Type: PER, Span: (547, 562)
#  - Texte: Anthony Santoro, Type: PER, Span: (566, 581)
#  - Texte: Facebook, Type: MISC, Span: (616, 624)
#  - Texte: Twitter, Type: MISC, Span: (626, 633)
#  - Texte: Jean Vincendon, Type: PER, Span: (966, 980)
#  - Texte: François Henry, Type: PER, Span: (984, 998)
# Article : https://www.francetvinfo.fr/societe/loi-de-bioethique/loi-de-bioethique-les-opposants-a-la-pma-manifestent-a-paris_3791629.html#xtor=RSS-3-[france]
#  - Texte: Marchons Enfants !, Type: MISC, Span: (106, 124)
#  - Texte: Manif, Type: ORG, Span: (186, 191)
#  - Texte: Paris, Type: LOC, Span: (428, 433)
#  - Texte: Carole Guyon, Type: PER, Span: (460, 472)
#  - Texte: Assemblée, Type: ORG, Span: (532, 541)
#  - Texte: Dimanche 19 janvier, Type: MISC, Span: (563, 582)
#  - Texte: la France, Type: LOC, Span: (620, 629)
#  - Texte: place de l'Opéra, Type: LOC, Span: (712, 728)
#  - Texte: Assemblée nationale, Type: ORG, Span: (914, 933)
#  - Texte: Sénat, Type: ORG, Span: (998, 1003)
# Article : https://www.francetvinfo.fr/societe/loi-de-bioethique/loi-de-bioethique-les-anti-pma-a-nouveau-dans-la-rue_3791531.html#xtor=RSS-3-[france]
#  - Texte: place de la Résistance, Type: LOC, Span: (55, 77)
#  - Texte: 7e arrondissement de Paris, Type: LOC, Span: (87, 113)
#  - Texte: Carole Guyon, Type: PER, Span: (120, 132)
#  - Texte: France Télévisions, Type: ORG, Span: (149, 167)
#  - Texte: Marchons Enfants !
#
# , Type: MISC, Span: (371, 391)
#  - Texte: Manif, Type: ORG, Span: (451, 456)
#  - Texte: Paris, Type: LOC, Span: (652, 657)
#  - Texte: la France, Type: LOC, Span: (716, 725)
#  - Texte: place de l'Opéra, Type: LOC, Span: (808, 824)
#  - Texte: JT, Type: ORG, Span: (857, 859)
#  - Texte: JT, Type: ORG, Span: (882, 884)
# Article : https://www.francetvinfo.fr/france/tendance-louer-ses-meubles-une-solution-commode_3790613.html#xtor=RSS-3-[france]
#  - Texte: Caroline, Type: LOC, Span: (45, 53)
#  - Texte: Appoline, Type: LOC, Span: (55, 63)
#  - Texte: Clément, Type: PER, Span: (67, 74)
#  - Texte: Lyon, Type: LOC, Span: (86, 90)
#  - Texte: Rhône, Type: LOC, Span: (92, 97)
#  - Texte: Ça, Type: MISC, Span: (181, 183)
#  - Texte: Caroline Letalenet, Type: PER, Span: (391, 409)
#  - Texte: hi-fi, Type: MISC, Span: (749, 754)
#  - Texte: Marie-Alice Duval, Type: PER, Span: (850, 867)
#  - Texte: JT, Type: ORG, Span: (1023, 1025)
#  - Texte: JT, Type: ORG, Span: (1048, 1050)
# Article : https://www.francetvinfo.fr/societe/education/reforme-du-bac/education-le-nouveau-bac-deja-mis-a-l-epreuve_3790665.html#xtor=RSS-3-[france]
#  - Texte: Clermont-Ferrand, Type: LOC, Span: (91, 107)
#  - Texte: Puy-de-Dôme, Type: LOC, Span: (117, 128)
#  - Texte: lycée Blaise, Type: LOC, Span: (248, 260)
#  - Texte: Ça, Type: MISC, Span: (484, 486)
#  - Texte: Farouk, Type: PER, Span: (589, 595)
#  - Texte: Sommés, Type: PER, Span: (658, 664)
#  - Texte: Lyon, Type: LOC, Span: (837, 841)
#  - Texte: Laurent Doléac, Type: PER, Span: (1081, 1095)
#  - Texte: JT, Type: ORG, Span: (1130, 1132)
#  - Texte: JT, Type: ORG, Span: (1155, 1157)
# Article : https://www.francetvinfo.fr/culture/musique/musique-ils-reprennent-leurs-groupes-favoris_3790659.html#xtor=RSS-3-[france]
#  - Texte: Goldmen, Type: MISC, Span: (119, 126)
#  - Texte: Best of Floyd, Type: MISC, Span: (130, 143)
#  - Texte: Marseille, Type: LOC, Span: (169, 178)
#  - Texte: Pink Floyd, Type: ORG, Span: (296, 306)
#  - Texte: David Gilmour, Type: PER, Span: (345, 358)
#  - Texte: Français, Type: LOC, Span: (384, 392)
#  - Texte: Best of Floyd, Type: ORG, Span: (403, 416)
#  - Texte: Bertrand Lefebvre, Type: PER, Span: (482, 499)
#  - Texte: Best of Floyd, Type: MISC, Span: (515, 528)
#  - Texte: Pink Floyd, Type: ORG, Span: (618, 628)
#  - Texte: Adoubé, Type: PER, Span: (671, 677)
#  - Texte: Jean-Jacques Goldman, Type: PER, Span: (682, 702)
#  - Texte: Alain Stevez, Type: PER, Span: (805, 817)
#  - Texte: Jean-Jacques Goldman, Type: PER, Span: (877, 897)
#  - Texte: France 2, Type: ORG, Span: (945, 953)
#  - Texte: Goldman, Type: PER, Span: (993, 1000)
#  - Texte: JT, Type: ORG, Span: (1304, 1306)
#  - Texte: JT, Type: ORG, Span: (1329, 1331)
# Article : https://www.francetvinfo.fr/economie/transports/gilets-jaunes/gilets-jaunes-une-fin-de-manifestation-mouvementee_3790649.html#xtor=RSS-3-[france]
#  - Texte: gare de Lyon, Type: LOC, Span: (116, 128)
#  - Texte: Paris, Type: LOC, Span: (130, 135)
#  - Texte: France 2, Type: ORG, Span: (143, 151)
#  - Texte: Dorothée Olliéric, Type: PER, Span: (153, 170)
#  - Texte: JT, Type: ORG, Span: (909, 911)
#  - Texte: JT, Type: ORG, Span: (934, 936)
# Article : https://www.francetvinfo.fr/economie/fabrique-en-france-des-produits-plebiscites_3790643.html#xtor=RSS-3-[france]
#  - Texte: Arnaud Montebourg, Type: PER, Span: (0, 17)
#  - Texte: made in France, Type: MISC, Span: (35, 49)
#  - Texte: made in France, Type: MISC, Span: (118, 132)
#  - Texte: France, Type: LOC, Span: (319, 325)
#  - Texte: Élysée, Type: LOC, Span: (397, 403)
#  - Texte: État, Type: LOC, Span: (646, 650)
#  - Texte: made in France, Type: MISC, Span: (685, 699)
#  - Texte: France, Type: LOC, Span: (856, 862)
#  - Texte: JT, Type: ORG, Span: (917, 919)
#  - Texte: JT, Type: ORG, Span: (942, 944)
# Article : https://www.francetvinfo.fr/monde/afrique/egypte/ariege-une-dent-au-pouvoir-magique_3790447.html#xtor=RSS-3-[france]
#  - Texte: Lezat-sur-Leze, Type: LOC, Span: (2, 16)
#  - Texte: Ariège, Type: LOC, Span: (25, 31)
#  - Texte: sainte Appolonie, Type: PER, Span: (92, 108)
#  - Texte: Ariègeoise, Type: LOC, Span: (374, 384)
#  - Texte: Appolonie, Type: LOC, Span: (387, 396)
#  - Texte: IIIe, Type: MISC, Span: (407, 411)
#  - Texte: Égypte, Type: LOC, Span: (422, 428)
#  - Texte: sainte Appolonie, Type: PER, Span: (475, 491)
#  - Texte: sainte Appolonie, Type: PER, Span: (713, 729)
#  - Texte: Appolonie, Type: LOC, Span: (802, 811)
#  - Texte: IIIe, Type: MISC, Span: (822, 826)
#  - Texte: Égypte, Type: LOC, Span: (837, 843)
#  - Texte: Christ, Type: PER, Span: (876, 882)
#  - Texte: JT, Type: ORG, Span: (929, 931)
#  - Texte: JT, Type: ORG, Span: (954, 956)
# Article : https://www.francetvinfo.fr/culture/spectacles/video-la-pratique-de-la-danse-classique-a-permis-a-lilian-de-sortir-de-l-isolement-dans-lequel-une-dyslexie-severe-l-avait-plonge_3790381.html#xtor=RSS-3-[france]
#  - Texte: Lilian Dubus, Type: PER, Span: (210, 222)
#  - Texte: Valérie Houssin, Type: PER, Span: (292, 307)
#  - Texte: Zutkerque, Type: LOC, Span: (417, 426)
#  - Texte: Pas-de-Calais, Type: LOC, Span: (428, 441)
#  - Texte: CE2, Type: MISC, Span: (537, 540)
#  - Texte: CP, Type: LOC, Span: (1206, 1208)
#  - Texte: Lilian, Type: MISC, Span: (1434, 1440)
# Article : https://www.francetvinfo.fr/replay-magazine/france-2/13h15/13h15-du-samedi-18-janvier-2020_3766801.html#xtor=RSS-3-[france]
#  - Texte: Lilian, Type: PER, Span: (330, 336)
#  - Texte: Billy Elliot, Type: PER, Span: (649, 661)
#  - Texte: la France, Type: LOC, Span: (674, 683)
#  - Texte: Hélène Lam Trong, Type: PER, Span: (708, 724)
#  - Texte: Benjamine Jeunehomme, Type: PER, Span: (726, 746)
#  - Texte: Bérengère Lafont, Type: PER, Span: (750, 766)
#  - Texte: Facebook, Type: MISC, Span: (799, 807)
#  - Texte: Twitter, Type: MISC, Span: (809, 816)
#  - Texte: Billy Elliot, Type: PER, Span: (984, 996)
#  - Texte: Stephen Daldry, Type: PER, Span: (1055, 1069)
#  - Texte: Lilian, Type: PER, Span: (1072, 1078)
#  - Texte: Zutkerque, Type: LOC, Span: (1352, 1361)
#  - Texte: Pas-de-Calais, Type: LOC, Span: (1363, 1376)
# Article : https://www.francetvinfo.fr/culture/mode/createurs/made-in-france-un-label-qui-a-le-vent-en-poupe_3790445.html#xtor=RSS-3-[france]
#  - Texte: 13 Heures, Type: MISC, Span: (18, 27)
#  - Texte: France Télévisions Christelle Méral, Type: ORG, Span: (47, 82)
#  - Texte: France, Type: LOC, Span: (324, 330)
#  - Texte: made in France, Type: MISC, Span: (859, 873)
#  - Texte: JT, Type: ORG, Span: (969, 971)
#  - Texte: JT, Type: ORG, Span: (994, 996)
# Article : https://www.francetvinfo.fr/france/debarquement-du-6-juin-1944/lyon-l-hommage-a-franck-labois-policier-mort-en-service_3789501.html#xtor=RSS-3-[france]
#  - Texte: Bron, Type: LOC, Span: (136, 140)
#  - Texte: Rhône, Type: LOC, Span: (142, 147)
#  - Texte: Lyon, Type: LOC, Span: (206, 210)
#  - Texte: Rhône, Type: LOC, Span: (212, 217)
#  - Texte: Franck Labois, Type: PER, Span: (380, 393)
#  - Texte: Légion d'honneur, Type: ORG, Span: (421, 437)
#  - Texte: Christophe Castaner, Type: PER, Span: (470, 489)
#  - Texte: Premier ministre, Type: MISC, Span: (494, 510)
#  - Texte: JT, Type: ORG, Span: (835, 837)
#  - Texte: JT, Type: ORG, Span: (860, 862)
# Article : https://www.francetvinfo.fr/economie/industrie/made-in-france-le-savoir-faire-des-artisans-a-l-honneur_3789219.html#xtor=RSS-3-[france]
#  - Texte: Emmanuel Macron, Type: PER, Span: (18, 33)
#  - Texte: la France, Type: LOC, Span: (105, 114)
#  - Texte: Élysée, Type: LOC, Span: (118, 124)
#  - Texte: Français, Type: LOC, Span: (320, 328)
#  - Texte: Oraison, Type: LOC, Span: (480, 487)
#  - Texte: Alpes-de-Haute-Provence, Type: LOC, Span: (489, 512)
#  - Texte: Jean-Marc Doucet, Type: PER, Span: (527, 543)
#  - Texte: JT, Type: ORG, Span: (898, 900)
#  - Texte: JT, Type: ORG, Span: (923, 925)
# Article : https://www.francetvinfo.fr/societe/video-en-1952-la-france-apprenait-quelle-comptait-42-millions-d-habitants_3789021.html#xtor=RSS-3-[france]
#  - Texte: Insee, Type: ORG, Span: (2, 7)
#  - Texte: La France, Type: LOC, Span: (76, 85)
#  - Texte: Hexagone, Type: LOC, Span: (139, 147)
# Article : https://france3-regions.francetvinfo.fr/bretagne/cotes-d-armor/saint-brieuc/explosion-rue-trevise-paris-on-vecu-choses-que-peu-gens-vivront-ca-il-faut-accepter-1771345.html#xtor=RSS-3-[france]
#  - Texte: rue de Trévise, Type: LOC, Span: (43, 57)
#  - Texte: Annie, Type: LOC, Span: (193, 198)
#  - Texte: IXème, Type: MISC, Span: (687, 692)
#  - Texte: Julien, Type: PER, Span: (739, 745)
#  - Texte: Saint-Brieuc, Type: LOC, Span: (759, 771)
#  - Texte: Paris, Type: LOC, Span: (843, 848)
#  - Texte: Trévise, Type: LOC, Span: (878, 885)
#  - Texte: Julien, Type: PER, Span: (1539, 1545)
#  - Texte: Paris, Type: LOC, Span: (1901, 1906)
#  - Texte: Charlie Hebdo, Type: PER, Span: (1968, 1981)
#  - Texte: Julien, Type: PER, Span: (2013, 2019)
#  - Texte: Julien, Type: PER, Span: (2117, 2123)
#  - Texte: IXème arrondissement, Type: LOC, Span: (2495, 2515)
#  - Texte: Énervement, Type: PER, Span: (2731, 2741)
#  - Texte: Bretagne, Type: LOC, Span: (2785, 2793)
#  - Texte: Julien, Type: PER, Span: (2836, 2842)
#  - Texte: Côtes d'Armor, Type: LOC, Span: (2905, 2918)
#  - Texte: Ça, Type: MISC, Span: (2940, 2942)
#  - Texte: Paris, Type: LOC, Span: (3042, 3047)
#  - Texte: Paris, Type: LOC, Span: (3217, 3222)
#  - Texte: ça, Type: MISC, Span: (3603, 3605)
#  - Texte: Paris, Type: LOC, Span: (3662, 3667)
# Article : https://france3-regions.francetvinfo.fr/centre-val-de-loire/eure-et-loir/eure-loir-ophelie-coiffeuse-recupere-vos-cheveux-depolluer-mers-1767397.html#xtor=RSS-3-[france]
#  - Texte: Ophélie, Type: PER, Span: (576, 583)
#  - Texte: Chassant / ©, Type: ORG, Span: (613, 625)
#  - Texte: France, Type: LOC, Span: (626, 632)
#  - Texte: Télévisions Ophélie, Type: PER, Span: (633, 652)
#  - Texte: France Télévisions, Type: ORG, Span: (763, 781)
#  - Texte: Matter of trust, Type: MISC, Span: (904, 919)
#  - Texte: Il faut un kilo de cheveux pour « absorber » un litre de pétrole, Type: MISC, Span: (921, 985)
#  - Texte: Coiffeurs justes, Type: MISC, Span: (1004, 1020)
#  - Texte: Thierry Gras, Type: PER, Span: (1031, 1043)
#  - Texte: Saint-Zacharie, Type: LOC, Span: (1083, 1097)
#  - Texte: Var, Type: LOC, Span: (1114, 1117)
#  - Texte: Ophélie Loison, Type: PER, Span: (1118, 1132)
#  - Texte: Thierry Gras, Type: PER, Span: (1198, 1210)
#  - Texte: Thierry Gras, Type: PER, Span: (1384, 1396)
#  - Texte: Coiffeurs justes, Type: MISC, Span: (1488, 1504)
#  - Texte: Coiffeurs justes espèreIl, Type: MISC, Span: (1948, 1973)
#  - Texte: Amoco Cadiz, Type: MISC, Span: (2198, 2209)
#  - Texte: baie de San Francisco, Type: LOC, Span: (2283, 2304)
#  - Texte: Matter of trust, Type: ORG, Span: (2340, 2355)
#  - Texte: Deepwater, Type: MISC, Span: (2427, 2436)
#  - Texte: Nouvelle-Orléans, Type: LOC, Span: (2449, 2465)
#  - Texte: Thierry Gras, Type: PER, Span: (2477, 2489)
#  - Texte: Europe, Type: LOC, Span: (2517, 2523)
# Article : https://www.francetvinfo.fr/replay-magazine/france-3/nous-les-europeens/nous-les-europeens-du-dimanche-19-janvier-2020_3766789.html#xtor=RSS-3-[monde/europe]
#  - Texte: Européens, Type: LOC, Span: (98, 107)
#  - Texte: Twitter, Type: MISC, Span: (110, 117)
#  - Texte: Francis Letellier, Type: PER, Span: (133, 150)
#  - Texte: France 3, Type: ORG, Span: (186, 194)
#  - Texte: Estonie, Type: LOC, Span: (233, 240)
#  - Texte: Prévenir, Type: MISC, Span: (822, 830)
#  - Texte: REPORTAGE, Type: MISC, Span: (855, 864)
#  - Texte: L’Estonie, Type: LOC, Span: (866, 875)
#  - Texte: Estoniens, Type: LOC, Span: (1068, 1077)
#  - Texte: Etat, Type: LOC, Span: (1266, 1270)
#  - Texte: Jérôme Tournier, Type: PER, Span: (1469, 1484)
#  - Texte: Yaël Goujon, Type: PER, Span: (1488, 1499)
#  - Texte: INVITE
#
# Jean-François Delfraissy, Type: MISC, Span: (1506, 1538)
#  - Texte: Comité consultatif national d’éthique pour les sciences de la vie, Type: ORG, Span: (1578, 1643)
#  - Texte: CCNE, Type: ORG, Span: (1660, 1664)
#  - Texte: LES INSTANTANES DE L'EUROPE, Type: MISC, Span: (1710, 1737)
#  - Texte: Europe, Type: LOC, Span: (1749, 1755)
#  - Texte: François Beaudonnet, Type: PER, Span: (1824, 1843)
# Article : https://www.francetvinfo.fr/monde/europe/video-estonie-une-banque-d-adn-publique-unique-au-monde-au-service-de-la-medecine-predictive_3785935.html#xtor=RSS-3-[monde/europe]
#  - Texte: Tartu, Type: LOC, Span: (38, 43)
#  - Texte: Estonie, Type: LOC, Span: (65, 72)
#  - Texte: Biobank, Type: LOC, Span: (77, 84)
#  - Texte: Estoniens, Type: LOC, Span: (152, 161)
#  - Texte: Etat, Type: LOC, Span: (318, 322)
#  - Texte: Médecins, Type: ORG, Span: (351, 359)
#  - Texte: Biobank, Type: LOC, Span: (501, 508)
#  - Texte: Neeme Tönisson, Type: PER, Span: (869, 883)
#  - Texte: Européens, Type: LOC, Span: (1500, 1509)
#  - Texte: France 3, Type: ORG, Span: (1556, 1564)
# Article : https://www.francetvinfo.fr/monde/europe/video-l-estonie-est-le-premier-pays-europeen-a-s-etre-dote-d-ambulances-connectees-pour-le-bien-des-patients_3785827.html#xtor=RSS-3-[monde/europe]
#  - Texte: L'Estonie, Type: LOC, Span: (0, 9)
#  - Texte: Européens, Type: LOC, Span: (1307, 1316)
#  - Texte: France 3, Type: ORG, Span: (1363, 1371)
# Article : https://www.francetvinfo.fr/monde/espagne/eurozapping-une-mesure-choc-fait-debat-en-espagne-126-millions-de-cigarettes-saisies-en-belgique_3790315.html#xtor=RSS-3-[monde/europe]
#  - Texte: Espagne, Type: LOC, Span: (20, 27)
#  - Texte: Vox, Type: ORG, Span: (82, 85)
#  - Texte: région de Murcie, Type: LOC, Span: (90, 106)
#  - Texte: Genève, Type: LOC, Span: (441, 447)
#  - Texte: Saisie, Type: MISC, Span: (467, 473)
#  - Texte: Belgique, Type: LOC, Span: (513, 521)
#  - Texte: Asie du Sud-Est, Type: LOC, Span: (575, 590)
#  - Texte: Anvers, Type: LOC, Span: (749, 755)
#  - Texte: Europe, Type: LOC, Span: (818, 824)
#  - Texte: Genève, Type: LOC, Span: (860, 866)
#  - Texte: Suisse, Type: LOC, Span: (868, 874)
#  - Texte: JT, Type: ORG, Span: (1121, 1123)
#  - Texte: JT, Type: ORG, Span: (1146, 1148)
# Article : https://www.francetvinfo.fr/monde/video-megxit-c-est-tres-dur-pour-un-cadet-de-trouver-sa-place-affirme-une-fan-des-royals-a-propos-du-prince-harry_3790205.html#xtor=RSS-3-[monde/europe]
#  - Texte: Margaret Tyler, Type: PER, Span: (0, 14)
#  - Texte: Windsor, Type: PER, Span: (178, 185)
#  - Texte: Londres, Type: LOC, Span: (234, 241)
#  - Texte: prince Harry, Type: PER, Span: (312, 324)
#  - Texte: Megxit, Type: LOC, Span: (357, 363)
#  - Texte: William, Type: PER, Span: (390, 397)
#  - Texte: Sussex, Type: LOC, Span: (757, 763)
#  - Texte: Diana, Type: MISC, Span: (821, 826)
#  - Texte: Charles, Type: PER, Span: (911, 918)
#  - Texte: William, Type: PER, Span: (930, 937)
#  - Texte: George, Type: PER, Span: (972, 978)
#  - Texte: Charlotte, Type: PER, Span: (980, 989)
#  - Texte: Louis, Type: PER, Span: (993, 998)
#  - Texte: Diana, Type: MISC, Span: (1044, 1049)
#  - Texte: Londres, Type: LOC, Span: (1094, 1101)
#  - Texte: Eton, Type: LOC, Span: (1118, 1122)
#  - Texte: prince Harry, Type: PER, Span: (1127, 1139)
#  - Texte: Afghanistan, Type: LOC, Span: (1277, 1288)
#  - Texte: Meghan Markle, Type: PER, Span: (1419, 1432)
#  - Texte: Archie, Type: PER, Span: (1495, 1501)
#  - Texte: Philip Turle, Type: PER, Span: (1682, 1694)
#  - Texte: Harry, Type: PER, Span: (1844, 1849)
#  - Texte: Meghan, Type: PER, Span: (1853, 1859)
# Article : https://www.francetvinfo.fr/replay-radio/micro-europeen/micro-europeen-inebranlable-et-tres-conservatrice-pologne-souvent-opposee-a-bruxelles_3770157.html#xtor=RSS-3-[monde/europe]
#  - Texte: Zbigniew Ziobro, Type: MISC, Span: (0, 15)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (17, 35)
#  - Texte: Jaroslaw Gowin, Type: PER, Span: (40, 54)
#  - Texte: Droit et justice, Type: MISC, Span: (142, 158)
#  - Texte: PiS, Type: ORG, Span: (161, 164)
#  - Texte: GETTY IMAGES, Type: MISC, Span: (168, 180)
#  - Texte: La Pologne, Type: LOC, Span: (183, 193)
#  - Texte: Union européenne, Type: ORG, Span: (300, 316)
#  - Texte: 2015, Type: MISC, Span: (330, 334)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (364, 382)
#  - Texte: PiS, Type: ORG, Span: (386, 389)
#  - Texte: Droit et Justice, Type: ORG, Span: (392, 408)
#  - Texte: Président de la République, Type: PER, Span: (426, 452)
#  - Texte: Andrzej Duda, Type: PER, Span: (457, 469)
#  - Texte: Mateusz Morawiecki, Type: PER, Span: (473, 491)
#  - Texte: la Pologne, Type: LOC, Span: (539, 549)
#  - Texte: Visegrad, Type: LOC, Span: (574, 582)
#  - Texte: Hongrie, Type: LOC, Span: (603, 610)
#  - Texte: République tchèque, Type: LOC, Span: (615, 633)
#  - Texte: Slovaquie, Type: LOC, Span: (640, 649)
#  - Texte: Union européenne, Type: ORG, Span: (735, 751)
#  - Texte: Otan, Type: ORG, Span: (760, 764)
#  - Texte: Visegrad, Type: LOC, Span: (791, 799)
#  - Texte: Bruxelles, Type: LOC, Span: (848, 857)
#  - Texte: Visegrad, Type: LOC, Span: (878, 886)
#  - Texte: Pologne, Type: LOC, Span: (936, 943)
#  - Texte: Bohême, Type: LOC, Span: (945, 951)
#  - Texte: Hongrie, Type: LOC, Span: (955, 962)
#  - Texte: Habsbourg, Type: PER, Span: (1013, 1022)
#  - Texte: Pologne, Type: LOC, Span: (1089, 1096)
#  - Texte: Piotr Moszynski, Type: PER, Span: (1159, 1174)
#  - Texte: Gazeta Wyborcza, Type: ORG, Span: (1203, 1218)
#  - Texte: Pologne, Type: LOC, Span: (1242, 1249)
#  - Texte: Bruxelles, Type: LOC, Span: (1268, 1277)
#  - Texte: Union européenne, Type: ORG, Span: (1323, 1339)
#  - Texte: Varsovie, Type: LOC, Span: (1491, 1499)
#  - Texte: Varsovie, Type: LOC, Span: (1672, 1680)
#  - Texte: Bruxelles, Type: LOC, Span: (1684, 1693)
#  - Texte: PiS, Type: ORG, Span: (1727, 1730)
#  - Texte: Pologne, Type: LOC, Span: (2078, 2085)
#  - Texte: la Pologne, Type: LOC, Span: (2140, 2150)
#  - Texte: UE, Type: ORG, Span: (2172, 2174)
#  - Texte: Varsovie, Type: LOC, Span: (2200, 2208)
#  - Texte: Washington, Type: PER, Span: (2247, 2257)
#  - Texte: Varsovie, Type: LOC, Span: (2424, 2432)
#  - Texte: l’Europe, Type: LOC, Span: (2546, 2554)
#  - Texte: Varsovie, Type: LOC, Span: (2604, 2612)
#  - Texte: Bruxelles, Type: LOC, Span: (2731, 2740)
#  - Texte: Union, Type: ORG, Span: (2826, 2831)
#  - Texte: Andrzej Duda, Type: PER, Span: (2862, 2874)
#  - Texte: président de la République, Type: PER, Span: (2882, 2908)
#  - Texte: la Pologne, Type: LOC, Span: (2945, 2955)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (2979, 2997)
#  - Texte: PiS, Type: ORG, Span: (3014, 3017)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (3030, 3048)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (3135, 3153)
#  - Texte: PiS, Type: ORG, Span: (3168, 3171)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (3225, 3243)
#  - Texte: Varsovie, Type: LOC, Span: (3540, 3548)
#  - Texte: PiS, Type: ORG, Span: (3668, 3671)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (3681, 3699)
#  - Texte: Varsovie, Type: LOC, Span: (3767, 3775)
#  - Texte: Pologne, Type: LOC, Span: (3843, 3850)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (3938, 3956)
#  - Texte: PiS, Type: ORG, Span: (4003, 4006)
#  - Texte: Donald Tusk, Type: PER, Span: (4082, 4093)
#  - Texte: Conseil européen, Type: ORG, Span: (4117, 4133)
#  - Texte: Jaroslaw Kaczynski, Type: PER, Span: (4158, 4176)
#  - Texte: PiS, Type: ORG, Span: (4213, 4216)
#  - Texte: Pologne, Type: LOC, Span: (4278, 4285)
#  - Texte: Washington, Type: LOC, Span: (4379, 4389)
#  - Texte: Varsovie, Type: LOC, Span: (4424, 4432)
# Article : https://www.francetvinfo.fr/monde/europe/la-grande-bretagne-et-l-ue/les-cloches-de-big-ben-ne-sonneront-pas-pour-le-brexit-mais-un-decompte-geant-apparaitra-au-10-downing-street_3790099.html#xtor=RSS-3-[monde/europe]
#  - Texte: Royaume-Unis, Type: LOC, Span: (69, 81)
#  - Texte: Union européenne, Type: ORG, Span: (87, 103)
#  - Texte: Downing Street, Type: LOC, Span: (163, 177)
#  - Texte: Parlement, Type: ORG, Span: (270, 279)
#  - Texte: Big Ben, Type: LOC, Span: (295, 302)
#  - Texte: Boris Johnson, Type: PER, Span: (305, 318)
#  - Texte: Brexit, Type: ORG, Span: (358, 364)
#  - Texte: Big Ben, Type: MISC, Span: (439, 446)
#  - Texte: Royaume-Uni, Type: LOC, Span: (473, 484)
#  - Texte: Union européenne, Type: ORG, Span: (490, 506)
#  - Texte: Vendredi 17, Type: MISC, Span: (508, 519)
#  - Texte: Big Ben, Type: LOC, Span: (693, 700)
#  - Texte: Nouvel an, Type: ORG, Span: (879, 888)
#  - Texte: Big Ben, Type: LOC, Span: (975, 982)
#  - Texte: Parlement, Type: ORG, Span: (1191, 1200)
#  - Texte: Boris Johnson, Type: PER, Span: (1202, 1215)
#  - Texte: Brexit, Type: ORG, Span: (1237, 1243)
#  - Texte: Britanniques, Type: LOC, Span: (1380, 1392)
#  - Texte: Embarrassés, Type: MISC, Span: (1545, 1556)
#  - Texte: Premier ministre, Type: MISC, Span: (1574, 1590)
#  - Texte: Parlement, Type: ORG, Span: (1614, 1623)
#  - Texte: Big Ben, Type: LOC, Span: (1706, 1713)
#  - Texte: UE, Type: ORG, Span: (1769, 1771)
#  - Texte: Downing Street, Type: LOC, Span: (1829, 1843)
#  - Texte: Union Jack, Type: ORG, Span: (1921, 1931)
#  - Texte: Parlement, Type: ORG, Span: (1961, 1970)
# Article : https://www.francetvinfo.fr/monde/europe/la-grande-bretagne-et-l-ue/royaume-uni-faut-il-feter-le-brexit_3789225.html#xtor=RSS-3-[monde/europe]
#  - Texte: Brexit, Type: ORG, Span: (19, 25)
#  - Texte: Brexiters, Type: ORG, Span: (109, 118)
#  - Texte: Big Ben, Type: MISC, Span: (121, 128)
#  - Texte: Union européenne, Type: ORG, Span: (175, 191)
#  - Texte: Westminster, Type: LOC, Span: (213, 224)
#  - Texte: Britanniques, Type: LOC, Span: (418, 430)
#  - Texte: Boris Johnson, Type: PER, Span: (648, 661)
#  - Texte: Ça, Type: MISC, Span: (727, 729)
#  - Texte: JT, Type: ORG, Span: (841, 843)
#  - Texte: JT, Type: ORG, Span: (866, 868)
# Article : https://www.francetvinfo.fr/sante/drogue-addictions/belgique-les-douanes-font-une-saisie-record-de-126-millions-de-cigarettes-de-contrefacon_3788849.html#xtor=RSS-3-[monde/europe]
#  - Texte: Belgique, Type: LOC, Span: (174, 182)
#  - Texte: Anvers, Type: LOC, Span: (325, 331)
#  - Texte: Asie du Sud-Est, Type: LOC, Span: (525, 540)
#  - Texte: Rothmans Blue, Type: MISC, Span: (587, 600)
#  - Texte: John Player Special, Type: MISC, Span: (602, 621)
#  - Texte: em@il, Type: MISC, Span: (625, 630)
#  - Texte: Stabroek, Type: LOC, Span: (841, 849)
#  - Texte: Anvers, Type: LOC, Span: (888, 894)
#  - Texte: Brecht, Type: PER, Span: (1096, 1102)
#  - Texte: Anvers, Type: LOC, Span: (1110, 1116)
#  - Texte: TVA, Type: ORG, Span: (1372, 1375)
# Article : https://www.francetvinfo.fr/monde/italie/italie-des-impots-alleges-pour-les-retraites-europeens_3788911.html#xtor=RSS-3-[monde/europe]
#  - Texte: L'Italie, Type: LOC, Span: (0, 8)
#  - Texte: Lucia Gugliermo, Type: PER, Span: (478, 493)
#  - Texte: ville de, Type: LOC, Span: (518, 526)
#  - Texte: Paris, Type: LOC, Span: (527, 532)
#  - Texte: Français, Type: LOC, Span: (578, 586)
#  - Texte: Italie, Type: LOC, Span: (603, 609)
#  - Texte: France, Type: LOC, Span: (722, 728)
#  - Texte: Italie, Type: LOC, Span: (765, 771)
#  - Texte: Pouilles, Type: LOC, Span: (834, 842)
#  - Texte: la France, Type: LOC, Span: (889, 898)
#  - Texte: Claudine Kichenin, Type: PER, Span: (995, 1012)
# Article : https://www.francetvinfo.fr/monde/europe/la-grande-bretagne-et-l-ue/big-ben-va-t-elle-sonner-pour-le-brexit-le-debat-divise-les-britanniques_3788655.html#xtor=RSS-3-[monde/europe]
#  - Texte: Brexiters, Type: ORG, Span: (149, 158)
#  - Texte: Union européenne, Type: ORG, Span: (201, 217)
#  - Texte: Sonner, Type: PER, Span: (235, 241)
#  - Texte: Brexit, Type: ORG, Span: (303, 309)
#  - Texte: Union européenne, Type: ORG, Span: (326, 342)
#  - Texte: Britanniques, Type: LOC, Span: (368, 380)
#  - Texte: Big Ben, Type: MISC, Span: (433, 440)
#  - Texte: Nouvel An, Type: ORG, Span: (708, 717)
#  - Texte: Brexit, Type: ORG, Span: (744, 750)
#  - Texte: Union européenne, Type: ORG, Span: (791, 807)
#  - Texte: Big Ben, Type: MISC, Span: (886, 893)
#  - Texte: Chambre des communes, Type: LOC, Span: (1013, 1033)
#  - Texte: Lindsay Hoyle, Type: PER, Span: (1035, 1048)
#  - Texte: Premier ministre, Type: MISC, Span: (1058, 1074)
#  - Texte: Boris Johnson, Type: PER, Span: (1075, 1088)
#  - Texte: Brexit, Type: ORG, Span: (1110, 1116)
#  - Texte: Daily Express, Type: ORG, Span: (1352, 1365)
#  - Texte: Big Ben, Type: LOC, Span: (1411, 1418)
#  - Texte: Brexit, Type: ORG, Span: (1441, 1447)
#  - Texte: Downing Street, Type: LOC, Span: (1450, 1464)
#  - Texte: Brexiters, Type: ORG, Span: (1498, 1507)
#  - Texte: Parlement, Type: ORG, Span: (1533, 1542)
#  - Texte: La Une du Daily Express, Type: MISC, Span: (1627, 1650)
#  - Texte: Big Ben, Type: LOC, Span: (1668, 1675)
#  - Texte: Brexit, Type: MISC, Span: (1697, 1703)
#  - Texte: Alexander Seale, Type: PER, Span: (1735, 1750)
#  - Texte: January 15, Type: MISC, Span: (1764, 1774)
#  - Texte: Mark François, Type: PER, Span: (1865, 1878)
#  - Texte: Brexit, Type: ORG, Span: (2084, 2090)
#  - Texte: Nigel Farage, Type: PER, Span: (2136, 2148)
#  - Texte: Union européenne, Type: ORG, Span: (2200, 2216)
#  - Texte: Union européenne, Type: ORG, Span: (2320, 2336)
#  - Texte: Big Ben, Type: MISC, Span: (2393, 2400)
#  - Texte: Nouvel An, Type: MISC, Span: (2461, 2470)
# Article : https://www.francetvinfo.fr/monde/europe/migrants/l-espagne-aura-besoin-de-millions-et-de-millions-de-migrants-dans-les-prochaines-annees-estime-un-ministre-espagnol_3788059.html#xtor=RSS-3-[monde/europe]
#  - Texte: Ca, Type: LOC, Span: (42, 44)
#  - Texte: ministre de la Sécurité sociale, Type: ORG, Span: (93, 124)
#  - Texte: L'Espagne, Type: LOC, Span: (161, 170)
#  - Texte: José Luis Escriva, Type: PER, Span: (264, 281)
#  - Texte: Sécurité sociale, Type: ORG, Span: (307, 323)
#  - Texte: Forum de l'OCDE, Type: ORG, Span: (570, 585)
#  - Texte: Paris, Type: LOC, Span: (608, 613)
#  - Texte: France, Type: LOC, Span: (983, 989)
#  - Texte: Retraites, Type: LOC, Span: (1058, 1067)
#  - Texte: Jean-Paul Delevoye, Type: PER, Span: (1068, 1086)
#  - Texte: Europe, Type: LOC, Span: (1280, 1286)
#  - Texte: Ca, Type: LOC, Span: (1340, 1342)
#  - Texte: Commissaire européenne, Type: ORG, Span: (1788, 1810)
#  - Texte: Ylva Johansson, Type: PER, Span: (1836, 1850)
#  - Texte: Union européenne, Type: ORG, Span: (2428, 2444)
#  - Texte: Ca, Type: LOC, Span: (2486, 2488)
#  - Texte: Ylva Johansson, Type: PER, Span: (2575, 2589)
# Article : https://www.francetvinfo.fr/replay-radio/un-monde-d-avance/l-economie-allemande-au-bord-de-la-panne_3767811.html#xtor=RSS-3-[monde/europe]
#  - Texte: Hambach, Type: LOC, Span: (31, 38)
#  - Texte: Allemagne, Type: LOC, Span: (58, 67)
#  - Texte: INA FASSBENDER, Type: ORG, Span: (70, 84)
#  - Texte: AFP, Type: ORG, Span: (87, 90)
#  - Texte: Allemagne, Type: LOC, Span: (95, 104)
#  - Texte: la France, Type: LOC, Span: (400, 409)
#  - Texte: BMW, Type: ORG, Span: (1061, 1064)
#  - Texte: Volkswagen, Type: ORG, Span: (1066, 1076)
#  - Texte: Daimler, Type: ORG, Span: (1078, 1085)
#  - Texte: Angela Merkel, Type: PER, Span: (1334, 1347)
#  - Texte: Donald Trump, Type: PER, Span: (1365, 1377)
#  - Texte: Donald Trump, Type: PER, Span: (1883, 1895)
#  - Texte: la Chine, Type: LOC, Span: (1992, 2000)
#  - Texte: Européens, Type: LOC, Span: (2008, 2017)
#  - Texte: États-Unis, Type: LOC, Span: (2234, 2244)
#  - Texte: Allemagne, Type: LOC, Span: (2318, 2327)
#  - Texte: Berlin, Type: LOC, Span: (2329, 2335)
#  - Texte: Europe, Type: LOC, Span: (2394, 2400)
#  - Texte: États-Unis, Type: LOC, Span: (2401, 2411)
#  - Texte: Allemagne, Type: LOC, Span: (2470, 2479)
#  - Texte: Allemagne, Type: LOC, Span: (2774, 2783)
#  - Texte: Berlin, Type: LOC, Span: (2976, 2982)
# Article : https://www.francetvinfo.fr/monde/europe/la-grande-bretagne-et-l-ue/desintox-non-le-brexit-ne-va-pas-mettre-fin-au-programme-erasmus-au-royaume-uni-pour-le-moment_3787321.html#xtor=RSS-3-[monde/europe]
#  - Texte: Brexit, Type: ORG, Span: (3, 9)
#  - Texte: Royaume-Uni, Type: LOC, Span: (46, 57)
#  - Texte: Manche, Type: LOC, Span: (205, 211)
#  - Texte: Chambre des Communes, Type: LOC, Span: (246, 266)
#  - Texte: Erasmus, Type: ORG, Span: (310, 317)
#  - Texte: France, Type: LOC, Span: (322, 328)
#  - Texte: Alex Taylor, Type: PER, Span: (364, 375)
#  - Texte: Grande Bretagne, Type: LOC, Span: (445, 460)
#  - Texte: Erasmus, Type: ORG, Span: (524, 531)
#  - Texte: MoDem, Type: ORG, Span: (557, 562)
#  - Texte: Erasmus, Type: ORG, Span: (621, 628)
#  - Texte: Royaume-Uni, Type: LOC, Span: (671, 682)
#  - Texte: Union Européenne, Type: ORG, Span: (839, 855)
#  - Texte: Erasmus, Type: ORG, Span: (891, 898)
#  - Texte: Brexit, Type: ORG, Span: (929, 935)
#  - Texte: Bruxelles, Type: LOC, Span: (1057, 1066)
#  - Texte: ministre britannique de l’, Type: ORG, Span: (1072, 1098)
#  - Texte: Enseignement supérieur, Type: ORG, Span: (1098, 1120)
#  - Texte: Royaume-Uni, Type: LOC, Span: (1276, 1287)
#  - Texte: Erasmus, Type: ORG, Span: (1316, 1323)
#  - Texte: Union Européenne, Type: ORG, Span: (1346, 1362)
#  - Texte: Union Européenne, Type: ORG, Span: (1448, 1464)
#  - Texte: Erasmus, Type: ORG, Span: (1499, 1506)
#  - Texte: Brexit, Type: ORG, Span: (1526, 1532)
#  - Texte: Minutes, Type: MISC, Span: (1678, 1685)
#  - Texte: Arte, Type: ORG, Span: (1690, 1694)
#  - Texte: Elisabeth Quin, Type: PER, Span: (1710, 1724)
#  - Texte: Facebook :, Type: MISC, Span: (1731, 1741)
#  - Texte: YouTube, Type: MISC, Span: (1783, 1790)
#  - Texte: Instagram, Type: LOC, Span: (1841, 1850)
#  - Texte: https://www.instagram.com/artedesintox/, Type: LOC, Span: (1853, 1892)
#  - Texte: Arte, Type: LOC, Span: (1908, 1912)
#  - Texte: http://28minutes.arte.tv/, Type: LOC, Span: (1915, 1940)
# Article : https://www.francetvinfo.fr/sciences/espace/exomars/2020-annee-de-la-conquete-de-mars_3787313.html#xtor=RSS-3-[monde/europe]
#  - Texte: La Terre, Type: LOC, Span: (155, 163)
#  - Texte: Mars, Type: LOC, Span: (167, 171)
#  - Texte: Mars 2020, Type: MISC, Span: (323, 332)
#  - Texte: États-Unis, Type: LOC, Span: (338, 348)
#  - Texte: Curiosity, Type: MISC, Span: (393, 402)
#  - Texte: Mars, Type: LOC, Span: (421, 425)
#  - Texte: Mars, Type: LOC, Span: (496, 500)
#  - Texte: Terre, Type: LOC, Span: (641, 646)
#  - Texte: ExoMars, Type: MISC, Span: (738, 745)
#  - Texte: Huoxing 1 des Chinois, Type: MISC, Span: (831, 852)
#  - Texte: Émirats arabes unis, Type: LOC, Span: (961, 980)
#  - Texte: Mars, Type: LOC, Span: (1019, 1023)
#  - Texte: Hope, Type: ORG, Span: (1061, 1065)
#  - Texte: Sylvestre Maurice, Type: PER, Span: (1084, 1101)
#  - Texte: Mars, Type: LOC, Span: (1146, 1150)
#  - Texte: JT, Type: ORG, Span: (1216, 1218)
#  - Texte: JT, Type: ORG, Span: (1241, 1243)
# Article : https://www.francetvinfo.fr/culture/jeux-video/eurozapping-une-francaise-vendue-a-des-rappeurs-puis-prostituee-les-jeux-video-reconnus-en-norvege_3787299.html#xtor=RSS-3-[monde/europe]
#  - Texte: Belgique, Type: LOC, Span: (65, 73)
#  - Texte: Bruxelles, Type: LOC, Span: (119, 128)
#  - Texte: Françaises, Type: LOC, Span: (316, 326)
#  - Texte: Sicile, Type: LOC, Span: (381, 387)
#  - Texte: Sicile, Type: LOC, Span: (637, 643)
#  - Texte: Italie, Type: LOC, Span: (645, 651)
#  - Texte: Norvège, Type: LOC, Span: (744, 751)
#  - Texte: JT, Type: ORG, Span: (1010, 1012)
#  - Texte: JT, Type: ORG, Span: (1035, 1037)
# Article : https://www.francetvinfo.fr/replay-radio/en-direct-du-monde/en-allemagne-les-deputes-doivent-voter-une-loi-sur-le-don-d-organes-qui-prevoit-le-consentement-presume_3767415.html#xtor=RSS-3-[monde/europe]
#  - Texte: ministre de la Santé allemand, Type: ORG, Span: (3, 32)
#  - Texte: Jens Spahn, Type: PER, Span: (33, 43)
#  - Texte: Berlin, Type: LOC, Span: (47, 53)
#  - Texte: RONNY, Type: MISC, Span: (77, 82)
#  - Texte: HARTMANN, Type: ORG, Span: (83, 91)
#  - Texte: AFP, Type: ORG, Span: (94, 97)
#  - Texte: Bundestag, Type: ORG, Span: (115, 124)
#  - Texte: Berlin, Type: LOC, Span: (155, 161)
#  - Texte: ministre de la Santé, Type: ORG, Span: (197, 217)
#  - Texte: Jens Spahn, Type: PER, Span: (218, 228)
#  - Texte: France, Type: LOC, Span: (524, 530)
#  - Texte: Allemagne, Type: LOC, Span: (586, 595)
#  - Texte: ministre de la Santé, Type: ORG, Span: (766, 786)
#  - Texte: Jens Spahn, Type: PER, Span: (788, 798)
#  - Texte: Allemagne, Type: LOC, Span: (991, 1000)
#  - Texte: la France, Type: LOC, Span: (1024, 1033)
#  - Texte: Espagne, Type: LOC, Span: (1090, 1097)
#  - Texte: CDU, Type: ORG, Span: (1322, 1325)
#  - Texte: ministre de la Santé, Type: ORG, Span: (1339, 1359)
#  - Texte: CSU, Type: ORG, Span: (1428, 1431)
#  - Texte: Allemagne, Type: LOC, Span: (1478, 1487)
#  - Texte: Constitution, Type: ORG, Span: (1573, 1585)
#  - Texte: des Verts, Type: ORG, Span: (1990, 1999)
#  - Texte: Die Linke, Type: ORG, Span: (2045, 2054)
#  - Texte: ministre de la Santé, Type: ORG, Span: (2365, 2385)
#  - Texte: Jens Spahn, Type: PER, Span: (2386, 2396)
#  - Texte: Allemagne, Type: LOC, Span: (2580, 2589)
#  - Texte: Jens Spahn, Type: PER, Span: (2833, 2843)
#  - Texte: Allemands, Type: LOC, Span: (3067, 3076)
# Article : https://www.francetvinfo.fr/monde/europe/la-grande-bretagne-et-l-ue/irlande-des-elections-anticipees-auront-lieu-le-8-fevrier-apres-la-date-prevue-du-brexit_3784683.html#xtor=RSS-3-[monde/europe]
#  - Texte: L'Irlande, Type: LOC, Span: (0, 9)
#  - Texte: Royaume-Uni, Type: LOC, Span: (61, 72)
#  - Texte: Union européenne, Type: ORG, Span: (78, 94)
#  - Texte: Premier ministre, Type: MISC, Span: (179, 195)
#  - Texte: Leo Varadkar, Type: PER, Span: (206, 218)
#  - Texte: Royaume-Uni, Type: LOC, Span: (376, 387)
#  - Texte: Union européenne, Type: ORG, Span: (393, 409)
#  - Texte: république d'Irlande, Type: LOC, Span: (415, 435)
#  - Texte: Brexit, Type: ORG, Span: (555, 561)
#  - Texte: Irlandais, Type: LOC, Span: (829, 838)
#  - Texte: Royaume-Uni, Type: LOC, Span: (885, 896)
#  - Texte: Leo Varadkar, Type: PER, Span: (1024, 1036)
#  - Texte: Fine Gael, Type: ORG, Span: (1052, 1061)
#  - Texte: Fianna Fail, Type: ORG, Span: (1088, 1099)
#  - Texte: Brexit, Type: ORG, Span: (1122, 1128)
#  - Texte: UE, Type: ORG, Span: (1253, 1255)
#  - Texte: Irlande, Type: LOC, Span: (1269, 1276)
#  - Texte: Royaume-Uni, Type: LOC, Span: (1284, 1295)
#  - Texte: L'Irlande, Type: LOC, Span: (1382, 1391)
#  - Texte: Royaume-Uni, Type: LOC, Span: (1447, 1458)
#  - Texte: Londres, Type: LOC, Span: (1841, 1848)
#  - Texte: Bruxelles, Type: LOC, Span: (1852, 1861)
# Article : https://www.francetvinfo.fr/culture/patrimoine/histoire/des-arbres-ont-ils-vraiment-ete-plantes-de-facon-a-former-une-croix-gammee-vue-du-ciel-en-allemagne_3782759.html#xtor=RSS-3-[monde/europe]
#  - Texte: Twitter, Type: MISC, Span: (284, 291)
#  - Texte: IIIe Reich, Type: ORG, Span: (356, 366)
#  - Texte: Nord, Type: LOC, Span: (596, 600)
#  - Texte: Allemagne, Type: LOC, Span: (606, 615)
#  - Texte: Nazisme, Type: MISC, Span: (693, 700)
#  - Texte: Croix Nazie, Type: ORG, Span: (845, 856)
#  - Texte: Bouteflikov, Type: PER, Span: (887, 898)
#  - Texte: January 12, Type: LOC, Span: (915, 925)
#  - Texte: Brandebourg, Type: LOC, Span: (1052, 1063)
#  - Texte: Berlin, Type: LOC, Span: (1076, 1082)
#  - Texte: Der Spiegel, Type: MISC, Span: (1157, 1168)
#  - Texte: Zernikow, Type: LOC, Span: (1257, 1265)
#  - Texte: Jeunesses hitlériennes, Type: ORG, Span: (1853, 1875)
#  - Texte: Adolf Hitler, Type: PER, Span: (1931, 1943)
#  - Texte: Spiegel, Type: MISC, Span: (2067, 2074)
#  - Texte: Zernikow, Type: LOC, Span: (2313, 2321)
#  - Texte: Allemagne, Type: LOC, Span: (2349, 2358)
#  - Texte: Helmut Kohl, Type: PER, Span: (2391, 2402)
#  - Texte: BBC, Type: ORG, Span: (2623, 2626)
#  - Texte: Reuters, Type: ORG, Span: (2708, 2715)
#  - Texte: ministère de l'Agriculture du Brandebourg, Type: ORG, Span: (2761, 2802)
#  - Texte: CNN, Type: ORG, Span: (2905, 2908)
#  - Texte: Allemagne, Type: LOC, Span: (3247, 3256)
#  - Texte: Spiegel, Type: MISC, Span: (3267, 3274)
#  - Texte: Hesse, Type: PER, Span: (3302, 3307)
#  - Texte: Adolf Hitler, Type: PER, Span: (3450, 3462)
#  - Texte: Le Point, Type: ORG, Span: (3473, 3481)
#  - Texte: Kirghizistan, Type: LOC, Span: (3575, 3587)
#  - Texte: Asie centrale, Type: LOC, Span: (3592, 3605)
#  - Texte: New York Times, Type: ORG, Span: (3627, 3641)
#  - Texte: Tash-Bashat, Type: LOC, Span: (3690, 3701)
#  - Texte: Seconde Guerre mondiale, Type: MISC, Span: (3848, 3871)
#  - Texte: Staline, Type: PER, Span: (4243, 4250)
#  - Texte: New York Times, Type: ORG, Span: (4264, 4278)
#  - Texte: mont Giano, Type: LOC, Span: (4339, 4349)
#  - Texte: Italie, Type: LOC, Span: (4351, 4357)
#  - Texte: Benito Mussolini, Type: PER, Span: (4406, 4422)
#  - Texte: TONY, Type: MISC, Span: (4425, 4429)
#  - Texte: GENTILE, Type: ORG, Span: (4430, 4437)
#  - Texte: REUTERS, Type: ORG, Span: (4440, 4447)
#  - Texte: Italien, Type: LOC, Span: (4585, 4592)
#  - Texte: Benito Mussolini, Type: PER, Span: (4593, 4609)
#  - Texte: DVX, Type: ORG, Span: (4683, 4686)
#  - Texte: mont Giano, Type: LOC, Span: (4742, 4752)
#  - Texte: Rome, Type: LOC, Span: (4766, 4770)
#  - Texte: Deutsche Welle, Type: MISC, Span: (4856, 4870)
#  - Texte: Etats-Unis, Type: LOC, Span: (4989, 4999)
#  - Texte: mont Rushmore, Type: LOC, Span: (5062, 5075)
#  - Texte: Dakota du Sud, Type: LOC, Span: (5077, 5090)
#  - Texte: mont Sokda, Type: LOC, Span: (5195, 5205)
#  - Texte: Corée du Nord, Type: LOC, Span: (5210, 5223)
#  - Texte: Kim Jong-il, Type: PER, Span: (5257, 5268)
# Article : https://www.francetvinfo.fr/monde/afrique/libye/libye-le-president-turc-erdogan-promet-d-infliger-une-lecon-au-marechal-haftar-s-il-reprend-ses-attaques_3784301.html#xtor=RSS-3-[monde/europe]
#  - Texte: Moscou, Type: LOC, Span: (38, 44)
#  - Texte: Fayez al-Sarraj, Type: PER, Span: (105, 120)
#  - Texte: Gouvernement libyen, Type: PER, Span: (130, 149)
#  - Texte: ONU, Type: ORG, Span: (164, 167)
#  - Texte: GNA, Type: ORG, Span: (169, 172)
#  - Texte: Haftar la leçon, Type: PER, Span: (227, 242)
#  - Texte: Libye, Type: LOC, Span: (340, 345)
#  - Texte: Recep Tayyip Erdogan, Type: PER, Span: (395, 415)
#  - Texte: ONU, Type: ORG, Span: (504, 507)
#  - Texte: GNA, Type: ORG, Span: (509, 512)
#  - Texte: Fayez al-Sarraj, Type: LOC, Span: (514, 529)
#  - Texte: Khalifa Haftar, Type: PER, Span: (533, 547)
#  - Texte: Tripoli, Type: LOC, Span: (616, 623)
#  - Texte: Moscou, Type: LOC, Span: (690, 696)
#  - Texte: Fayez al-Sarraj, Type: PER, Span: (820, 835)
#  - Texte: Ankara, Type: LOC, Span: (992, 998)
#  - Texte: Sarraj, Type: PER, Span: (1008, 1014)
#  - Texte: Moscou, Type: LOC, Span: (1057, 1063)
#  - Texte: Haftar, Type: PER, Span: (1113, 1119)
#  - Texte: Turquie, Type: LOC, Span: (1212, 1219)
#  - Texte: Ankara, Type: LOC, Span: (1498, 1504)
#  - Texte: Moscou, Type: LOC, Span: (1508, 1514)
#  - Texte: Moscou, Type: LOC, Span: (1518, 1524)
#  - Texte: Syrie, Type: LOC, Span: (1548, 1553)
#  - Texte: Moyen-Orient, Type: MISC, Span: (1597, 1609)
#  - Texte: Libye, Type: LOC, Span: (1661, 1666)
#  - Texte: Russie, Type: LOC, Span: (1830, 1836)
#  - Texte: Vladimir Poutine, Type: PER, Span: (1904, 1920)
#  - Texte: Afrique, Type: LOC, Span: (1951, 1958)
#  - Texte: Turquie, Type: LOC, Span: (1964, 1971)
#  - Texte: GNA, Type: ORG, Span: (2048, 2051)
#  - Texte: Méditerranée, Type: LOC, Span: (2161, 2173)
#  - Texte: Berlin, Type: LOC, Span: (2188, 2194)
#  - Texte: conférence de Moscou, Type: MISC, Span: (2222, 2242)
#  - Texte: Libye, Type: LOC, Span: (2338, 2343)
#  - Texte: ONU, Type: ORG, Span: (2369, 2372)
#  - Texte: Berlin, Type: LOC, Span: (2375, 2381)
#  - Texte: Allemands, Type: LOC, Span: (2407, 2416)
#  - Texte: Berlin, Type: LOC, Span: (2483, 2489)
#  - Texte: Turquie, Type: LOC, Span: (2531, 2538)
#  - Texte: Allemagne, Type: LOC, Span: (2542, 2551)
#  - Texte: France, Type: LOC, Span: (2556, 2562)
#  - Texte: Grande-Bretagne, Type: LOC, Span: (2567, 2582)
#  - Texte: Russie, Type: LOC, Span: (2587, 2593)
#  - Texte: Italie, Type: LOC, Span: (2597, 2603)
#  - Texte: Egypte, Type: LOC, Span: (2607, 2613)
#  - Texte: Algérie, Type: LOC, Span: (2617, 2624)
#  - Texte: Emirats arabes unis, Type: LOC, Span: (2632, 2651)
#  - Texte: Recep Tayyip Erdogan, Type: MISC, Span: (2664, 2684)
#  - Texte: Moscou, Type: LOC, Span: (2737, 2743)
#  - Texte: Vladimir Poutine, Type: PER, Span: (2798, 2814)
#  - Texte: Angela Merkel, Type: PER, Span: (2818, 2831)
#  - Texte: Moscou, Type: LOC, Span: (2949, 2955)
#  - Texte: Libye, Type: LOC, Span: (2976, 2981)
#  - Texte: Haftar, Type: PER, Span: (3049, 3055)
#  - Texte: Turquie, Type: LOC, Span: (3135, 3142)
#  - Texte: GNA, Type: ORG, Span: (3199, 3202)
#  - Texte: Turquie, Type: LOC, Span: (3310, 3317)
#  - Texte: Haftar, Type: PER, Span: (3356, 3362)
# Article : https://www.francetvinfo.fr/economie/emploi/carriere/entreprendre/creation-d-entreprise/economie-l-activite-fragile-des-autoentrepreneurs_3788041.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: Français, Type: LOC, Span: (284, 292)
#  - Texte: Amélie Serri, Type: PER, Span: (637, 649)
#  - Texte: Atelier Français, Type: LOC, Span: (667, 683)
#  - Texte: JT, Type: ORG, Span: (1014, 1016)
#  - Texte: JT, Type: ORG, Span: (1039, 1041)
# Article : https://www.francetvinfo.fr/economie/emploi/carriere/entreprendre/creation-d-entreprise/economie-les-creations-d-entreprises-en-forte-hausse_3787715.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: Amélie Serri, Type: PER, Span: (195, 207)
#  - Texte: Atelier Français, Type: LOC, Span: (225, 241)
#  - Texte: Nice, Type: LOC, Span: (386, 390)
#  - Texte: Alpes-Maritimes, Type: LOC, Span: (392, 407)
#  - Texte: Français, Type: LOC, Span: (851, 859)
#  - Texte: JT, Type: ORG, Span: (938, 940)
#  - Texte: JT, Type: ORG, Span: (963, 965)
# Article : https://www.francetvinfo.fr/economie/transports/sncf/greve-a-la-sncf/greve-une-majorite-des-entreprises-franciliennes-ont-propose-des-solutions-a-leurs-employes_3787291.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: Paris, Type: LOC, Span: (223, 228)
#  - Texte: la France, Type: LOC, Span: (257, 266)
#  - Texte: VTC, Type: ORG, Span: (715, 718)
#  - Texte: JT, Type: ORG, Span: (1033, 1035)
#  - Texte: JT, Type: ORG, Span: (1058, 1060)
# Article : https://www.francetvinfo.fr/replay-radio/l-interview-eco/le-slip-francais-dans-la-tourmente-un-impact-economique-pour-lentreprise_3766695.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: Guillaume Gibault, Type: PER, Span: (0, 17)
#  - Texte: franceinfo, Type: ORG, Span: (23, 33)
#  - Texte: FRANCEINFO, Type: ORG, Span: (57, 67)
#  - Texte: Le Slip Français, Type: ORG, Span: (153, 169)
#  - Texte: France, Type: LOC, Span: (249, 255)
#  - Texte: franceinfo mercredi, Type: ORG, Span: (333, 352)
#  - Texte: Guillaume Gibault, Type: PER, Span: (380, 397)
#  - Texte: Viva Africa, Type: ORG, Span: (774, 785)
#  - Texte: Slip Français, Type: ORG, Span: (891, 904)
#  - Texte: Guillaume Gibault, Type: PER, Span: (935, 952)
#  - Texte: Guillaume Gibault, Type: PER, Span: (1510, 1527)
#  - Texte: Slip Français, Type: ORG, Span: (1542, 1555)
#  - Texte: franceinfo
#
# , Type: ORG, Span: (1560, 1572)
#  - Texte: Guillaume Gibault, Type: PER, Span: (1796, 1813)
#  - Texte: Le Slip Français, Type: MISC, Span: (1963, 1979)
#  - Texte: Guillaume Gibault, Type: PER, Span: (2187, 2204)
# Article : https://www.francetvinfo.fr/economie/emploi/metiers/droit-et-justice/ardeche-lecole-privee-la-ferme-des-enfants-de-sophie-rabhi-epinglee-par-les-prudhommes-pour-travail-dissimule_3786121.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: Sophie Rabhi, Type: PER, Span: (42, 54)
#  - Texte: Prud'hommes, Type: LOC, Span: (235, 246)
#  - Texte: La ferme des enfants de Lablachère, Type: MISC, Span: (277, 311)
#  - Texte: Ardèche, Type: LOC, Span: (313, 320)
#  - Texte: Sophie Rabhi, Type: PER, Span: (349, 361)
#  - Texte: Aubenas, Type: LOC, Span: (444, 451)
#  - Texte: France Bleu, Type: ORG, Span: (479, 490)
#  - Texte: Aubenas, Type: LOC, Span: (662, 669)
#  - Texte: Pôle Emploi, Type: LOC, Span: (1018, 1029)
#  - Texte: La ferme des enfants, Type: MISC, Span: (1121, 1141)
#  - Texte: Sophie Rabhi, Type: PER, Span: (1858, 1870)
#  - Texte: Pierre Rabhi, Type: PER, Span: (1884, 1896)
# Article : https://www.francetvinfo.fr/economie/entreprises/haute-loire-dans-la-derniere-usine-de-lavage-de-laine-en-france_3780493.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: la France, Type: LOC, Span: (290, 299)
#  - Texte: République tchèque, Type: LOC, Span: (394, 412)
#  - Texte: Italie, Type: LOC, Span: (416, 422)
#  - Texte: Belgique, Type: LOC, Span: (427, 435)
#  - Texte: Chine, Type: LOC, Span: (442, 447)
#  - Texte: Bruyères, Type: LOC, Span: (802, 810)
#  - Texte: JT, Type: ORG, Span: (955, 957)
#  - Texte: JT, Type: ORG, Span: (980, 982)
# Article : https://www.francetvinfo.fr/economie/entreprises/crowdfunding-en-entreprise-quand-les-consommateurs-s-impliquent_3780425.html#xtor=RSS-3-[economie/entreprises]
#  - Texte: Guillaume Mariller, Type: PER, Span: (160, 178)
#  - Texte: Seb, Type: PER, Span: (582, 585)
# ...
#  - Texte: Whirlpool, Type: ORG, Span: (230, 239)
#  - Texte: Seb, Type: PER, Span: (241, 244)
#  - Texte: Smeg, Type: PER, Span: (246, 250)
#  - Texte: Whirlpool, Type: LOC, Span: (252, 261)
#  - Texte: Boulanger, Type: LOC, Span: (263, 272)
#  - Texte: Darty, Type: ORG, Span: (274, 279)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (285, 311)
#  - Texte: Franceinfo, Type: LOC, Span: (898, 908)
#  - Texte: Seb, Type: PER, Span: (1020, 1023)
#  - Texte: Whirlpool, Type: ORG, Span: (1092, 1101)
#  - Texte: Indesit, Type: LOC, Span: (1277, 1284)
#  - Texte: BSH, Type: ORG, Span: (1342, 1345)
#  - Texte: Siemens, Type: ORG, Span: (1366, 1373)
#  - Texte: Bosch, Type: PER, Span: (1377, 1382)
#  - Texte: Electrolux, Type: ORG, Span: (1537, 1547)
#  - Texte: Candy Hoover, Type: PER, Span: (1573, 1585)
#  - Texte: LG, Type: ORG, Span: (1604, 1606)
#  - Texte: Miele, Type: PER, Span: (1624, 1629)
#  - Texte: Smeg, Type: LOC, Span: (1648, 1652)
#  - Texte: Eberhardt, Type: LOC, Span: (1671, 1680)
#  - Texte: Darty, Type: ORG, Span: (1712, 1717)
#  - Texte: Boulanger, Type: PER, Span: (1721, 1730)
#  - Texte: Darty, Type: ORG, Span: (2143, 2148)
#  - Texte: Boulanger, Type: PER, Span: (2152, 2161)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (2344, 2370)
#  - Texte: internet, Type: MISC, Span: (2519, 2527)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (2572, 2598)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (3430, 3456)
#  - Texte: BSH, Type: ORG, Span: (3885, 3888)
#  - Texte: Whirlpool, Type: ORG, Span: (3890, 3899)
#  - Texte: Indesit, Type: LOC, Span: (3901, 3908)
#  - Texte: Electrolux, Type: ORG, Span: (3910, 3920)
#  - Texte: Candy Hoover, Type: PER, Span: (3922, 3934)
#  - Texte: Eberhardt Frères, Type: PER, Span: (3938, 3954)
#  - Texte: Darty, Type: ORG, Span: (4072, 4077)
#  - Texte: Boulanger, Type: PER, Span: (4081, 4090)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (4096, 4122)
#  - Texte: Darty, Type: ORG, Span: (4135, 4140)
#  - Texte: Boulanger, Type: PER, Span: (4144, 4153)
#  - Texte: Autorité de la concurrence dans un communiqué, Type: ORG, Span: (4802, 4847)
#  - Texte: Darty, Type: ORG, Span: (4864, 4869)
#  - Texte: Boulanger, Type: PER, Span: (4873, 4882)
#  - Texte: Autorité, Type: ORG, Span: (5152, 5160)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (5238, 5264)
#  - Texte: Autorité, Type: ORG, Span: (5765, 5773)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (6356, 6382)
#  - Texte: Fnac Darty, Type: ORG, Span: (6415, 6425)
#  - Texte: Electrolux, Type: ORG, Span: (6675, 6685)
#  - Texte: Boulanger, Type: MISC, Span: (6802, 6811)
#  - Texte: Seb, Type: PER, Span: (6828, 6831)
#  - Texte: Autorité, Type: ORG, Span: (6933, 6941)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (7093, 7119)
#  - Texte: Seb, Type: PER, Span: (7122, 7125)
#  - Texte: Boulanger, Type: PER, Span: (7302, 7311)
#  - Texte: X, Type: ORG, Span: (7449, 7450)
#  - Texte: Paris, Type: LOC, Span: (7574, 7579)
# Article : https://www.francetvinfo.fr/economie/entreprises/des-geants-de-l-electromenager-vont-devoir-payer-611-millions-d-euros-d-amendes-pour-des-ententes-sur-les-prix_6964664.html#xtor=RSS-3-[general]
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (257, 283)
#  - Texte: BSH, Type: ORG, Span: (379, 382)
#  - Texte: Candy Hoover, Type: PER, Span: (384, 396)
#  - Texte: Eberhardt, Type: PER, Span: (398, 407)
#  - Texte: Electrolux, Type: ORG, Span: (409, 419)
#  - Texte: Indesit, Type: ORG, Span: (421, 428)
#  - Texte: LG, Type: ORG, Span: (430, 432)
#  - Texte: Miele, Type: PER, Span: (434, 439)
#  - Texte: SEB, Type: PER, Span: (441, 444)
#  - Texte: Smeg, Type: PER, Span: (446, 450)
#  - Texte: Whirlpool, Type: LOC, Span: (452, 461)
#  - Texte: Boulanger, Type: LOC, Span: (463, 472)
#  - Texte: Darty, Type: ORG, Span: (476, 481)
#  - Texte: SEB, Type: PER, Span: (813, 816)
#  - Texte: internet, Type: MISC, Span: (891, 899)
#  - Texte: Darty, Type: ORG, Span: (1040, 1045)
#  - Texte: Boulanger, Type: PER, Span: (1049, 1058)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (1113, 1139)
#  - Texte: Fnac Darty, Type: ORG, Span: (1341, 1351)
#  - Texte: Autorité de la concurrence, Type: ORG, Span: (1515, 1541)
#  - Texte: SEB, Type: ORG, Span: (1615, 1618)
#  - Texte: SEB, Type: PER, Span: (1760, 1763)
#  - Texte: Paris, Type: LOC, Span: (1827, 1832)
#  - Texte: Electrolux, Type: ORG, Span: (1950, 1960)
# Article : https://www.francetvinfo.fr/replay-radio/le-brief-eco/une-alliance-se-prepare-entre-les-constructeurs-automobiles-japonais-honda-et-nissan_6936284.html#xtor=RSS-3-[general]
#  - Texte: Honda, Type: ORG, Span: (19, 24)
#  - Texte: Nissan, Type: ORG, Span: (83, 89)
#  - Texte: Mitsubishi Motors, Type: ORG, Span: (120, 137)
#  - Texte: Nissan, Type: ORG, Span: (143, 149)
#  - Texte: Honda, Type: ORG, Span: (204, 209)
#  - Texte: Nissan, Type: ORG, Span: (213, 219)
#  - Texte: Toyota, Type: ORG, Span: (336, 342)
#  - Texte: Volkswagen, Type: ORG, Span: (357, 367)
#  - Texte: Nissan, Type: ORG, Span: (691, 697)
#  - Texte: Honda, Type: ORG, Span: (968, 973)
#  - Texte: General Motors, Type: ORG, Span: (1021, 1035)
#  - Texte: Mitsubichi Motors, Type: ORG, Span: (1142, 1159)
#  - Texte: Honda, Type: ORG, Span: (1309, 1314)
#  - Texte: Nissan, Type: ORG, Span: (1316, 1322)
#  - Texte: Mitsubishi Motors, Type: ORG, Span: (1326, 1343)
#  - Texte: Tesla, Type: ORG, Span: (1363, 1368)
#  - Texte: Japon, Type: LOC, Span: (1663, 1668)
#  - Texte: la Chine, Type: LOC, Span: (1811, 1819)
#  - Texte: le Japon, Type: LOC, Span: (1832, 1840)
#  - Texte: Elon Musk, Type: PER, Span: (1925, 1934)
#  - Texte: BYD, Type: ORG, Span: (2001, 2004)
#  - Texte: Hyundai, Type: ORG, Span: (2022, 2029)
#  - Texte: Honda, Type: ORG, Span: (2056, 2061)
#  - Texte: Renault, Type: ORG, Span: (2370, 2377)
#  - Texte: Bourse de Nissan, Type: ORG, Span: (2466, 2482)
# Article : https://www.francetvinfo.fr/economie/entreprises/fermeture-d-usine-des-clients-s-estiment-leses-apres-la-liquidation-de-mister-menuiserie_6962960.html#xtor=RSS-3-[general]
#  - Texte: L. Franchineau, Type: PER, Span: (12, 26)
#  - Texte: M. Renier, Type: PER, Span: (28, 37)
#  - Texte: D. Chevalier, Type: PER, Span: (39, 51)
#  - Texte: C. Arnold, Type: PER, Span: (53, 62)
#  - Texte: A. Husser
#
# Fermeture, Type: PER, Span: (64, 84)
#  - Texte: Mister Menuiserie
#
# Temps, Type: PER, Span: (148, 172)
#  - Texte: Mister Menuiserie, Type: PER, Span: (271, 288)
#  - Texte: Christophe Schoenberg, Type: PER, Span: (426, 447)
#  - Texte: Durrenentzen, Type: LOC, Span: (487, 499)
#  - Texte: Haut-Rhin, Type: LOC, Span: (501, 510)
#  - Texte: Mister Menuiserie, Type: PER, Span: (691, 708)
#  - Texte: Christophe Schoenberg, Type: PER, Span: (1004, 1025)
#  - Texte: Mister Menuiserie, Type: PER, Span: (1297, 1314)
#  - Texte: Covid-19, Type: MISC, Span: (1389, 1397)
# Article : https://www.francetvinfo.fr/economie/entreprises/fermeture-d-usine-en-normandie-la-marque-historique-cafes-legal-met-la-cle-sous-la-porte_6962876.html#xtor=RSS-3-[general]
#  - Texte: Normandie, Type: LOC, Span: (23, 32)
#  - Texte: Cafés Legal, Type: ORG, Span: (56, 67)
#  - Texte: du Havre, Type: LOC, Span: (132, 140)
#  - Texte: Cafés Legal, Type: ORG, Span: (143, 154)
#  - Texte: du Havre, Type: LOC, Span: (284, 292)
#  - Texte: Seine-Maritime, Type: LOC, Span: (294, 308)
#  - Texte: Cafés Legal, Type: ORG, Span: (333, 344)
#  - Texte: Julien Schmaltz, Type: PER, Span: (617, 632)
#  - Texte: Legal, Type: ORG, Span: (669, 674)
#  - Texte: Noël, Type: MISC, Span: (822, 826)
#  - Texte: Thomas Thierry, Type: PER, Span: (846, 860)
#  - Texte: Legal, Type: LOC, Span: (891, 896)
#  - Texte: au Havre, Type: LOC, Span: (1025, 1033)
#  - Texte: Covid-19, Type: MISC, Span: (1233, 1241)
# Article : https://www.francetvinfo.fr/replay-radio/les-informes-du-matin/la-relation-macron-bayrou-l-appel-du-patronat-et-des-syndicats-les-informes-du-matin-du-mercredi-18-decembre_6934433.html#xtor=RSS-3-[general]
#  - Texte: Emmanuel Macron, Type: PER, Span: (14, 29)
#  - Texte: François Bayrou, Type: PER, Span: (33, 48)
#  - Texte: Premier ministre, Type: MISC, Span: (146, 162)
#  - Texte: Élysée, Type: LOC, Span: (316, 322)
#  - Texte: Emmanuel Macron, Type: PER, Span: (324, 339)
#  - Texte: Bruxelles, Type: LOC, Span: (372, 381)
#  - Texte: Mayotte, Type: LOC, Span: (406, 413)
#  - Texte: Édito, Type: MISC, Span: (484, 489)
#  - Texte: Emmanuel Macron, Type: PER, Span: (570, 585)
#  - Texte: François Bayrou, Type: PER, Span: (589, 604)
#  - Texte: Victoria Koussa, Type: PER, Span: (1016, 1031)
#  - Texte: franceinfo, Type: ORG, Span: (1069, 1079)
#  - Texte: Mathieu Gallard, Type: PER, Span: (1081, 1096)
#  - Texte: institut Ipsos, Type: ORG, Span: (1121, 1135)
#  - Texte: Jean-Claude Mailly, Type: PER, Span: (1137, 1155)
#  - Texte: Force Ouvrière, Type: ORG, Span: (1186, 1200)
# Article : https://www.francetvinfo.fr/replay-radio/le-brief-eco/la-crise-immobiliere-fait-plonger-le-secteur-du-batiment_6934442.html#xtor=RSS-3-[general]
#  - Texte: Fédération française du bâtiment, Type: ORG, Span: (132, 164)
#  - Texte: France, Type: LOC, Span: (642, 648)
#  - Texte: BTP, Type: ORG, Span: (670, 673)
#  - Texte: Olivier Salleron, Type: PER, Span: (1263, 1279)
#  - Texte: FFB, Type: ORG, Span: (1297, 1300)
#  - Texte: la France, Type: LOC, Span: (1405, 1414)
#  - Texte: Assemblée nationale, Type: ORG, Span: (1664, 1683)
# Article : https://www.francetvinfo.fr/economie/entreprises/l-entreprise-cafes-legal-situee-au-havre-en-liquidation-judiciaire-les-110-salaries-licencies_6961214.html#xtor=RSS-3-[general]
#  - Texte: Cafés Legal, Type: ORG, Span: (13, 24)
#  - Texte: Havre, Type: LOC, Span: (35, 40)
#  - Texte: Seine-Maritime, Type: LOC, Span: (42, 56)
#  - Texte: Paris, Type: LOC, Span: (126, 131)
#  - Texte: France Bleu Normandie, Type: LOC, Span: (160, 181)
#  - Texte: Michel Ohayon, Type: PER, Span: (398, 411)
#  - Texte: Cafés Legal, Type: ORG, Span: (716, 727)
#  - Texte: du Havre, Type: LOC, Span: (904, 912)
#  - Texte: Normandie, Type: LOC, Span: (1278, 1287)
#  - Texte: Paris, Type: LOC, Span: (1383, 1388)
#  - Texte: du Havre, Type: LOC, Span: (1417, 1425)
#  - Texte: Cafés Legal, Type: ORG, Span: (1663, 1674)
# Article : https://www.francetvinfo.fr/economie/energie/energies-renouvelables-il-va-falloir-simplifier-les-procedures-pour-accelerer-la-decarbonation-estime-la-directrice-france-de-totalenergies_6960404.html#xtor=RSS-3-[general]
#  - Texte: France, Type: LOC, Span: (12, 18)
#  - Texte: Total, Type: ORG, Span: (74, 79)
#  - Texte: Patrick Pouyanné, Type: PER, Span: (80, 96)
#  - Texte: Isabelle Patrier, Type: PER, Span: (133, 149)
#  - Texte: TotalEnergies, Type: ORG, Span: (275, 288)
#  - Texte: Isabelle Patrier, Type: PER, Span: (290, 306)
#  - Texte: France Bleu Nord, Type: ORG, Span: (330, 346)
#  - Texte: Total, Type: ORG, Span: (391, 396)
#  - Texte: Patrick Pouyanné, Type: PER, Span: (397, 413)
#  - Texte: France, Type: LOC, Span: (455, 461)
#  - Texte: Isabelle Patrier, Type: PER, Span: (497, 513)
#  - Texte: TotalEnergies, Type: ORG, Span: (541, 554)
#  - Texte: Isabelle Patrier, Type: PER, Span: (868, 884)
#  - Texte: France, Type: LOC, Span: (897, 903)
#  - Texte: TotalEnergies, Type: ORG, Span: (907, 920)
#  - Texte: France Bleu Nord, Type: LOC, Span: (923, 939)
#  - Texte: TotalEnergies, Type: ORG, Span: (971, 984)
#  - Texte: France, Type: LOC, Span: (1268, 1274)
#  - Texte: Patrick Pouyanné, Type: PER, Span: (1295, 1311)
#  - Texte: États-Unis, Type: LOC, Span: (1384, 1394)
#  - Texte: Allemagne, Type: LOC, Span: (1401, 1410)
#  - Texte: France, Type: LOC, Span: (1424, 1430)
#  - Texte: pays France, Type: LOC, Span: (1477, 1488)
#  - Texte: Isabelle Patrier, Type: PER, Span: (1569, 1585)
#  - Texte: France, Type: LOC, Span: (1804, 1810)
#  - Texte: TotalEnergies, Type: ORG, Span: (1873, 1886)
#  - Texte: Isabelle Patrier, Type: PER, Span: (2176, 2192)
#  - Texte: Isabelle Patrier, Type: PER, Span: (2481, 2497)
#  - Texte: Total Energies, Type: ORG, Span: (2517, 2531)
#  - Texte: parc nucléaire français, Type: LOC, Span: (2569, 2592)
# Article : https://www.francetvinfo.fr/replay-radio/le-brief-eco/le-japonais-softbank-annonce-investir-cent-milliards-de-dollars-aux-etats-unis_6932525.html#xtor=RSS-3-[general]
#  - Texte: SoftBank, Type: ORG, Span: (33, 41)
#  - Texte: Donald Trump, Type: PER, Span: (51, 63)
#  - Texte: États-Unis, Type: LOC, Span: (162, 172)
#  - Texte: Europe, Type: LOC, Span: (179, 185)
#  - Texte: États-Unis, Type: LOC, Span: (291, 301)
#  - Texte: Maison-Blanche, Type: LOC, Span: (382, 396)
#  - Texte: SoftBank Corporation, Type: ORG, Span: (416, 436)
#  - Texte: YahooBB, Type: MISC, Span: (593, 600)
#  - Texte: Yahoo, Type: ORG, Span: (639, 644)
#  - Texte: Japon, Type: LOC, Span: (648, 653)
#  - Texte: Trump, Type: PER, Span: (731, 736)
#  - Texte: SoftBank, Type: ORG, Span: (746, 754)
#  - Texte: Donald Trump, Type: PER, Span: (884, 896)
#  - Texte: Tokyo, Type: LOC, Span: (911, 916)
#  - Texte: l’Amérique, Type: LOC, Span: (992, 1002)
#  - Texte: Chine, Type: LOC, Span: (1070, 1075)
#  - Texte: SoftBank, Type: MISC, Span: (1218, 1226)
#  - Texte: Intelligence Artificielle, Type: ORG, Span: (1282, 1307)
#  - Texte: NVidia, Type: MISC, Span: (1427, 1433)
#  - Texte: États-Unis, Type: LOC, Span: (1487, 1497)
#  - Texte: Trump, Type: PER, Span: (1647, 1652)
#  - Texte: Le Japon, Type: LOC, Span: (1726, 1734)
#  - Texte: Tokyo, Type: LOC, Span: (1777, 1782)
#  - Texte: Microsoft, Type: ORG, Span: (1943, 1952)
#  - Texte: Amazon, Type: ORG, Span: (1954, 1960)
#  - Texte: Google, Type: ORG, Span: (1964, 1970)
#  - Texte: Japon, Type: LOC, Span: (2023, 2028)
#  - Texte: Washington, Type: LOC, Span: (2066, 2076)
#  - Texte: Tokyo, Type: LOC, Span: (2080, 2085)
#  - Texte: l’Europe, Type: LOC, Span: (2116, 2124)
# Article : https://www.francetvinfo.fr/economie/entreprises/duralex-le-succes-de-la-boutique-des-salaries-a-orleans_6958724.html#xtor=RSS-3-[general]
#  - Texte: Duralex, Type: LOC, Span: (19, 26)
#  - Texte: Orléans, Type: LOC, Span: (66, 73)
#  - Texte: Loiret, Type: LOC, Span: (83, 89)
#  - Texte: Duralex, Type: LOC, Span: (201, 208)
#  - Texte: Orléans, Type: LOC, Span: (248, 255)
#  - Texte: Loiret, Type: LOC, Span: (265, 271)
#  - Texte: Orléans, Type: LOC, Span: (382, 389)
#  - Texte: Loiret, Type: LOC, Span: (391, 397)
#  - Texte: Duralex, Type: PER, Span: (421, 428)
#  - Texte: Orléanaise, Type: LOC, Span: (594, 604)
#  - Texte: Noël, Type: MISC, Span: (627, 631)
#  - Texte: Ahmed Terristi, Type: PER, Span: (803, 817)
#  - Texte: Ça, Type: MISC, Span: (968, 970)
#  - Texte: État, Type: LOC, Span: (1250, 1254)
# Article : https://www.francetvinfo.fr/replay-radio/le-decryptage-eco/la-france-creuse-son-deficit-a-6-en-2024-une-tendance-qui-pourrait-se-prolonger-en-2025_6930737.html#xtor=RSS-3-[general]
#  - Texte: Assemblée nationale, Type: ORG, Span: (51, 70)
#  - Texte: François Bayrou, Type: PER, Span: (247, 262)
#  - Texte: Parlement, Type: ORG, Span: (336, 345)
#  - Texte: État, Type: LOC, Span: (431, 435)
#  - Texte: François Bayrou, Type: PER, Span: (540, 555)
#  - Texte: Budget, Type: PER, Span: (611, 617)
#  - Texte: l'État français, Type: LOC, Span: (745, 760)
#  - Texte: Barnier, Type: PER, Span: (810, 817)
#  - Texte: Morgan Stanley, Type: PER, Span: (892, 906)
#  - Texte: TVA, Type: ORG, Span: (1265, 1268)
#  - Texte: Michel Barnier, Type: PER, Span: (1423, 1437)
#  - Texte: Laurent Saint Martin, Type: PER, Span: (1902, 1922)
#  - Texte: la France, Type: LOC, Span: (2056, 2065)
#  - Texte: Europe, Type: LOC, Span: (2115, 2121)
#  - Texte: Moody', Type: ORG, Span: (2294, 2300)
#  - Texte: François Bayrou, Type: PER, Span: (2328, 2343)
#  - Texte: Moody', Type: ORG, Span: (2513, 2519)
#  - Texte: François Bayrou, Type: PER, Span: (2577, 2592)
# Article : https://www.francetvinfo.fr/replay-radio/ca-nous-marque/bioderma-le-secteur-de-la-dermocosmetique-est-en-croissance-de-pres-de-8_6927266.html#xtor=RSS-3-[general]
#  - Texte: Bioderma, Type: MISC, Span: (163, 171)
#  - Texte: Jean-Noël Thorel, Type: PER, Span: (270, 286)
#  - Texte: David Durand, Type: PER, Span: (604, 616)
#  - Texte: Naos, Type: LOC, Span: (649, 653)
#  - Texte: Bioderma, Type: LOC, Span: (671, 679)
#  - Texte: David Durand, Type: PER, Span: (1034, 1046)
#  - Texte: Aix-en-Provence, Type: LOC, Span: (1535, 1550)
#  - Texte: la France, Type: LOC, Span: (1567, 1576)
#  - Texte: David Durand, Type: PER, Span: (1578, 1590)

# %%
# Affichage des résultats
print("Top 20 des entités globales (toutes catégories):")
top_20_df = pd.DataFrame(top_20_entites, columns=["Entité", "Fréquence"])
top_20_df.head(20)
# Out:
# Top 20 des entités globales (toutes catégories):
#               Entité  Fréquence
# 0                 JT       2082
# 1             France        811
# 2           Covid-19        790
# 3          Allemagne        569
# 4           Français        412
# 5          la France        399
# 6              Paris        380
# 7         franceinfo        365
# 8             Europe        332
# 9   Union européenne        325
# 10              État        297
# 11       Royaume-Uni        260
# 12            Italie        256
# 13   Emmanuel Macron        254
# 14              Etat        237
# 15            Brexit        232
# 16                UE        220
# 17             Chine        203
# 18             Grèce        203
# 19          l'Europe        201

# %%
print("\nTop 20 des entités de type PERSONNE:")
top_20_personnes_df = pd.DataFrame(top_20_personnes, columns=["Personne", "Fréquence"])
top_20_personnes_df.head(20)
# Out:
# Top 20 des entités de type PERSONNE:
#                       Personne  Fréquence
# 0              Emmanuel Macron        254
# 1               Bruno Le Maire        123
# 2                Angela Merkel        118
# 3   président de la République         63
# 4                Boris Johnson         55
# 5           Laurent Desbonnets         50
# 6              Muriel Pénicaud         48
# 7               Thierry Breton         44
# 8         Ursula von der Leyen         41
# 9                 Donald Trump         40
# 10            Edouard Philippe         37
# 11                    Birkenau         35
# 12               Olivier Véran         33
# 13            Vladimir Poutine         30
# 14                       César         27
# 15                George Floyd         27
# 16              Michel Barnier         26
# 17              Valéry Lerouge         26
# 18         Christophe Castaner         24
# 19              Jérôme Salomon         24

# %%
print("\nTop 20 des entités de type LIEU:")
top_20_lieux_df = pd.DataFrame(top_20_lieux, columns=["Lieu", "Fréquence"])
top_20_lieux_df.head(20)
# Out:
# Top 20 des entités de type LIEU:
#            Lieu  Fréquence
# 0        France        811
# 1     Allemagne        569
# 2     la France        399
# 3         Paris        380
# 4      Français        339
# 5        Europe        332
# 6          État        297
# 7   Royaume-Uni        260
# 8        Italie        256
# 9          Etat        237
# 10        Chine        203
# 11        Grèce        202
# 12     l'Europe        201
# 13      Turquie        167
# 14    Bruxelles        158
# 15      Londres        141
# 16       Berlin        135
# 17      Espagne        132
# 18    Européens        119
# 19   Franceinfo        113

# %%
print("\nTop 20 des entités de type ORGANISATION:")
top_20_organisations_df = pd.DataFrame(top_20_organisations, columns=["Organisation", "Fréquence"])
top_20_organisations_df.head(20)
# Out:
# Top 20 des entités de type ORGANISATION:
#              Organisation  Fréquence
# 0                      JT       2082
# 1              franceinfo        361
# 2        Union européenne        325
# 3                  Brexit        226
# 4                      UE        220
# 5                     AFP        159
# 6      France Télévisions        128
# 7   Commission européenne        108
# 8                 Renault         96
# 9                  MAXPPP         78
# 10                    CGT         73
# 11              Magazines         67
# 12                 Alstom         62
# 13   ministre de la Santé         61
# 14                 Amazon         56
# 15                 Airbus         49
# 16                   LREM         48
# 17                  Medef         46
# 18              Parlement         43
# 19                Travail         42

# %% [markdown]
# ### 1. **Top 20 des entités globales (toutes catégories confondues)**
#
# Les entités globales incluent un large éventail de termes, notamment des noms géographiques, des concepts politiques et des événements sociaux. Voici quelques observations clés :
#
# - **Les entités liées à l'actualité** : Des termes comme **"Covid-19"** (790 occurrences) et **"Brexit"** (232 occurrences) sont des entités très fréquentes, ce qui reflète l'importance de ces événements mondiaux dans les discussions actuelles.
# - **La France et l'Europe** : Des mentions récurrentes de **"France"**, **"Paris"**, **"Europe"**, et **"Union européenne"** montrent que les articles analysés se concentrent principalement sur la politique, la géopolitique et les affaires européennes. **"la France"** et **"l'Europe"** (201 occurrences) sont également mentionnées fréquemment, ce qui suggère une focalisation sur des enjeux régionaux.
# - **Autres mentions géopolitiques** : **"Allemagne"** (569 occurrences), **"Chine"** (203 occurrences), **"Royaume-Uni"** (260 occurrences), et **"Italie"** (256 occurrences) témoignent des relations internationales importantes, notamment dans le contexte économique et politique européen.
# - **Personnalités publiques et organisations** : Des termes comme **"Emmanuel Macron"** (254 occurrences), **"franceinfo"** (365 occurrences), et **"Covid-19"** (790 occurrences) apparaissent régulièrement, ce qui reflète leur présence notable dans les discussions médiatiques.
#
# Ces entités indiquent que la collection de documents traite principalement des questions politiques, sociales et internationales, avec une forte concentration sur les événements liés à la pandémie de Covid-19, aux questions économiques et aux enjeux géopolitiques.
#
# ---
#
# ### 2. **Top 20 des entités de type PERSONNE**
#
# Les entités de type **"personne"** montrent principalement des figures politiques et publiques. Voici quelques points saillants :
#
# - **Les leaders politiques** : Les personnalités les plus fréquentes incluent des figures majeures comme **"Emmanuel Macron"** (254 occurrences), **"Angela Merkel"** (118 occurrences), **"Boris Johnson"** (55 occurrences), et **"Vladimir Poutine"** (30 occurrences). Cela reflète probablement l'importance des dirigeants politiques dans les débats et discussions sur des sujets tels que la politique nationale et internationale, le Covid-19, et la gestion des crises.
# - **Les ministres et autres personnalités** : Des figures comme **"Bruno Le Maire"** (123 occurrences), **"Laurent Desbonnets"** (50 occurrences), **"Muriel Pénicaud"** (48 occurrences), et **"Thierry Breton"** (44 occurrences) soulignent l'importance des ministres et responsables d'État dans la gestion des affaires publiques et des politiques économiques.
# - **Références indirectes** : Des mentions comme **"président de la République"** (63 occurrences) et **"César"** (27 occurrences) suggèrent aussi une représentation symbolique ou indirecte de figures politiques et historiques.
#
# Cela montre que les documents analysés se concentrent principalement sur les figures politiques et les personnalités associées à des événements géopolitiques, économiques ou sociaux majeurs.
#
# ---
#
# ### 3. **Top 20 des entités de type LIEU**
#
# Les entités de type **"lieu"** montrent une forte présence des pays et des régions européennes, ce qui est cohérent avec les entités globales analysées.
#
# - **Les pays européens** : **"France"** (810 occurrences), **"Allemagne"** (569 occurrences), **"Italie"** (256 occurrences), **"Royaume-Uni"** (260 occurrences), **"Grèce"** (202 occurrences), et **"Espagne"** (132 occurrences) sont des lieux fréquemment mentionnés, ce qui indique que les documents traitent largement des questions politiques, sociales et économiques au sein de l'Europe.
# - **L'Europe dans son ensemble** : Des mentions comme **"Europe"** (332 occurrences) et **"l'Europe"** (201 occurrences) témoignent de l'importance de la région dans les discussions mondiales, notamment concernant la politique et l'intégration européenne.
# - **Les capitales et grandes villes** : **"Paris"** (380 occurrences), **"Bruxelles"** (158 occurrences), **"Londres"** (141 occurrences), et **"Berlin"** (135 occurrences) sont des lieux stratégiques, soulignant probablement leur importance dans les décisions politiques et économiques prises au niveau de l'UE et sur la scène mondiale.
#
# Les lieux mentionnés sont majoritairement européens, avec une concentration particulière sur les grandes capitales et les discussions liées à l'UE, la politique et les crises géopolitiques.
#
# ---
#
# ### 4. **Top 20 des entités de type ORGANISATION**
#
# Les entités de type **"organisation"** font ressortir des groupes médiatiques, des institutions politiques et des entreprises majeures, illustrant les structures influentes dans les domaines politique, économique et médiatique. Voici quelques observations :
#
# - **Les médias et organisations médiatiques** : Des entités comme **"JT"** (2082 occurrences), **"franceinfo"** (361 occurrences), et **"France Télévisions"** (128 occurrences) dominent, reflétant l'importance des chaînes de télévision et des organisations médiatiques dans la diffusion des informations. La mention récurrente de **"franceinfo"** indique un rôle important dans la couverture médiatique des sujets analysés.
# - **Les institutions politiques et européennes** : **"Union européenne"** (325 occurrences), **"Commission européenne"** (108 occurrences), et **"Parlement"** (41 occurrences) montrent que les discussions sont souvent centrées sur les décisions et les politiques de l'UE, ainsi que sur les discussions au niveau européen.
# - **Les entreprises et organisations économiques** : Des entités comme **"Renault"** (96 occurrences), **"Airbus"** (49 occurrences), **"Alstom"** (62 occurrences), et **"Amazon"** (56 occurrences) soulignent la présence de grandes entreprises dans les discussions économiques. Cela peut être lié à des questions de politique industrielle, de croissance économique et de compétitivité internationale.
# - **Les syndicats et organisations sociales** : La mention de la **"CGT"** (73 occurrences), un syndicat français majeur, et de **"Medef"** (46 occurrences), une organisation patronale, témoigne des préoccupations sociales et des tensions économiques, en particulier en France.
#
# Les organisations extraites indiquent un mélange d'acteurs médiatiques, politiques et économiques, mettant en évidence les préoccupations sur les politiques publiques, les débats économiques et les enjeux sociaux dans la collection de documents.
#
# ---
#
# ### Conclusion générale :
#
# Les résultats montrent que la collection de documents est fortement orientée autour des **questions géopolitiques** et **économiques** internationales, notamment celles liées à l'Europe et à la gestion de crises mondiales comme la pandémie de **Covid-19**. Les figures politiques de premier plan, notamment les présidents français et allemands, ainsi que des événements géopolitiques majeurs (comme le **Brexit** et les relations avec la **Chine**), dominent les entités extraites.
#
# L'accent mis sur les **lieux européens**, les **organisations médiatiques**, ainsi que les **personnalités politiques** et les **organisations économiques** reflète l'intérêt pour la politique, l'économie et les relations internationales, particulièrement au sein de l'UE. Ce type d'analyse peut aider à mieux comprendre les thématiques traitées dans les documents et à identifier les principaux acteurs et lieux impliqués dans les discussions de cette période.

# %% [markdown]
# ### Question 10

# %%
def count_co_occurrences(entity1, type1, entity2, type2, resultats):
    """
    Fonction qui compte le nombre de co-occurrences de deux entités données dans un même document.
    
    Parameters:
    entity1 (str) : Le texte de la première entité.
    type1 (str) : Le type de la première entité.
    entity2 (str) : Le texte de la deuxième entité.
    type2 (str) : Le type de la deuxième entité.
    resultats (dict) : Dictionnaire contenant les entités extraites pour chaque article.

    Returns:
    int : Le nombre de co-occurrences des deux entités dans un même document.
    """
    co_occurrences = 0
    
    # Parcours de tous les documents dans le résultat
    for doc_entities in resultats.values():
        # Extraire les entités du document et leur type
        entities_in_doc = [(ent['text'], ent['type']) for ent in doc_entities]
        
        # Vérifier si les deux entités (et leurs types respectifs) apparaissent dans le même document
        found_entity1 = any(ent[0] == entity1 and ent[1] == type1 for ent in entities_in_doc)
        found_entity2 = any(ent[0] == entity2 and ent[1] == type2 for ent in entities_in_doc)
        
        # Si les deux entités sont présentes dans le document, augmenter le compteur de co-occurrences
        if found_entity1 and found_entity2:
            co_occurrences += 1
    
    return co_occurrences

# %%
co_occurrences_count = count_co_occurrences("Emmanuel Macron", "PER", "France", "LOC", resultats)
print(f"Nombre de co-occurrences de 'Emmanuel Macron' et 'France' : {co_occurrences_count}")
# Out:
# Nombre de co-occurrences de 'Emmanuel Macron' et 'France' : 46

# %%
co_occurrences_count = count_co_occurrences("François Bayrou", "PER", "Mayotte", "LOC", resultats)

# Affichage du résultat
print(f"Nombre de co-occurrences de 'François Bayrou' et 'Mayotte' : {co_occurrences_count}")
# Out:
# Nombre de co-occurrences de 'François Bayrou' et 'Mayotte' : 4

# %% [markdown]
# ### 1. Nombre de co-occurrences de **'Emmanuel Macron'** et **'France'** : **46**
#
# **Interprétation** :
# - **'Emmanuel Macron'** est une figure politique très médiatisée, étant le président actuel de la République française. Le nom de **'Emmanuel Macron'** est donc souvent mentionné dans le contexte de la **France**, que ce soit en relation avec ses décisions politiques, ses déplacements, ses discours ou ses actions à l'échelle nationale.
# - Le nombre relativement élevé de **46 co-occurrences** reflète le fait qu'il est fréquemment associé au pays dans de nombreux documents et articles d'actualité. Dans un grand nombre de textes politiques, économiques, ou sociaux, **'Emmanuel Macron'** et **'France'** apparaissent ensemble, ce qui est typique des articles sur la politique française, les réformes ou les événements nationaux.
#
# **Conclusion** :
# - Ces 46 co-occurrences montrent que la relation entre **Emmanuel Macron** et **la France** est étroite dans les sources d'actualités analysées. Cela peut également refléter une couverture médiatique particulièrement orientée vers les actions du président à l'échelle nationale.
#
# ### 2. Nombre de co-occurrences de **'François Bayrou'** et **'Mayotte'** : **4**
#
# **Interprétation** :
# - **'François Bayrou'** est une personnalité politique française, mais sa relation avec **Mayotte** est plus spécifique. Bayrou est parfois mentionné dans le cadre de ses prises de position ou de ses actions concernant les départements d'outre-mer, et Mayotte, en tant que territoire français, peut être un sujet ponctuel dans ses discours ou dans certaines politiques publiques.
# - Le nombre relativement faible de **4 co-occurrences** montre que **François Bayrou** et **Mayotte** ne sont pas fréquemment associés dans les documents analysés. Cela peut suggérer que soit les sujets impliquant **François Bayrou** ne portent pas souvent sur **Mayotte**, soit que **Mayotte** est relativement moins médiatisée dans le contexte politique de **François Bayrou**.
#
# **Conclusion** :
# - Les 4 co-occurrences peuvent signifier que l'association entre **François Bayrou** et **Mayotte** est limitée à des événements ou des décisions ponctuelles. **François Bayrou** pourrait avoir mentionné **Mayotte** dans des discours ou projets spécifiques, mais ce n'est pas un thème récurrent dans l'actualité le concernant.
#
# ### Comparaison des résultats :
# - Le contraste entre les deux nombres (46 et 4) montre clairement que **'Emmanuel Macron'** et **'France'** sont beaucoup plus fréquemment associés dans les documents analysés, ce qui est logique au regard de la position centrale d'Emmanuel Macron dans la politique française et de la couverture médiatique constante qui l'entoure.
# - En revanche, l'association entre **'François Bayrou'** et **'Mayotte'** est plus marginale et spécifique, ce qui est à la fois un reflet de son rôle plus restreint dans les affaires concernant ce territoire particulier, et peut-être aussi de l'importance moins médiatisée de Mayotte dans l'actualité politique liée à **François Bayrou**.
#
# ### Synthèse :
# - **Emmanuel Macron** est une figure nationale avec une couverture médiatique omniprésente en lien avec la France, ce qui explique les 46 co-occurrences.
# - **François Bayrou** et **Mayotte** sont davantage liés à des sujets spécifiques, et leur association dans les documents est plus marginale, d'où le faible nombre de 4 co-occurrences.

# %% [markdown]
# ### Question 11

# %%
from collections import Counter

# Dictionnaire pour stocker les co-occurrences
co_occurrences = Counter()

# Fonction pour compter les co-occurrences entre paires d'entités de types différents
def count_co_occurrences(entities):
    # On utilise un dictionnaire pour stocker les entités par type
    entity_types = defaultdict(list)
    for ent in entities:
        entity_types[ent['type']].append(ent['text'])
    
    # Calcul des co-occurrences entre entités de types différents
    for type1, entities_type1 in entity_types.items():
        for type2, entities_type2 in entity_types.items():
            if type1 != type2:  # On ne compte que les entités de types différents
                for ent1 in entities_type1:
                    for ent2 in entities_type2:
                        co_occurrences[(ent1, ent2)] += 1

# Analyser toutes les entités extraites
for article_url, entities in entities_by_article.items():
    count_co_occurrences(entities)

# Afficher les 10 paires d'entités les plus fréquentes
top_co_occurrences = co_occurrences.most_common(10)
for pair, count in top_co_occurrences:
    print(f"Paire : {pair} -> Co-occurrences : {count}")
# Out:
# Paire : ('Auschwitz', 'Birkenau') -> Co-occurrences : 994
# Paire : ('Birkenau', 'Auschwitz') -> Co-occurrences : 994
# Paire : ('Covid-19', 'JT') -> Co-occurrences : 720
# Paire : ('JT', 'Covid-19') -> Co-occurrences : 720
# Paire : ('Royaume-Uni', 'Brexit') -> Co-occurrences : 661
# Paire : ('Brexit', 'Royaume-Uni') -> Co-occurrences : 661
# Paire : ('ANCV', 'ANCV') -> Co-occurrences : 608
# Paire : ('ANCV', 'État') -> Co-occurrences : 598
# Paire : ('État', 'ANCV') -> Co-occurrences : 598
# Paire : ('Allemagne', 'JT') -> Co-occurrences : 528

# %% [markdown]
# ### Commentaire des résultats :
#
# 1. **Paire ('Auschwitz', 'Birkenau') et ('Birkenau', 'Auschwitz')** -> **Co-occurrences : 994**
#
#    - Ces deux entités sont souvent mentionnées ensemble, ce qui est très logique étant donné qu'**Auschwitz** et **Birkenau** désignent deux sites principaux du camp de concentration nazi pendant la Seconde Guerre mondiale, situés dans la même région et souvent associés ensemble dans les discussions historiques. Leur co-occurrence élevée peut être liée aux commémorations, aux documents historiques et aux articles éducatifs ou d'actualité relatifs à l'histoire de la Shoah.
#
# 2. **Paire ('Covid-19', 'JT') et ('JT', 'Covid-19')** -> **Co-occurrences : 720**
#
#    - Cette paire montre que **Covid-19** et **JT (Journal Télévisé)** sont fréquemment mentionnés ensemble. Cela est tout à fait attendu, puisque la pandémie de **Covid-19** a été un sujet majeur traité en priorité dans les journaux télévisés pendant plusieurs mois, voire années. Le nombre élevé de co-occurrences témoigne de l'omniprésence de ce sujet dans les médias, en particulier dans les journaux télévisés où il est souvent au centre des discussions sur les mesures sanitaires, les mises à jour épidémiologiques et les politiques gouvernementales.
#
# 3. **Paire ('Royaume-Uni', 'Brexit') et ('Brexit', 'Royaume-Uni')** -> **Co-occurrences : 661**
#
#    - Le **Brexit** et le **Royaume-Uni** sont étroitement liés, donc leur fréquence de co-occurrence est très élevée. Les discussions sur le **Brexit** sont inévitablement centrées sur le **Royaume-Uni**, qu'il s'agisse de négociations politiques, de ses effets économiques ou des réactions sociales. Cette paire est très logique et reflète l'importance du **Brexit** dans les actualités et analyses politiques concernant le **Royaume-Uni**.
#
# 4. **Paire ('ANCV', 'ANCV')** -> **Co-occurrences : 608**
#
#    - Cette paire peut sembler étrange au premier abord, car elle implique la même entité mentionnée deux fois. Cependant, cela peut signifier qu'à l'intérieur des articles, l'acronyme **ANCV** (Agence Nationale pour les Chèques-Vacances) est souvent mentionné à plusieurs reprises, en particulier dans des articles économiques ou liés aux politiques de loisirs et de vacances en France. Le fait qu'elle apparaisse si souvent dans un même document est une particularité liée au contexte.
#
# 5. **Paire ('ANCV', 'État') et ('État', 'ANCV')** -> **Co-occurrences : 598**
#
#    - **ANCV** et **État** apparaissent fréquemment ensemble, ce qui est logique si l'on considère que l'**État** (dans le sens gouvernemental) soutient souvent des initiatives comme celles de l'**ANCV**, notamment en matière de politique de vacances, d'aides sociales ou de loisirs pour les citoyens. Les co-occurrences élevées montrent que les deux entités sont fréquemment associées dans des contextes de politique publique ou de programmes gouvernementaux.
#
# 6. **Paire ('Allemagne', 'JT')** -> **Co-occurrences : 528**
#
#    - Cette paire montre une relation entre **l'Allemagne** et le **Journal Télévisé**. Bien que l'Allemagne ne soit pas aussi centrale que certains autres pays dans le contexte des JT français, elle apparaît tout de même fréquemment dans les journaux télévisés, surtout dans le cadre de discussions sur la politique européenne, l'économie, les affaires internationales ou les crises comme la pandémie de Covid-19. Les relations diplomatiques, les événements européens ou les politiques économiques de l'Allemagne sont des sujets courants dans les journaux télévisés français.
#
# ### Synthèse générale :
# - Les résultats montrent des associations logiques et attendues entre des entités fortement liées dans les discours médiatiques et politiques.
# - Des entités comme **'Covid-19'**, **'Brexit'**, et **'Royaume-Uni'** apparaissent fréquemment dans des contextes médiatiques où ces événements ont été au cœur de l'actualité mondiale, expliquant ainsi les fortes co-occurrences.
# - Les paires telles que **'Auschwitz'** et **'Birkenau'**, ou encore **'ANCV'** et **'État'**, mettent en évidence des relations très spécifiques qui peuvent être liées à des discussions ou des articles thématiques (histoire, politiques publiques, etc.).
#
# Ces co-occurrences offrent un aperçu des thématiques majeures abordées dans les articles et témoignent de la manière dont certaines entités sont fréquemment liées dans les discours publics et médiatiques. Les résultats suggèrent également un fort accent sur des sujets spécifiques, comme la politique européenne, la pandémie, et des entités institutionnelles françaises.

# %% [markdown]
# ### Question 12

# %%
import spacy
from collections import Counter, defaultdict
import json

# Charger le modèle spaCy pour l'analyse linguistique
nlp = spacy.load("fr_core_news_md")

# Charger le fichier JSON avec les articles
with open('francetvinfo.json', 'r', encoding='utf-8') as f:
    articles = json.load(f)

# Dictionnaire pour stocker les co-occurrences
co_occurrences = Counter()

# Fonction pour compter les co-occurrences entre entités dans la même phrase
def count_co_occurrences_in_sentence(entities_in_sentence):
    # On utilise un dictionnaire pour stocker les entités par type
    entity_types = defaultdict(list)
    for ent in entities_in_sentence:
        entity_types[ent.label_].append(ent.text)
    
    # Calcul des co-occurrences entre entités de types différents
    for type1, entities_type1 in entity_types.items():
        for type2, entities_type2 in entity_types.items():
            if type1 != type2:  # On ne compte que les entités de types différents
                for ent1 in entities_type1:
                    for ent2 in entities_type2:
                        co_occurrences[(ent1, ent2)] += 1

# Analyser tous les articles et leurs contenus
for url, article in articles.items():
    # Traiter le texte de l'article avec spaCy pour l'analyse linguistique
    doc = nlp(article['content'])

    # Pour chaque phrase du document
    for sentence in doc.sents:
        # Extraire les entités présentes dans la phrase
        entities_in_sentence = [ent for ent in sentence.ents]

        # Si des entités existent dans la phrase, compter les co-occurrences
        if entities_in_sentence:
            count_co_occurrences_in_sentence(entities_in_sentence)

# Afficher les 10 paires d'entités les plus fréquentes dans une même phrase
top_co_occurrences = co_occurrences.most_common(10)
for pair, count in top_co_occurrences:
    print(f"Paire : {pair} -> Co-occurrences : {count}")
# Out:
# Paire : ('France Télévisions', 'Franceinfo') -> Co-occurrences : 67
# Paire : ('Franceinfo', 'France Télévisions') -> Co-occurrences : 67
# Paire : ('Magazines', 'Franceinfo') -> Co-occurrences : 66
# Paire : ('Franceinfo', 'Magazines') -> Co-occurrences : 66
# Paire : ('France Télévisions', 'iOS & Android') -> Co-occurrences : 64
# Paire : ('Franceinfo', 'iOS & Android') -> Co-occurrences : 64
# Paire : ('iOS & Android', 'France Télévisions') -> Co-occurrences : 64
# Paire : ('iOS & Android', 'Franceinfo') -> Co-occurrences : 64
# Paire : ('Magazines', 'iOS & Android') -> Co-occurrences : 63
# Paire : ('iOS & Android', 'Magazines') -> Co-occurrences : 63

# %% [markdown]
# ### Analyse des Paires et de leurs Co-occurrences :
#
# 1. **Paires associées à 'France Télévisions' et 'Franceinfo' :**
#    - Les paires **('France Télévisions', 'Franceinfo')** et **('Franceinfo', 'France Télévisions')** apparaissent chacune **67 fois**. Cela montre une forte association entre ces deux entités, suggérant qu'elles sont souvent mentionnées ensemble dans les articles. Cela pourrait être dû au fait que "France Télévisions" est l'entité mère de "Franceinfo", qui est une filiale d'information. En effet, ces deux entités pourraient être fréquemment citées ensemble dans le contexte des actualités ou des productions médias liées à France Télévisions.
#
# 2. **Paires associées à 'Franceinfo' et 'Magazines' :**
#    - Les paires **('Magazines', 'Franceinfo')** et **('Franceinfo', 'Magazines')** apparaissent **66 fois**. Cette forte co-occurrence suggère que "Franceinfo" et les "Magazines" sont souvent mentionnés ensemble, probablement dans des articles où "Franceinfo" est mentionnée en rapport avec des magazines d'actualités ou des publications en ligne. Cela pourrait également signifier que des articles de presse sur Franceinfo couvrent des sujets liés à des magazines ou à des plateformes de publication.
#
# 3. **Paires associées à 'France Télévisions' et 'iOS & Android' :**
#    - Les paires **('France Télévisions', 'iOS & Android')** et **('iOS & Android', 'France Télévisions')** apparaissent **64 fois**. Cela montre qu'il y a une relation notable entre France Télévisions et les plateformes mobiles (iOS et Android). Ces co-occurrences suggèrent probablement que des articles parlent des applications mobiles de France Télévisions, des plateformes où ses contenus sont accessibles, ou des sujets en lien avec l'adaptation des services médias de France Télévisions aux appareils mobiles.
#
# 4. **Paires associées à 'iOS & Android' et 'Magazines' :**
#    - Les paires **('Magazines', 'iOS & Android')** et **('iOS & Android', 'Magazines')** apparaissent **63 fois**. Cela peut indiquer que dans ces articles, des magazines en ligne ou des applications dédiées aux magazines sont souvent mentionnées en relation avec les plateformes mobiles iOS et Android. Il est possible que l'analyse concerne des magazines numériques disponibles sur ces systèmes d'exploitation.
#
# ### Observations Générales :
# - **Redondance des Paires :** Certaines paires sont inversées (par exemple, **('France Télévisions', 'Franceinfo')** et **('Franceinfo', 'France Télévisions')**), mais elles indiquent la même relation dans les articles. Cela montre une répétition dans la manière dont ces entités sont associées dans les phrases.
# - **Thématiques Principales :** Les articles semblent fortement centrés autour des thématiques de France Télévisions, Franceinfo, les magazines et les plateformes mobiles (iOS & Android). Ces co-occurrences peuvent être liées à des articles qui abordent les applications, les plateformes numériques, ou les services en ligne de France Télévisions, en particulier dans le cadre de la consommation de médias via des appareils mobiles.
#
# ### Conclusion :
# Le résultat suggère que les entités "France Télévisions", "Franceinfo", "Magazines" et "iOS & Android" sont fréquemment mentionnées ensemble, probablement en raison de leur relation étroite dans le domaine des médias numériques et des applications mobiles. Ces associations peuvent refléter la manière dont les utilisateurs accèdent aux contenus de France Télévisions et de Franceinfo, ainsi que la présence de ces entités dans les discussions sur les nouvelles technologies et les plateformes multimédia.

# %% [markdown]
# ### Question 13

# %%
# Extraction des verbes entre deux entités
def extract_verbs_between_entities(doc, ent1_text, ent1_type, ent2_text, ent2_type):
    verbs = []
    ent1 = None
    ent2 = None

    # Identifier les entités dans le document
    for ent in doc.ents:
        if ent1_text in ent.text and ent.label_ == ent1_type:  # Recherche partielle
            ent1 = ent
        elif ent2_text in ent.text and ent.label_ == ent2_type:  # Recherche partielle
            ent2 = ent

    if not ent1 or not ent2:
        return verbs

    # Vérifier si les entités sont dans la même phrase
    for sent in doc.sents:
        if ent1.start >= sent.start and ent2.end <= sent.end:
            # Trier les entités pour que ent1 soit toujours avant ent2
            start, end = sorted([ent1.start, ent2.start])

            # Extraire les tokens entre les entités
            for token in sent[start:end]:
                if token.pos_ == "VERB":
                    verbs.append(token.lemma_)

    return verbs

# Traitement des articles
for key, doc in zip(commentaires.keys(), process.pipe(commentaires.values(), batch_size=20, n_process=2)):
    try:
        entities = extract_entities(doc)
        resultats[key] = entities
    except Exception as e:
        print(f"Erreur lors du traitement du document {key}: {e}")



# Recherche des relations pour les 20 entités les plus fréquentes
relations = []
for key, content in commentaires.items():
    doc = process(content)
    for ent1_text, _ in top_20_personnes:
        for ent2_text, _ in top_20_lieux:
            verbs = extract_verbs_between_entities(doc, ent1_text, "PER", ent2_text, "LOC")
            if verbs:
                relations.append((ent1_text, ent2_text, verbs))

# Afficher les relations détectées
for relation in relations:
    print(f"Relation entre {relation[0]} (PER) et {relation[1]} (LOC) : {relation[2]}")
# Out:
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['recevoir', 'vanter']
# Relation entre Emmanuel Macron (PER) et la France (LOC) : ['recevoir', 'vanter']
# Relation entre Thierry Breton (PER) et État (LOC) : ['promettre', 'charger', 'vouloir', 'dire', 'décider']
# Relation entre Emmanuel Macron (PER) et la France (LOC) : ['recevoir']
# Relation entre président de la République (PER) et la France (LOC) : ['recevoir']
# Relation entre Emmanuel Macron (PER) et Paris (LOC) : ['inaugurer']
# Relation entre Edouard Philippe (PER) et Paris (LOC) : ['dédier', 'modifier']
# Relation entre Jérôme Salomon (PER) et France (LOC) : ['donner']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['pouvoir', 'observer', 'aller', 'passer']
# Relation entre Boris Johnson (PER) et Français (LOC) : ['prévoir', 'dévoiler', 'valoir', 'avoir', 'avoir', 'écrire', 'prendre', 'reste', 'quitte', 'combler', 'choisir', 'pourrir']
# Relation entre Michel Barnier (PER) et Français (LOC) : ['prévoir', 'dévoiler', 'valoir', 'avoir', 'avoir', 'écrire', 'prendre']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['établir', 'agir', 'prévenir', 'pouvoir', 'laisser', 'établir']
# Relation entre Boris Johnson (PER) et Royaume-Uni (LOC) : ['autoriser', 'accéder']
# Relation entre Boris Johnson (PER) et Londres (LOC) : ['vouloir']
# Relation entre Emmanuel Macron (PER) et la France (LOC) : ['commencer', 'préciser', 'reste', 'commémorer', 'faire', 'charger', 'rappeler', 'paraître', 'vouloir', 'regarder']
# Relation entre Angela Merkel (PER) et Turquie (LOC) : ['faire', 'prendre', 'ensevelir', 'venir', 'crier', 'permettre', 'refuser', 'féliciter', 'demande']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['élire', 'voir', 'bouleverser', 'devoir', 'déplaire', 'pointer', 'voir', 'sakellaropoulou', 'vouloir', 'engager', 'espérer', 'redonner', 'apparaître', 'donner', 'porter', 'pouvoir', 'dire', 'avoir', 'provoquer', 'étouffer', 'voir', 'péricliter', 'laisser', 'faire', 'autoriser', 'vouloir', 'trouver', 'résoudre', 'dire', 'dissuader', 'ruiner', 'régler', 'traiter', 'exclure', 'maudire', 'commencer', 'recevoir', 'considérer', 'estimer']
# Relation entre Angela Merkel (PER) et Etat (LOC) : ['élire', 'voir', 'bouleverser', 'devoir', 'déplaire', 'pointer', 'voir', 'sakellaropoulou', 'vouloir', 'engager', 'espérer', 'redonner', 'apparaître', 'donner', 'porter', 'pouvoir', 'dire', 'avoir', 'provoquer', 'étouffer', 'voir', 'péricliter', 'laisser', 'faire', 'autoriser', 'vouloir', 'trouver', 'résoudre', 'dire', 'dissuader', 'ruiner', 'régler', 'traiter', 'exclure', 'maudire', 'commencer', 'recevoir', 'considérer', 'estimer', 'procéder', 'montrer', 'avoir', 'aboutir', 'demeurer', 'écarter']
# Relation entre Ursula von der Leyen (PER) et Etat (LOC) : ['élire', 'voir', 'bouleverser', 'devoir', 'déplaire', 'pointer', 'voir', 'sakellaropoulou', 'vouloir', 'engager', 'espérer', 'redonner']
# Relation entre César (PER) et Franceinfo (LOC) : ['rejeter', 'aimer', 'pouvoir', 'faire', 'aller', 'étrangler', 'reconnaître', 'répondre', 'habiter', 'pendre', 'faire', 'jeter', 'pencher', 'signer', 'prévenir', 'organiser', 'faire', 'avoir', 'vivre', 'souvenir', 'trouver', 'habiter', 'reprendre', 'retrouver', 'sentir', 'passer', 'reste', 'devoir', 'faire', 'pleurer', 'devoir', 'gérer', 'reprendre', 'conseiller', 'passer', 'relativiser', 'reprendre', 'illustre', 'dire', 'renchérir']
# Relation entre Angela Merkel (PER) et Allemagne (LOC) : ['justifier', 'allier']
# Relation entre Angela Merkel (PER) et Allemagne (LOC) : ['briguer']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['prendre', 'programmer', 'décommander']
# Relation entre Emmanuel Macron (PER) et Paris (LOC) : ['féliciter', 'parcourir', 'réunir', 'déclarer', 'monter', 'préférer', 'retourner']
# Relation entre Emmanuel Macron (PER) et État (LOC) : ['réunir', 'déclarer', 'monter']
# Relation entre Thierry Breton (PER) et Bruxelles (LOC) : ['vouloir', 'jouer']
# Relation entre Ursula von der Leyen (PER) et Bruxelles (LOC) : ['vouloir', 'jouer']
# Relation entre Ursula von der Leyen (PER) et Europe (LOC) : ['avoir', 'jouer', 'devoir', 'défendre', 'affirmer']
# Relation entre Ursula von der Leyen (PER) et l'Europe (LOC) : ['avoir', 'jouer', 'devoir', 'défendre', 'affirmer']
# Relation entre Jérôme Salomon (PER) et Paris (LOC) : ['préconiser']
# Relation entre Valéry Lerouge (PER) et Bruxelles (LOC) : ['correspondre']
# Relation entre Bruno Le Maire (PER) et France (LOC) : ['mobiliser', 'informer', 'pouvoir', 'baisser', 'confirmer', 'pouvoir', 'provoquer', 'confirmer']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['rassurer']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['produire']
# Relation entre Angela Merkel (PER) et Bruxelles (LOC) : ['trouver', 'désigner', 'devenir', 'annoncer', 'lever', 'montrer', 'bénéficier', 'prendre', 'contester', 'demeurer', 'devenir', 'dominer', 'correspondre', 'citer', 'rester', 'créer', 'provoquer']
# Relation entre Ursula von der Leyen (PER) et Bruxelles (LOC) : ['trouver', 'désigner', 'devenir', 'annoncer', 'lever', 'montrer', 'bénéficier', 'prendre', 'contester', 'demeurer', 'devenir']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['recenser', 'indiquer', 'contracter', 'réunir', 'expliquer']
# Relation entre Boris Johnson (PER) et Italie (LOC) : ['décréter', 'tuer', 'dépasser', 'jouer', 'clore', 'mettre', 'sembler', 'constituer', 'trouver', 'rester', 'changer']
# Relation entre Donald Trump (PER) et Etat (LOC) : ['heurter', 'aimer', 'associer', 'faire', 'travailler', 'aller', 'manger', 'connaître', 'pouvoir', 'travailler', 'commencer', 'créer', 'pouvoir', 'déplacer', 'travailler', 'pouvoir', 'déplacer', 'continuer', 'développer', 'embauche', 'pouvoir', 'aller', 'chercher', 'pouvoir', 'analyser', 'aller', 'créer', 'détailler', 'aller', 'manger', 'connaître', 'pouvoir', 'travailler', 'faire', 'avoir']
# Relation entre Vladimir Poutine (PER) et Grèce (LOC) : ['passer']
# Relation entre président de la République (PER) et Paris (LOC) : ['saluer', 'faire']
# Relation entre Ursula von der Leyen (PER) et État (LOC) : ['déclarer']
# Relation entre Boris Johnson (PER) et Espagne (LOC) : ['fermer', 'interdire', 'aller', 'jouer', 'clore', 'penser', 'épargner', 'confirmer', 'décider', 'prendre', 'interdire', 'devoir', 'avoir']
# Relation entre Angela Merkel (PER) et Allemagne (LOC) : ['pouvoir', 'annoncer', 'prendre', 'soutenir', 'mettre', 'cibler', 'devoir', 'choisir', 'suivre', 'baisser', 'soutenir', 'décider', 'tourner', 'juger', 'être', 'avoir', 'agir', 'destiner', 'rassurer', 'annoncer', 'accorder', 'pouvoir', 'prêter', 'manquer', 'appeler', 'prendre', 'dégager', 'quitte', 'dépasser', 'imposer', 'dire', 'mettre']
# Relation entre Angela Merkel (PER) et Italie (LOC) : ['sortir']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['rappeler']
# Relation entre Bruno Le Maire (PER) et France (LOC) : ['déplorer', 'faire', 'falloir', 'multiplier', 'expliquer']
# Relation entre Muriel Pénicaud (PER) et France (LOC) : ['déplorer', 'faire', 'falloir', 'multiplier']
# Relation entre Emmanuel Macron (PER) et la France (LOC) : ['covid-19', 'provoquer']
# Relation entre Emmanuel Macron (PER) et Italie (LOC) : ['instaurer']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['annoncer', 'restreindre']
# Relation entre Ursula von der Leyen (PER) et Etat (LOC) : ['annoncer', 'restreindre', 'instaurer']
# Relation entre Thierry Breton (PER) et Europe (LOC) : ['souligner', 'prendre', 'permettre', 'avoir', 'indiquer']
# Relation entre Thierry Breton (PER) et l'Europe (LOC) : ['souligner', 'prendre', 'permettre', 'avoir', 'indiquer']
# Relation entre Emmanuel Macron (PER) et Français (LOC) : ['annoncer', 'prendre', 'faire', 'chuter', 'continuer', 'bénéficier', 'pouvoir', 'faire', 'cible', 'pouvoir', 'tenir', 'exercer', 'savoir', 'jouer', 'dire', 'mobiliser', 'proposer', 'effacer', 'faire', 'avoir', 'débourser', 'dire', 'aller', 'créer', 'abonder', 'aller', 'faire', 'avoir', 'aller', 'mettre', 'annoncer', 'confirmer', 'voir', 'marche', 'permettre', 'préserver', 'ouvrir', 'fixer', 'aider', 'sortir', 'livrer', '”']
# Relation entre Edouard Philippe (PER) et France (LOC) : ['prononcer', 'protéger', 'protéger', 'aider', 'faire', 'déclarer']
# Relation entre Edouard Philippe (PER) et la France (LOC) : ['prononcer', 'protéger', 'protéger', 'aider', 'faire', 'déclarer']
# Relation entre Christophe Castaner (PER) et France (LOC) : ['parler']
# Relation entre Christophe Castaner (PER) et la France (LOC) : ['parler']
# Relation entre Thierry Breton (PER) et Paris (LOC) : ['expliquer']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['endiguer']
# Relation entre Bruno Le Maire (PER) et France (LOC) : ['craindre', 'expliquer']
# Relation entre président de la République (PER) et France (LOC) : ['craindre', 'expliquer']
# Relation entre Vladimir Poutine (PER) et Allemagne (LOC) : ['adresser', 'avoir', 'exprimer', 'insister', 'décréter', 'interdire', 'déserter', 'affirmer', 'confirmer', 'gagner', 'progresser', 'porter', 'fermer', 'fermer', 'montrer']
# Relation entre Angela Merkel (PER) et Europe (LOC) : ['expliquer', 'préciser']
# Relation entre Ursula von der Leyen (PER) et Franceinfo (LOC) : ['dresse', 'annoncer', 'tenter', 'endiguer', 'annoncer', 'partir', 'contenir', 'agir', 'aller', 'occuper', 'prévenir']
# Relation entre Laurent Desbonnets (PER) et la France (LOC) : ['réaliser']
# Relation entre Ursula von der Leyen (PER) et Bruxelles (LOC) : ['suivre', 'faire', 'permettre', 'déroger', 'déclarer', 'publier']
# Relation entre Emmanuel Macron (PER) et Bruxelles (LOC) : ['accorder', 'toucher', 'faire', 'préciser', 'indiquer']
# Relation entre Bruno Le Maire (PER) et Bruxelles (LOC) : ['accorder', 'toucher', 'faire', 'préciser', 'indiquer']
# Relation entre Bruno Le Maire (PER) et la France (LOC) : ['rendre']
# Relation entre Angela Merkel (PER) et Etat (LOC) : ['destiner']
# Relation entre Donald Trump (PER) et Italie (LOC) : ['recenser', 'passer', 'coucher', 'faire', 'mobiliser', 'accueillir', 'expliquer', 'installer', 'médicaliser', 'accueillir', 'exprimer', 'rapporter', 'avoir', 'parler', 'inviter', 'rester', 'dire', 'falloir', 'taire']
# Relation entre Donald Trump (PER) et Espagne (LOC) : ['accueillir', 'expliquer', 'rapporter', 'avoir', 'taire']
# Relation entre Jérôme Salomon (PER) et France (LOC) : ['multiplier']
# Relation entre Jérôme Salomon (PER) et l'Europe (LOC) : ['annoncer', 'multiplier']
# Relation entre Angela Merkel (PER) et Grèce (LOC) : ['durer', 'confirmer', 'organiser', 'multiplier', 'être', 'infecter']
# Relation entre Bruno Le Maire (PER) et France (LOC) : ['mettre', 'savoir', 'aller', 'dépasser', 'évoquer']
# Relation entre Bruno Le Maire (PER) et France (LOC) : ['mettre', 'savoir', 'aller', 'dépasser', 'évoquer']
# Relation entre Laurent Desbonnets (PER) et Allemagne (LOC) : ['réaliser', 'mobiliser', 'exister', 'faire', 'avoir', 'avoir', 'pouvoir', 'tester', 'faire', 'aller', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['avoir', 'passer']
# Relation entre Emmanuel Macron (PER) et Europe (LOC) : ['saturer', 'réunir', 'étaler']
# Relation entre Angela Merkel (PER) et Berlin (LOC) : ['tirer', 'prévenir']
# Relation entre Emmanuel Macron (PER) et Français (LOC) : ['participer']
# Relation entre Angela Merkel (PER) et Franceinfo (LOC) : ['comparer', 'sévir', 'affiche', 'recenser', 'affiche', 'recenser', 'rendre', 'saturer', 'transférer', 'faire', 'figurer', 'identifier', 'savoir', 'situer', 'commencer', 'tester', 'correspondre', 'avérer', 'mettre', 'appliquer', 'appuyer', 'disséminer', 'communiquer', 'réaliser', 'décrire', 'croire', 'prendre', 'faire', 'arriver', 'tester', 'expliquer', 'tester', 'compte', 'arrêter', 'révéler', 'prescrire', 'inspirer', 'cibler', 'présenter', 'réaliser', 'installer', 'isoler', 'importer', 'tester', 'retrouver', 'confiner', 'expliquer', 'avoir', 'ouvrir', 'identifier', 'infecter', 'permettre', 'limiter', 'limiter', 'expliquer', 'interroger', 'avoir', 'voir', 'susciter', 'expliquer', 'permettre', 'produire', 'tester', 'avoir', 'expliquer', 'abonner', 'rationner', 'pratiquer', 'être', 'confirmer', 'voyager', 'expliquer', 'appeler', 'dépister', 'obliger', 'revoir', 'réaliser', 'assurer', 'aller', 'démultiplier', 'répéter', 'affirmer', 'vouloir', 'parvenir', 'devoir', 'porter', 'préciser', 'mettre', 'avoir', 'déclarer', 'téléviser']
# Relation entre Laurent Desbonnets (PER) et Franceinfo (LOC) : ['comparer', 'sévir', 'affiche', 'recenser', 'affiche', 'recenser', 'rendre', 'saturer', 'transférer', 'faire', 'figurer', 'identifier', 'savoir', 'situer', 'commencer', 'tester', 'correspondre', 'avérer', 'mettre', 'appliquer', 'appuyer', 'disséminer', 'communiquer', 'réaliser', 'décrire', 'croire', 'prendre', 'faire', 'arriver', 'tester', 'expliquer', 'tester', 'compte', 'arrêter', 'révéler', 'prescrire', 'inspirer', 'cibler', 'présenter', 'réaliser', 'installer', 'isoler', 'importer', 'tester', 'retrouver', 'confiner', 'expliquer']
# Relation entre Olivier Véran (PER) et Franceinfo (LOC) : ['comparer', 'sévir', 'affiche', 'recenser', 'affiche', 'recenser', 'rendre', 'saturer', 'transférer', 'faire', 'figurer', 'identifier', 'savoir', 'situer', 'commencer', 'tester', 'correspondre', 'avérer', 'mettre', 'appliquer', 'appuyer', 'disséminer', 'communiquer', 'réaliser', 'décrire', 'croire', 'prendre', 'faire', 'arriver', 'tester', 'expliquer', 'tester', 'compte', 'arrêter', 'révéler', 'prescrire', 'inspirer', 'cibler', 'présenter', 'réaliser', 'installer', 'isoler', 'importer', 'tester', 'retrouver', 'confiner', 'expliquer', 'avoir', 'ouvrir', 'identifier', 'infecter', 'permettre', 'limiter', 'limiter', 'expliquer', 'interroger', 'avoir', 'voir', 'susciter', 'expliquer', 'permettre', 'produire', 'tester', 'avoir', 'expliquer', 'abonner', 'rationner', 'pratiquer', 'être', 'confirmer', 'voyager', 'expliquer', 'appeler', 'dépister', 'obliger', 'revoir', 'réaliser', 'assurer', 'aller', 'démultiplier', 'répéter', 'affirmer', 'vouloir', 'parvenir', 'devoir', 'porter', 'préciser', 'mettre', 'avoir', 'déclarer', 'téléviser', 'être', 'doter', 'représenter', 'équiper', 'falloir', 'dire', 'implanter', 'expliquer', 'faire', 'doter', 'dire', 'entretenir', 'doter', 'posséder', 'révéler', 'fermer', 'avoir', 'décrire', 'pourvoir', 'devoir', 'appeler', 'porter', 'estimer', 'faire', 'craindre', 'survenir', 'traverser', 'mettre', 'fonctionner', 'tendre', 'situer', 'développer', 'confronter', 'souhaiter', 'augmenter', 'atteindre', 'indiquer']
# Relation entre Laurent Desbonnets (PER) et France (LOC) : ['frapper', 'enregistrer', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Allemagne (LOC) : ['frapper', 'limiter', 'contenir', 'entendre', 'lancer', 'gélocalise', 'infecter', 'marcher', 'assurer', 'avoir', 'être', 'être', 'déplacer', 'posséder', 'enregistrer', 'tomber', 'transmettre', 'charger', 'prévenir', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['frapper', 'limiter', 'lancer', 'gélocalise', 'infecter', 'posséder', 'enregistrer', 'transmettre', 'charger', 'prévenir', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Italie (LOC) : ['frapper', 'infecter', 'posséder', 'enregistrer', 'prévenir', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et l'Europe (LOC) : ['frapper', 'limiter', 'lancer', 'gélocalise', 'infecter', 'posséder', 'enregistrer', 'transmettre', 'charger', 'prévenir', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Espagne (LOC) : ['frapper', 'posséder', 'enregistrer', 'expliquer']
# Relation entre Bruno Le Maire (PER) et la France (LOC) : ['commander', 'devenir', 'expliquer', 'souhaiter', 'permettre', 'emprunter']
# Relation entre Bruno Le Maire (PER) et Chine (LOC) : ['expliquer', 'permettre', 'emprunter']
# Relation entre président de la République (PER) et la France (LOC) : ['commander', 'devenir', 'expliquer']
# Relation entre président de la République (PER) et Chine (LOC) : ['expliquer']
# Relation entre Olivier Véran (PER) et la France (LOC) : ['préciser']
# Relation entre Olivier Véran (PER) et Chine (LOC) : ['préciser', 'commander']
# Relation entre Bruno Le Maire (PER) et Français (LOC) : ['représenter', 'venir', 'mettre', 'promettre', 'combler']
# Relation entre Muriel Pénicaud (PER) et Français (LOC) : ['représenter', 'venir', 'mettre', 'promettre', 'combler']
# Relation entre Emmanuel Macron (PER) et la France (LOC) : ['épargner', 'dire', 'risquer', 'tomber', 'aller', 'pouvoir', 'finir']
# Relation entre Valéry Lerouge (PER) et Europe (LOC) : ['nuire', 'diverger', 'mettre', 'permettre', 'sauver', 'moyenner', 'avoir', 'agacer', 'compte-tenu', 'aider', 'avoir', 'financer', 'expliquer', 'correspondre']
# Relation entre Laurent Desbonnets (PER) et Paris (LOC) : ['proposer', 'mettre', 'être', 'commencer', 'aller', 'tester', 'avancer', 'voir', 'lancer', 'indique']
# Relation entre Bruno Le Maire (PER) et France (LOC) : ['compte', 'aider', 'faire', 'annoncer', 'parvenir', 'aller', 'servir', 'falloir', 'dire', 'ajouter']
# Relation entre Emmanuel Macron (PER) et Paris (LOC) : ['annoncer', 'aller', 'passer', 'éviter', 'sauver', 'aider', 'dire', 'augmenter', 'prévoir', 'alimenter', 'résister', 'donne', 'tenir', 'produire', 'atteindre', 'emprunter', 'aller', 'évoquer', 'dédier', 'financer', 'promettre', 'revaloriser', 'aller', 'recevoir', 'aller', 'prolonger', 'aller', 'faire', 'préparer', 'savoir']
# Relation entre Bruno Le Maire (PER) et Paris (LOC) : ['annoncer', 'aller', 'passer', 'éviter', 'sauver', 'aider', 'dire', 'augmenter', 'prévoir', 'alimenter', 'résister', 'donne', 'tenir', 'produire', 'atteindre', 'emprunter', 'aller', 'évoquer', 'dédier']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['prendre', 'prévoir', 'répondre', 'rencontrer', 'covid-19', 'attendre', 'passer']
# Relation entre Emmanuel Macron (PER) et Français (LOC) : ['dire', 'aller', 'prolonger', 'inquiet', 'pouvoir', 'stocker', 'expliquer', 'avoir', 'prendre', 'falloir', 'être', '”', 'ajouter', 'suivre', 'voir', 'continuer', 'faire', 'valoir', 'avoir', 'répondre', 'prévoir', 'répondre', 'rencontrer', 'covid-19', 'attendre', 'passer']
# Relation entre président de la République (PER) et Français (LOC) : ['devoir', 'adresser']
# Relation entre Emmanuel Macron (PER) et France (LOC) : ['préparer', 'pouvoir', 'venir', 'faire', 'aller', 'devoir', 'patienter', 'poursuivre']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['savoir', 'aller', 'permettre', 'atteindre', 'réagir', 'engager', 'être', 'dire', 'laisse', 'trouver', 'changer', 'indique']
# Relation entre président de la République (PER) et Etat (LOC) : ['savoir', 'aller', 'permettre', 'atteindre', 'réagir', 'engager', 'être', 'dire', 'laisse', 'trouver', 'changer', 'indique']
# Relation entre Emmanuel Macron (PER) et Français (LOC) : ['téléviser', 'diffuser']
# Relation entre Angela Merkel (PER) et l'Europe (LOC) : ['retourner']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['suivre', 'déclarer', 'demander', 'être', 'répondre', 'pouvoir', 'suspendre', 'permettre', 'confiner', 'continuer', 'travailler', 'pouvoir', 'rester', 'évoquer']
# Relation entre Bruno Le Maire (PER) et Etat (LOC) : ['faire', 'rencontrer', 'exiger', 'subir']
# Relation entre Edouard Philippe (PER) et Etat (LOC) : ['faire', 'rencontrer', 'exiger', 'subir', 'consacrer', 'estimer', 'gérer', 'toucher', 'accueillir', 'covid-19', 'toucher']
# Relation entre Olivier Véran (PER) et Etat (LOC) : ['faire', 'rencontrer', 'exiger', 'subir', 'consacrer', 'estimer', 'gérer', 'toucher', 'accueillir', 'covid-19', 'toucher', 'souligner']
# Relation entre Bruno Le Maire (PER) et Etat (LOC) : ['aller', 'aider', 'acheter', 'redémarrer']
# Relation entre Bruno Le Maire (PER) et État (LOC) : ['mettre', 'aller', 'pouvoir', 'toucher', 'bénéficier', 'assouplir', 'avoir', 'avoir', 'conster', 'c’', 'aller', 'prendre', 'avoir', 'entrer']
# Relation entre Angela Merkel (PER) et Europe (LOC) : ['changer', 'sentir']
# Relation entre Laurent Desbonnets (PER) et Allemagne (LOC) : ['pouvoir', 'rouvrir', 'préparer', 'pouvoir', 'reprendre', 'disposer', 'souligner']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['changer', 'sentir', 'aller', 'pouvoir', 'rouvrir', 'préparer', 'pouvoir', 'reprendre', 'prévoir', 'déborder', 'disposer', 'souligner']
# Relation entre Angela Merkel (PER) et Berlin (LOC) : ['garantir']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['autoriser', 'présenter', 'signer', 'lier', 'lancer', 'adresser', 'rapporter']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['décider', 'reprendre']
# Relation entre Laurent Desbonnets (PER) et Espagne (LOC) : ['décider', 'reprendre']
# Relation entre Thierry Breton (PER) et Européens (LOC) : ['mettre', 'lutter', 'trouver', 'agir', 'mettre', 'agir', 'définir', 'devoir', 'avoir', 'préciser', 'subir', 'confier', 'finaliser', 'expliquer', 'inviter', 'finir', 'pouvoir', 'revenir', 'dire', 'voilà', 'préciser', 'aller', 'coûter', 'être', 'indique', 'devoir', 'mettre', 'falloir', 'avoir', 'acquérir', 'discuter', 'rajouter', 'retrouver', 'indique', 'aider', 'avoir', 'falloir', 'faire', 'aller', 'intervenir', 'pouvoir', 'avoir', 'indique', 'vouloir', 'payer', 'payer', 'différencier', 'devoir', 'emprunter', 'conclure']
# Relation entre Bruno Le Maire (PER) et Paris (LOC) : ['constater', 'faire', 'demeurer', 'présenter', 'régler', 'apprendre', 'vivre', 'récupérer', 'battre', 'reprendre', 'vivre', 'mettre', 'sauver', 'pouvoir', 'sauver']
# Relation entre président de la République (PER) et la France (LOC) : ['remercier', 'suivre', '>']
# Relation entre Emmanuel Macron (PER) et Paris (LOC) : ['arriver', 'faire', 'annoncer', '>', 'remercier', 'suivre', '>']
# Relation entre Emmanuel Macron (PER) et Etat (LOC) : ['>']
# Relation entre Emmanuel Macron (PER) et Chine (LOC) : ['annoncer', '>', 'remercier', 'suivre', '>']
# Relation entre président de la République (PER) et Paris (LOC) : ['arriver', 'faire', 'annoncer', '>', 'remercier', 'suivre', '>']
# Relation entre président de la République (PER) et Etat (LOC) : ['>']
# Relation entre président de la République (PER) et Chine (LOC) : ['annoncer', '>', 'remercier', 'suivre', '>']
# Relation entre Emmanuel Macron (PER) et Français (LOC) : ['faire', 'venir', 'propager', 'mettre', 'annoncer']
# Relation entre président de la République (PER) et Français (LOC) : ['faire', 'venir', 'propager', 'mettre', 'annoncer']
# Relation entre président de la République (PER) et Chine (LOC) : ['>', 'remercier', 'suivre', '>']
# Relation entre Emmanuel Macron (PER) et Paris (LOC) : ['imaginer', 'installer', 'bâtir', 'pouvoir', 'fréquenter', 'inaugurer', 'ouvrir', 'prononcer']
# Relation entre Christophe Castaner (PER) et la France (LOC) : ['entrer', 'arriver', 'suivre', 'faire', 'annoncer', 'imposer', 'annoncer']
# Relation entre Christophe Castaner (PER) et Royaume-Uni (LOC) : ['entrer', 'arriver', 'suivre', 'faire', 'annoncer', 'imposer', 'annoncer']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['commencer', 'assouplir', 'apprêter', 'reprendre', 'déclarer', 'porte', 'aller', 'travailler', 'avoir', 'rapporter', 'aller', 'reprendre', 'avérer', 'respecter', 'dire', 'être', 'rouvrir', 'annoncer']
# Relation entre Laurent Desbonnets (PER) et Italie (LOC) : ['apprêter', 'reprendre', 'avoir', 'rapporter', 'avérer', 'être', 'rouvrir']
# Relation entre Laurent Desbonnets (PER) et Allemagne (LOC) : ['commencer', 'poursuivre', 'pouvoir', 'rouvrir', 'expliquer']
# Relation entre Olivier Véran (PER) et Royaume-Uni (LOC) : ['faire']
# Relation entre Valéry Lerouge (PER) et Royaume-Uni (LOC) : ['faire']
# Relation entre Laurent Desbonnets (PER) et Berlin (LOC) : ['surveiller', 'réduire', 'respecter', 'préciser']
# Relation entre Thierry Breton (PER) et Paris (LOC) : ['covid-19', 'devoir', 'situer', 'expliquer', 'sauver', 'promettre', 'falloir', 'mettre', 'faire', 'pouvoir', 'voyager', 'travailler', 'falloir', 'accepter', 'poursuivre', 'ajouter', 'développer', 'aller', 'devoir', 'respecter', 'traiter', 'souligner', 'viser', 'maintenir', 'assurer']
# Relation entre Thierry Breton (PER) et Bruxelles (LOC) : ['coûter']
# Relation entre Angela Merkel (PER) et la France (LOC) : ['cherche', 'effectuer', 'accélérer', 'rapprocher', 'dire', 'devoir', 'plier', 'avoir', 'rivaliser', 'relayer', 'aller', 'rouvrir', 'aller', 'expliquer', 'reprendre', 'clore', 'donner', 'clore']
# Relation entre Laurent Desbonnets (PER) et la France (LOC) : ['cherche', 'effectuer', 'accélérer', 'rapprocher', 'dire', 'devoir', 'plier', 'avoir', 'rivaliser', 'relayer']
# Relation entre Olivier Véran (PER) et Europe (LOC) : ['mettre', 'promettre', 'voir', 'entasser', 'supprimer', 'tester', 'repérer', 'covid-19', 'circuler', 'travailler', 'avoir', 'ressembler', 'confier', 'commencer', 'prendre', 'rappeler', 'évaluer', 'protéger', 'poursuivre', 'émettre', 'répondre', 'dire', 'témoigner', 'falloir', 'équiper', 'sembler', 'falloir', 'charger', 'équiper', 'infecter', 'remplacer', 'estimer', 'tarder', 'mettre', 'faire', 'avoir', 'arriver', 'accepter', 'souvenir', 'avoir', 'avoir', 'palper', 'dire', 'devoir', 'insister', 'obtenir', 'enfermer', 'obtenir', 'montre', 'voir', 'témoigner', 'être', 'être', 'tourner', 'ordonner', 'retirer', 'témoigner', 'ajouter', 'falloir', 'attendre', 'apprendre', 'doter', 'souhaiter', 'répondre', 'exposer', 'ouvrir', 'pratiquer', 'être', 'pouvoir', 'prendre', 'contaminer', 'appliquer', 'imposer', 'éviter', 'avoir', 'coller', 'avoir', 'mettre', 'respecter', 'reconner', 'émettre', 'parler', 'tousser', 'diffuser', 'être', 'priser', 'installer', 'utiliser', 'expliquer', 'affirmer', 'permettre', 'restreindre', 'éliminer', 'donner', 'préconiser', 'devoir', 'continuer', 'délester', 'pouvoir', 'repasser', 'décharger', 'décharger', 'avoir', 'spécialiser', 'témoigner', 'avoir', 'voir', 'porter', 'attendre', 'avoir', 'avoir', 'pouvoir', 'lever', 'jouer', 'refuser', 'présenter', 'venir', 'chercher', 'contracter', 'travailler', 'expliquer', 'travailler', 'respecter', 'avoir', 'lâche', 'gérer', 'envoyer', 'savoir', 'avoir', 'protéger', 'pouvoir', 'consulter', 'réceptionner', 'pouvoir', 'disposer', 'rappeler', 'recommander', 'expliquer', 'recommander']
# Relation entre Jérôme Salomon (PER) et Europe (LOC) : ['mettre', 'promettre', 'voir', 'entasser', 'supprimer', 'tester', 'repérer', 'covid-19', 'circuler', 'travailler', 'avoir', 'ressembler', 'confier', 'commencer', 'prendre', 'rappeler', 'évaluer', 'protéger', 'poursuivre', 'émettre', 'répondre', 'dire', 'témoigner', 'falloir', 'équiper', 'sembler', 'falloir', 'charger', 'équiper', 'infecter', 'remplacer', 'estimer', 'tarder', 'mettre', 'faire', 'avoir', 'arriver', 'accepter', 'souvenir', 'avoir', 'avoir', 'palper', 'dire', 'devoir', 'insister', 'obtenir', 'enfermer', 'obtenir', 'montre', 'voir', 'témoigner', 'être', 'être', 'tourner', 'ordonner', 'retirer', 'témoigner', 'ajouter', 'falloir', 'attendre', 'apprendre', 'doter', 'souhaiter', 'répondre', 'exposer', 'ouvrir', 'pratiquer', 'être', 'pouvoir', 'prendre', 'contaminer', 'appliquer', 'imposer', 'éviter', 'avoir', 'coller', 'avoir', 'mettre', 'respecter', 'reconner', 'émettre', 'parler', 'tousser', 'diffuser', 'être', 'priser', 'installer', 'utiliser', 'expliquer', 'affirmer', 'permettre', 'restreindre', 'éliminer', 'donner', 'préconiser', 'devoir', 'continuer', 'délester', 'pouvoir', 'repasser', 'décharger', 'décharger', 'avoir', 'spécialiser', 'témoigner', 'avoir', 'voir', 'porter', 'attendre', 'avoir', 'avoir', 'pouvoir', 'lever', 'jouer', 'refuser', 'présenter', 'venir', 'chercher', 'contracter', 'travailler', 'expliquer', 'travailler', 'respecter', 'avoir', 'lâche', 'gérer', 'envoyer', 'savoir', 'avoir', 'protéger', 'pouvoir', 'consulter', 'réceptionner', 'pouvoir', 'disposer', 'rappeler', 'recommander', 'expliquer', 'recommander', 'déclarer', 'encourager', 'souhaiter', 'porter']
# Relation entre Bruno Le Maire (PER) et Paris (LOC) : ['effondrer', 'quasi', 'faire', 'maintenir', 'dire', 'verse', 'invite', 'faire', 'aider']
# Relation entre Valéry Lerouge (PER) et Européens (LOC) : ['diffuser', 'considérer', 'faire', 'covid-19', 'arrêter']
# Relation entre Valéry Lerouge (PER) et France (LOC) : ['alléger', 'déplorer', 'prononcer', 'entamer', 'expliquer', 'transmettre', 'rouvrir', 'voir', 'augmenter']
# Relation entre Valéry Lerouge (PER) et la France (LOC) : ['alléger', 'déplorer', 'prononcer', 'entamer', 'expliquer', 'transmettre', 'rouvrir', 'voir', 'augmenter']
# Relation entre Valéry Lerouge (PER) et Europe (LOC) : ['épargner', 'redouter', 'devoir', 'attendre', 'amorcer', 'alléger', 'déplorer', 'prononcer', 'crier', 'être', 'entamer', 'expliquer', 'transmettre', 'rouvrir', 'voir', 'augmenter']
# Relation entre Valéry Lerouge (PER) et l'Europe (LOC) : ['épargner', 'redouter', 'devoir', 'attendre', 'amorcer', 'alléger', 'déplorer', 'prononcer', 'crier', 'être', 'entamer', 'expliquer', 'transmettre', 'rouvrir', 'voir', 'augmenter']
# Relation entre Valéry Lerouge (PER) et Bruxelles (LOC) : ['augmenter']
# Relation entre Angela Merkel (PER) et Europe (LOC) : ['devoir', 'placer', 'accélérer', 'aller', 'pouvoir', 'rouvrir']
# Relation entre Edouard Philippe (PER) et France (LOC) : ['commémorer', 'proposer', 'présenter', 'prononcer']
# Relation entre Edouard Philippe (PER) et la France (LOC) : ['commémorer', 'proposer', 'présenter', 'prononcer']
# Relation entre président de la République (PER) et Paris (LOC) : ['avancer']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['faire', 'déconfiner']
# Relation entre Laurent Desbonnets (PER) et l'Europe (LOC) : ['faire', 'déconfiner']
# Relation entre Laurent Desbonnets (PER) et Allemagne (LOC) : ['pouvoir', 'enorgueillir', 'réussir', 'pouvoir', 'redémarrer', 'frappe', 'repérer', 'tourner', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Europe (LOC) : ['pouvoir', 'remettre', 'progresser', 'repartir', 'avoir', 'contaminer']
# Relation entre Laurent Desbonnets (PER) et l'Europe (LOC) : ['pouvoir', 'remettre', 'progresser', 'repartir', 'avoir', 'contaminer']
# Relation entre président de la République (PER) et État (LOC) : ['faire']
# Relation entre Emmanuel Macron (PER) et Allemagne (LOC) : ['soutenir', 'renforcer', 'soutenir', 'cibler', 'doter', 'souligner']
# Relation entre Angela Merkel (PER) et Allemagne (LOC) : ['soutenir', 'renforcer', 'soutenir', 'cibler', 'doter', 'souligner']
# Relation entre Bruno Le Maire (PER) et Allemagne (LOC) : ['financer']
# Relation entre Bruno Le Maire (PER) et Allemagne (LOC) : ['financer']
# Relation entre Edouard Philippe (PER) et France (LOC) : ['localiser']
# Relation entre Laurent Desbonnets (PER) et la France (LOC) : ['indiquer', 'valider', 'renforcer', 'grimper', 'convaincre', 'devoir', 'trouver', 'dire', 'falloir', 'convaincre', 'souhaiter', 'payer', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et la France (LOC) : ['indiquer', 'valider', 'renforcer', 'grimper', 'souhaiter', 'payer', 'expliquer']
# Relation entre Muriel Pénicaud (PER) et France (LOC) : ['licencier']
# Relation entre Muriel Pénicaud (PER) et la France (LOC) : ['licencier']
# Relation entre Ursula von der Leyen (PER) et France (LOC) : ['aller', 'rediriger', 'mériter', 'déclarer', 'devoir', 'continuer', 'diriger']
# Relation entre Ursula von der Leyen (PER) et Chine (LOC) : ['diriger']
# Relation entre Donald Trump (PER) et France (LOC) : ['aller', 'rediriger', 'mériter', 'déclarer', 'devoir', 'continuer', 'diriger']
# Relation entre Donald Trump (PER) et Chine (LOC) : ['diriger']
# Relation entre Laurent Desbonnets (PER) et France (LOC) : ['faire', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et Allemagne (LOC) : ['rouvrir', 'remettre', 'dire', 'faire', 'avoir', 'respecter', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et la France (LOC) : ['faire', 'expliquer']
# Relation entre Laurent Desbonnets (PER) et État (LOC) : ['annoncer', 'surprendre', 'pouvoir', 'dire', 'aller', 'recevoir']
# Relation entre Donald Trump (PER) et France (LOC) : ['dénoncer', 'voir', 'défiler', 'scander', 'rassembler', 'assurer', 'aller', 'devoir', 'entendre', 'protéger', 'fustiger']
# Relation entre Donald Trump (PER) et État (LOC) : ['protéger', 'fustiger']
# Relation entre George Floyd (PER) et France (LOC) : ['dénoncer', 'voir', 'défiler', 'scander']
# Relation entre Emmanuel Macron (PER) et Français (LOC) : ['marquer', 'saluer', 'craindre', 'passer', 'traduire', 'fonctionner', 'accroc', 'augure', 'avoir', 'ravager', 'rouvrir', 'atteindre', 'savoir', 'revenir', 'dévoiler', 'aller', 'imiter', 'arrêter', 'juger', 'faire', 'remettre', 'pulvériser', 'prêter', 'dire', 'rester', 'croire', 'obtenir', 'pouvoir', 'admettre', 'attester', 'retenir', 'franchir', 'graver', 'afficher', 'rappeler', 'falloir', 'soigner', 'avoir', 'rappeler', 'publier', 'citer', 'figurer', 'publier', 'reprendre', 'respecter', 'attendre', 'promettre', 'enfiler', 'tester', 'lgbt+', 'ouvrir', 'ouvrir', 'envers', 'marquer', 'constituer']
# Relation entre Emmanuel Macron (PER) et Italie (LOC) : ['marquer', 'saluer', 'craindre', 'passer', 'traduire', 'fonctionner', 'accroc', 'augure', 'avoir', 'ravager', 'rouvrir', 'savoir', 'revenir', 'dévoiler', 'imiter', 'arrêter', 'juger', 'faire', 'remettre', 'prêter', 'dire', 'rester', 'croire', 'obtenir', 'pouvoir', 'admettre', 'retenir', 'franchir', 'graver', 'rappeler', 'falloir', 'soigner', 'avoir', 'rappeler', 'figurer', 'publier', 'reprendre', 'respecter', 'attendre', 'promettre', 'enfiler', 'tester', 'lgbt+', 'ouvrir', 'ouvrir', 'envers', 'marquer', 'constituer']
# Relation entre Emmanuel Macron (PER) et Européens (LOC) : ['pointer', 'voir', 'retenir', 'terminer', 'marquer', 'saluer', 'craindre', 'passer', 'avoir', 'devenir', 'traduire', 'fonctionner', 'accroc', 'augure', 'avoir', 'finir', 'aller', 'limiter', 'remercier', 'sauver', 'ravager', 'rouvrir', 'anticiper', 'atteindre', 'illuminer', 'faire', 'savoir', 'revenir', 'dévoiler', 'équiper', 'sacrer', 'aller', 'imiter', 'arrêter', 'juger', 'faire', 'remettre', 'voler', 'sacrer', 'pulvériser', 'dire', 'adopter', 'taire', 'avoir', 'entendre', 'devenir', 'partir', 'décider', 'changer', 'trouver', 'prêter', 'prévoir', 'tomber', 'dire', 'rester', 'croire', 'décrocher', 'rejoindre', 'obtenir', 'pouvoir', 'admettre', 'faire', 'voter', 'autoriser', 'devoir', 'rester', 'poursuivre', 'effectuer', 'attester', 'falloir', 'résorber', 'régénérer', 'parler', 'oublier', 'améliorer', 'retenir', 'franchir', 'apprendre', 'établir', 'inscrire', 'graver', 'autoriser', 'inscrire', 'sceller', 'historique', 'faire', 'afficher', 'afficher', 'appuyer', 'battre', 'déterminer', 'mettre', 'organiser', 'presser', 'enregistrer', 'faire', 'croiser', 'parler', 'donner', 'aimer', 'rappeler', 'falloir', 'soigner', 'avoir', 'rappeler', 'continuer', 'illuminer', 'aller', 'prolonger', 'bouder', 'assimiler', 'voir', 'venir', 'revoici', 'louper', 'ralentir', 'chuter', 'publier', 'agir', 'citer', 'retrouver', 'perdre', 'repérer', 'figurer', 'publier', 'supposer', 'permettre', 'avoir', 'capturer', 'établir', 'ouvrir', 'ouvrir', 'signaler', 'devenir', 'exposer', 'signer', 'reprendre', 'croire', 'interroger', 'retrouver', 'nager', 'extasier', 'paraître', 'paraître', 'prévoir', 'respecter', 'attendre', 'promettre', 'enfiler', 'tester', 'lgbt+', 'ouvrir', 'ouvrir', 'envers', 'marquer', 'constituer']

# %% [markdown]
# ### Question 14 : Couples d’entités et verbes associés
#
# Voici quelques exemples de couples entités-verbes pertinents qui semblent avoir du sens :
#
# 1. **Emmanuel Macron** et **France** :
#    - Verbes associés : *recevoir*, *observer*, *commémorer*, *faire*.
#    - Ces verbes reflètent le rôle présidentiel d'Emmanuel Macron dans des contextes nationaux.
#
# 2. **Boris Johnson** et **Royaume-Uni** :
#    - Verbes associés : *autoriser*, *accéder*.
#    - Ces verbes illustrent des décisions ou actions politiques.
#
# 3. **Angela Merkel** et **Allemagne** :
#    - Verbes associés : *justifier*, *briguer*.
#    - Ces verbes traduisent son rôle dans la politique allemande.
#
# 4. **Emmanuel Macron** et **Paris** :
#    - Verbes associés : *inaugurer*, *déclarer*.
#    - Cela indique des activités officielles dans la capitale.
#
# 5. **George Floyd** et **France** :
#    - Verbes associés : *dénoncer*, *scander*.
#    - Ces verbes montrent une mobilisation sociale en réaction à son décès.
#
# ---
#
# ### Question 15 : Utilité des couples et verbes identifiés pour trouver ou grouper des relations
#
# 1. **Détection de relations spécifiques :**
#    - Les couples entité-verbe peuvent aider à identifier des interactions ou des événements spécifiques entre des entités, comme des discours, des décisions ou des mobilisations.
#
# 2. **Catégorisation des relations :**
#    - Les verbes permettent de grouper les relations selon leur nature, comme :
#      - **Politique** : Verbes comme *inaugurer*, *déclarer*.
#      - **Sociale** : Verbes comme *dénoncer*, *scander*.
#      - **Économique** : Verbes comme *autoriser*, *accéder*.
#
# 3. **Analyse temporelle ou géographique :**
#    - On peut suivre l'évolution des relations dans le temps ou les localiser géographiquement.
#
# 4. **Découverte de patterns récurrents :**
#    - Les verbes entre entités permettent de détecter des relations répétées, signalant des interactions ou structures importantes (ex. *président -> France -> recevoir*).
#
# ---
#
# ### Question 16 : Affiner l’analyse avec l’arbre de dépendance syntaxique
#
# L’arbre de dépendance syntaxique pourrait être utilisé pour :
# 1. **Identifier des relations précises entre entités :**
#    - En analysant les dépendances directes entre deux entités (sujets, objets ou compléments).
#    - Exemple : Si *Emmanuel Macron* est le sujet et *observer* est le verbe gouvernant, alors *France* peut être l'objet.
#
# 2. **Réduire le bruit dans les relations :**
#    - Actuellement, tous les verbes entre deux entités sont extraits. Avec l'arbre de dépendance, seuls les verbes gouvernant les entités directement pourraient être retenus.
#
# 3. **Étudier des relations indirectes ou complexes :**
#    - Par exemple, dans une phrase comme :
#      > *Emmanuel Macron a promis à Paris une réforme majeure*,
#      - L’arbre permettrait d’extraire correctement la relation entre *Emmanuel Macron* (sujet) et *Paris* (complément).
#
# 4. **Classifier les types de relations :**
#    - En combinant les relations syntaxiques et les catégories de verbes, on peut mieux comprendre la nature des interactions (ex. décisions politiques, relations interpersonnelles, etc.).
#
# ---
